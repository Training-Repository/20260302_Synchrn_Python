# %%
# %pip install httplib2
# Out:
# Requirement already satisfied: httplib2 in .\.venv-scraping\Lib\site-packages (0.31.2)
# Requirement already satisfied: pyparsing<4,>=3.1 in .\.venv-scraping\Lib\site-packages (from httplib2) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import httplib2
print(httplib2.__version__)
import webbrowser
from pprint import pprint
# Out:
# 0.31.2

# %%
bin_url = 'https://httpbin.org/'

# %%
webbrowser.open(bin_url)
# Out:
# True

# %%
# Create http object
http = httplib2.Http()

# %%
# resp - response headers
# data - response body
resp, data = http.request(bin_url)

# %%
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '9593',
#  'content-location': 'https://httpbin.org/',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:16 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
type(resp), len(resp)
# Out:
# (httplib2.Response, 9)

# %%
resp.status, resp.reason, resp.version
# Out:
# (200, 'OK', 11)

# %%
## Response body
pprint(data)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta charset="UTF-8">\n'
#  b'    <title>httpbin.org</title>\n    <link href="https://fonts.googleapis.'
#  b'com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,6'
#  b'00,700"\n        rel="stylesheet">\n    <link rel="stylesheet" type="text/'
#  b'css" href="/flasgger_static/swagger-ui.css">\n    <link rel="icon" type="'
#  b'image/png" href="/static/favicon.ico" sizes="64x64 32x32 16x16" />\n    <'
#  b'style>\n        html {\n            box-sizing: border-box;\n            ov'
#  b'erflow: -moz-scrollbars-vertical;\n            overflow-y: scroll;\n      '
#  b'  }\n\n        *,\n        *:before,\n        *:after {\n            box-'
#  b'sizing: inherit;\n        }\n\n        body {\n            margin: 0;\n  '
#  b'          background: #fafafa;\n        }\n    </style>\n</head>\n\n<body'
#  b'>\n    <a href="https://github.com/requests/httpbin" class="github-corner'
#  b'" aria-label="View source on Github">\n        <svg width="80" height="80'
#  b'" viewBox="0 0 250 250" style="fill:#151513; color:#fff; position: absolute;'
#  b' top: 0; border: 0; right: 0;"\n            aria-hidden="true">\n         '
#  b'   <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 Z"></path>\n '
#  b'           <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 C122.0,82'
#  b'.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 C127.3,80.9 125.5'
#  b',87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"\n                fi'
#  b'll="currentColor" style="transform-origin: 130px 106px;" class="octo-arm"></'
#  b'path>\n            <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,1'
#  b'15.4 L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 1'
#  b'43.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 171.4,40.'
#  b'1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 190.9,65.4 C194.5'
#  b',69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 216.3,84.9 C212.7,93.1 20'
#  b'6.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 198.3,112.5 C181.9,128.9 168.3,'
#  b'122.5 157.7,114.1 C157.9,116.9 156.7,120.9 152.7,124.9 L141.0,136.5 C139.8,1'
#  b'37.7 141.6,141.9 141.8,141.8 Z"\n                fill="currentColor" clas'
#  b's="octo-body"></path>\n        </svg>\n    </a>\n    <svg xmlns="http://www'
#  b'.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="position'
#  b':absolute;width:0;height:0">\n        <defs>\n            <symbol viewBox='
#  b'"0 0 20 20" id="unlocked">\n                <path d="M15.8 8H14V5.6C14 2.'
#  b'703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203'
#  b' 0 2 .754 2 2.199V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1'
#  b'.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-'
#  b'.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8z"></pat'
#  b'h>\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="lo'
#  b'cked">\n                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.'
#  b'334 1 6 2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307'
#  b'l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.19'
#  b'6-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8zM12 8H8V5'
#  b'.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"\n                />\n'
#  b'            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="close'
#  b'">\n                <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L1'
#  b'0 11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 0-1.6'
#  b'97l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 1.228-.469 '
#  b'1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 .469.469.469 1.229'
#  b' 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 1.698z"\n          '
#  b'      />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" '
#  b'id="large-arrow">\n                <path d="M13.25 10L6.109 2.58c-.268-.2'
#  b'7-.268-.707 0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l'
#  b'-7.83 7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10'
#  b'z"\n                />\n            </symbol>\n\n            <symbol viewBox'
#  b'="0 0 20 20" id="large-arrow-down">\n                <path d="M17.418 6.1'
#  b'09c.272-.268.709-.268.979 0s.271.701 0 .969l-7.908 7.83c-.27.268-.707.268-.9'
#  b'79 0l-7.908-7.83c-.27-.268-.27-.701 0-.969.271-.268.709-.268.979 0L10 13.25l'
#  b'7.418-7.141z"\n                />\n            </symbol>\n\n\n           '
#  b' <symbol viewBox="0 0 24 24" id="jump-to">\n                <path d="M19 '
#  b'7v4H5.83l3.58-3.59L8 6l-6 6 6 6 1.41-1.41L5.83 13H21V7z" />\n            '
#  b'</symbol>\n\n            <symbol viewBox="0 0 24 24" id="expand">\n        '
#  b'        <path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z" />\n    '
#  b'        </symbol>\n\n        </defs>\n    </svg>\n\n\n    <div id="swagger'
#  b'-ui">\n        <div data-reactroot="" class="swagger-ui">\n            <di'
#  b'v>\n                <div class="information-container wrapper">\n         '
#  b'           <section class="block col-12">\n                        <div c'
#  b'lass="info">\n                            <hgroup class="main">\n         '
#  b'                       <h2 class="title">httpbin.org\n                   '
#  b'                 <small>\n                                        <pre cl'
#  b'ass="version">0.9.2</pre>\n                                    </small>\n '
#  b'                               </h2>\n                                <pr'
#  b'e class="base-url">[ Base URL: httpbin.org/ ]</pre>\n                    '
#  b'        </hgroup>\n                            <div class="description">\n'
#  b'                                <div class="markdown">\n                 '
#  b'                   <p>A simple HTTP Request &amp; Response Service.\n    '
#  b'                                    <br>\n                               '
#  b'         <br>\n                                        <b>Run locally: </'
#  b'b>\n                                        <code>$ docker run -p 80:80 k'
#  b'ennethreitz/httpbin</code>\n                                    </p>\n    '
#  b'                            </div>\n                            </div>\n  '
#  b'                          <div>\n                                <div>\n  '
#  b'                                  <a href="https://kennethreitz.org" target='
#  b'"_blank">the developer - Website</a>\n                                </d'
#  b'iv>\n                                <a href="mailto:me@kennethreitz.org"'
#  b'>Send email to the developer</a>\n                            </div>\n    '
#  b'                    </div>\n                        <!-- ADDS THE LOADER '
#  b'SPINNER -->\n                        <div class="loading-container">\n    '
#  b'                        <div class="loading"></div>\n                    '
#  b'    </div>\n\n                    </section>\n                </div>\n      '
#  b"      </div>\n        </div>\n    </div>\n\n\n    <div class='swagger-ui'"
#  b'>\n        <div class="wrapper">\n            <section class="clear">\n    '
#  b'            <span style="float: right;">\n                    [Powered by'
#  b'\n                    <a target="_blank" href="https://github.com/rochacb'
#  b'runo/flasgger">Flasgger</a>]\n                    <br>\n                </'
#  b'span>\n            </section>\n        </div>\n    </div>\n\n\n\n    <scrip'
#  b't src="/flasgger_static/swagger-ui-bundle.js"> </script>\n    <script src'
#  b'="/flasgger_static/swagger-ui-standalone-preset.js"> </script>\n    <scri'
#  b"pt src='/flasgger_static/lib/jquery.min.js' type='text/javascript'></script>"
#  b'\n    <script>\n\n        window.onload = function () {\n            \n\n '
#  b'           fetch("/spec.json")\n                .then(function (response)'
#  b' {\n                    response.json()\n                        .then(fun'
#  b'ction (json) {\n                            var current_protocol = window'
#  b'.location.protocol.slice(0, -1);\n                            if (json.sc'
#  b'hemes[0] != current_protocol) {\n                                // Switc'
#  b'hes scheme to the current in use\n                                var oth'
#  b'er_protocol = json.schemes[0];\n                                json.sche'
#  b'mes[0] = current_protocol;\n                                json.schemes['
#  b'1] = other_protocol;\n\n                            }\n                    '
#  b'        json.host = window.location.host;  // sets the current host\n\n   '
#  b'                         const ui = SwaggerUIBundle({\n                  '
#  b'              spec: json,\n                                validatorUrl: '
#  b"null,\n                                dom_id: '#swagger-ui',\n           "
#  b'                     deepLinking: true,\n                                '
#  b'jsonEditor: true,\n                                docExpansion: "none",\n'
#  b'                                apisSorter: "alpha",\n                   '
#  b'             //operationsSorter: "alpha",\n                              '
#  b'  presets: [\n                                    SwaggerUIBundle.presets'
#  b'.apis,\n                                    // yay ES6 modules \xe2\x86'
#  b'\x98\n                                    Array.isArray(SwaggerUIStandaloneP'
#  b'reset) ? SwaggerUIStandalonePreset : SwaggerUIStandalonePreset.default\n '
#  b'                               ],\n                                plugin'
#  b's: [\n                                    SwaggerUIBundle.plugins.Downloa'
#  b'dUrl\n                                ],\n            \n            // layo'
#  b'ut: "StandaloneLayout"  // uncomment to enable the green top header\n    '
#  b'    })\n\n        window.ui = ui\n\n        // uncomment to rename the top b'
#  b'rand if layout is enabled\n        // $(".topbar-wrapper .link span").rep'
#  b'laceWith("<span>httpbin</span>");\n        })\n    })\n}\n    </script>  <di'
#  b'v class=\'swagger-ui\'>\n    <div class="wrapper">\n        <section class="'
#  b'block col-12 block-desktop col-12-desktop">\n            <div>\n\n         '
#  b'       <h2>Other Utilities</h2>\n\n                <ul>\n                  '
#  b'  <li>\n                        <a href="/forms/post">HTML form</a> that '
#  b'posts to /post /forms/post</li>\n                </ul>\n\n                <'
#  b'br />\n                <br />\n            </div>\n        </section>\n    <'
#  b'/div>\n</div>\n</body>\n\n</html>')

# %%
type(data), len(data)
# Out:
# (bytes, 9593)

# %%
html = data.decode("UTF-8")
type(html)
# Out:
# str

# %%
pprint(html)
# Out:
# ('<!DOCTYPE html>\n'
#  '<html lang="en">\n'
#  '\n'
#  '<head>\n'
#  '    <meta charset="UTF-8">\n'
#  '    <title>httpbin.org</title>\n'
#  '    <link '
#  'href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700"\n'
#  '        rel="stylesheet">\n'
#  '    <link rel="stylesheet" type="text/css" '
#  'href="/flasgger_static/swagger-ui.css">\n'
#  '    <link rel="icon" type="image/png" href="/static/favicon.ico" '
#  'sizes="64x64 32x32 16x16" />\n'
#  '    <style>\n'
#  '        html {\n'
#  '            box-sizing: border-box;\n'
#  '            overflow: -moz-scrollbars-vertical;\n'
#  '            overflow-y: scroll;\n'
#  '        }\n'
#  '\n'
#  '        *,\n'
#  '        *:before,\n'
#  '        *:after {\n'
#  '            box-sizing: inherit;\n'
#  '        }\n'
#  '\n'
#  '        body {\n'
#  '            margin: 0;\n'
#  '            background: #fafafa;\n'
#  '        }\n'
#  '    </style>\n'
#  '</head>\n'
#  '\n'
#  '<body>\n'
#  '    <a href="https://github.com/requests/httpbin" class="github-corner" '
#  'aria-label="View source on Github">\n'
#  '        <svg width="80" height="80" viewBox="0 0 250 250" '
#  'style="fill:#151513; color:#fff; position: absolute; top: 0; border: 0; '
#  'right: 0;"\n'
#  '            aria-hidden="true">\n'
#  '            <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 '
#  'Z"></path>\n'
#  '            <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 '
#  'C122.0,82.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 '
#  'C127.3,80.9 125.5,87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"\n'
#  '                fill="currentColor" style="transform-origin: 130px 106px;" '
#  'class="octo-arm"></path>\n'
#  '            <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,115.4 '
#  'L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 '
#  '143.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 '
#  '171.4,40.1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 '
#  '190.9,65.4 C194.5,69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 '
#  '216.3,84.9 C212.7,93.1 206.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 '
#  '198.3,112.5 C181.9,128.9 168.3,122.5 157.7,114.1 C157.9,116.9 156.7,120.9 '
#  '152.7,124.9 L141.0,136.5 C139.8,137.7 141.6,141.9 141.8,141.8 Z"\n'
#  '                fill="currentColor" class="octo-body"></path>\n'
#  '        </svg>\n'
#  '    </a>\n'
#  '    <svg xmlns="http://www.w3.org/2000/svg" '
#  'xmlns:xlink="http://www.w3.org/1999/xlink" '
#  'style="position:absolute;width:0;height:0">\n'
#  '        <defs>\n'
#  '            <symbol viewBox="0 0 20 20" id="unlocked">\n'
#  '                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 '
#  '2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8H4c-.553 '
#  '0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 '
#  '19 7.1 19h5.8c.549 0 1.428-.139 '
#  '1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 '
#  '15.8 8z"></path>\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="locked">\n'
#  '                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 '
#  '2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 '
#  '1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 '
#  '1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 '
#  '15.8 8zM12 8H8V5.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="close">\n'
#  '                <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L10 '
#  '11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 '
#  '0-1.697l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 '
#  '1.228-.469 1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 '
#  '.469.469.469 1.229 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 '
#  '1.698z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="large-arrow">\n'
#  '                <path d="M13.25 10L6.109 2.58c-.268-.27-.268-.707 '
#  '0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l-7.83 '
#  '7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="large-arrow-down">\n'
#  '                <path d="M17.418 6.109c.272-.268.709-.268.979 0s.271.701 0 '
#  '.969l-7.908 7.83c-.27.268-.707.268-.979 0l-7.908-7.83c-.27-.268-.27-.701 '
#  '0-.969.271-.268.709-.268.979 0L10 13.25l7.418-7.141z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '\n'
#  '            <symbol viewBox="0 0 24 24" id="jump-to">\n'
#  '                <path d="M19 7v4H5.83l3.58-3.59L8 6l-6 6 6 6 1.41-1.41L5.83 '
#  '13H21V7z" />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 24 24" id="expand">\n'
#  '                <path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z" />\n'
#  '            </symbol>\n'
#  '\n'
#  '        </defs>\n'
#  '    </svg>\n'
#  '\n'
#  '\n'
#  '    <div id="swagger-ui">\n'
#  '        <div data-reactroot="" class="swagger-ui">\n'
#  '            <div>\n'
#  '                <div class="information-container wrapper">\n'
#  '                    <section class="block col-12">\n'
#  '                        <div class="info">\n'
#  '                            <hgroup class="main">\n'
#  '                                <h2 class="title">httpbin.org\n'
#  '                                    <small>\n'
#  '                                        <pre class="version">0.9.2</pre>\n'
#  '                                    </small>\n'
#  '                                </h2>\n'
#  '                                <pre class="base-url">[ Base URL: '
#  'httpbin.org/ ]</pre>\n'
#  '                            </hgroup>\n'
#  '                            <div class="description">\n'
#  '                                <div class="markdown">\n'
#  '                                    <p>A simple HTTP Request &amp; Response '
#  'Service.\n'
#  '                                        <br>\n'
#  '                                        <br>\n'
#  '                                        <b>Run locally: </b>\n'
#  '                                        <code>$ docker run -p 80:80 '
#  'kennethreitz/httpbin</code>\n'
#  '                                    </p>\n'
#  '                                </div>\n'
#  '                            </div>\n'
#  '                            <div>\n'
#  '                                <div>\n'
#  '                                    <a href="https://kennethreitz.org" '
#  'target="_blank">the developer - Website</a>\n'
#  '                                </div>\n'
#  '                                <a href="mailto:me@kennethreitz.org">Send '
#  'email to the developer</a>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                        <!-- ADDS THE LOADER SPINNER -->\n'
#  '                        <div class="loading-container">\n'
#  '                            <div class="loading"></div>\n'
#  '                        </div>\n'
#  '\n'
#  '                    </section>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '\n'
#  "    <div class='swagger-ui'>\n"
#  '        <div class="wrapper">\n'
#  '            <section class="clear">\n'
#  '                <span style="float: right;">\n'
#  '                    [Powered by\n'
#  '                    <a target="_blank" '
#  'href="https://github.com/rochacbruno/flasgger">Flasgger</a>]\n'
#  '                    <br>\n'
#  '                </span>\n'
#  '            </section>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '    <script src="/flasgger_static/swagger-ui-bundle.js"> </script>\n'
#  '    <script src="/flasgger_static/swagger-ui-standalone-preset.js"> '
#  '</script>\n'
#  "    <script src='/flasgger_static/lib/jquery.min.js' "
#  "type='text/javascript'></script>\n"
#  '    <script>\n'
#  '\n'
#  '        window.onload = function () {\n'
#  '            \n'
#  '\n'
#  '            fetch("/spec.json")\n'
#  '                .then(function (response) {\n'
#  '                    response.json()\n'
#  '                        .then(function (json) {\n'
#  '                            var current_protocol = '
#  'window.location.protocol.slice(0, -1);\n'
#  '                            if (json.schemes[0] != current_protocol) {\n'
#  '                                // Switches scheme to the current in use\n'
#  '                                var other_protocol = json.schemes[0];\n'
#  '                                json.schemes[0] = current_protocol;\n'
#  '                                json.schemes[1] = other_protocol;\n'
#  '\n'
#  '                            }\n'
#  '                            json.host = window.location.host;  // sets the '
#  'current host\n'
#  '\n'
#  '                            const ui = SwaggerUIBundle({\n'
#  '                                spec: json,\n'
#  '                                validatorUrl: null,\n'
#  "                                dom_id: '#swagger-ui',\n"
#  '                                deepLinking: true,\n'
#  '                                jsonEditor: true,\n'
#  '                                docExpansion: "none",\n'
#  '                                apisSorter: "alpha",\n'
#  '                                //operationsSorter: "alpha",\n'
#  '                                presets: [\n'
#  '                                    SwaggerUIBundle.presets.apis,\n'
#  '                                    // yay ES6 modules ↘\n'
#  '                                    Array.isArray(SwaggerUIStandalonePreset) '
#  '? SwaggerUIStandalonePreset : SwaggerUIStandalonePreset.default\n'
#  '                                ],\n'
#  '                                plugins: [\n'
#  '                                    SwaggerUIBundle.plugins.DownloadUrl\n'
#  '                                ],\n'
#  '            \n'
#  '            // layout: "StandaloneLayout"  // uncomment to enable the green '
#  'top header\n'
#  '        })\n'
#  '\n'
#  '        window.ui = ui\n'
#  '\n'
#  '        // uncomment to rename the top brand if layout is enabled\n'
#  '        // $(".topbar-wrapper .link '
#  'span").replaceWith("<span>httpbin</span>");\n'
#  '        })\n'
#  '    })\n'
#  '}\n'
#  "    </script>  <div class='swagger-ui'>\n"
#  '    <div class="wrapper">\n'
#  '        <section class="block col-12 block-desktop col-12-desktop">\n'
#  '            <div>\n'
#  '\n'
#  '                <h2>Other Utilities</h2>\n'
#  '\n'
#  '                <ul>\n'
#  '                    <li>\n'
#  '                        <a href="/forms/post">HTML form</a> that posts to '
#  '/post /forms/post</li>\n'
#  '                </ul>\n'
#  '\n'
#  '                <br />\n'
#  '                <br />\n'
#  '            </div>\n'
#  '        </section>\n'
#  '    </div>\n'
#  '</div>\n'
#  '</body>\n'
#  '\n'
#  '</html>')

# %%
resp, data = http.request('http://google.com')
pprint(resp)
# Out:
# {'-content-encoding': 'gzip',
#  'cache-control': 'private, max-age=0',
#  'content-length': '20080',
#  'content-location': 'http://www.google.com/',
#  'content-security-policy-report-only': "object-src 'none';base-uri "
#                                         "'self';script-src "
#                                         "'nonce-hNSjLO4lkC20oQtt7q-L7Q' "
#                                         "'strict-dynamic' 'report-sample' "
#                                         "'unsafe-eval' 'unsafe-inline' https: "
#                                         'http:;report-uri '
#                                         'https://csp.withgoogle.com/csp/gws/other-hp',
#  'content-type': 'text/html; charset=ISO-8859-1',
#  'date': 'Fri, 06 Mar 2026 04:39:17 GMT',
#  'expires': '-1',
#  'p3p': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."',
#  'reporting-endpoints': 'default="//www.google.com/httpservice/retry/jserror?ei=dVqqabntL5K0hbIPi9rNqAE&cad=crash&error=Page%20Crash&jsel=1&bver=2392&dpf=-ilRIpYoaDLpVX1jDf-UriuGQ1YI0ko-S2Q1HMSXjKw"',
#  'server': 'gws',
#  'set-cookie': '__Secure-STRP=AEEP7gJz8FHZHJIEiEmr0G0hKknyEYfqIGV8xce3bV4P9_qf3PIV19lZWK7ezommlNvrLCpVNA8Qwu_pGW1nR9JQqMk-0KwPA-5t; '
#                'expires=Fri, 06-Mar-2026 04:44:17 GMT; path=/; '
#                'domain=.google.com; Secure; SameSite=strict, '
#                'AEC=AaJma5tTaW72S0hHYdQgztqr9LbcQT18NhtOzmp8BrNHuQ6fnrcVb05dEA; '
#                'expires=Wed, 02-Sep-2026 04:39:17 GMT; path=/; '
#                'domain=.google.com; Secure; HttpOnly; SameSite=lax, '
#                'NID=529=tXwMU39UJl49hKiYfTgJg3_P4e9vX8uYQ9IhTmFX2LSJ68u8jNXAIsnTw6t8Lu1V-GAIn3_Ju4wpZwqVCHXD-GOk9FjxtixoI0TrrGpyyKSGSSVKXJbyqmSREplr1IgHw2YiJE7WFBPK-G0iDKGtpwvt-NdP7tD6M5rKOw2TncVC7UtBAmVgcYlJDvdKur-bcHzgKl8A8BHlcrTnZFO10vdmGct3ECcrDA; '
#                'expires=Sat, 05-Sep-2026 04:39:17 GMT; path=/; '
#                'domain=.google.com; HttpOnly',
#  'status': '200',
#  'transfer-encoding': 'chunked',
#  'x-frame-options': 'SAMEORIGIN',
#  'x-xss-protection': '0'}

# %%
type(data)
# Out:
# bytes

# %%
html = data.decode('ISO-8859-1')
type(html)
# Out:
# str

# %%
pprint(html)
# Out:
# ('<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" '
#  'lang="en-IN"><head><meta content="text/html; charset=UTF-8" '
#  'http-equiv="Content-Type"><meta '
#  'content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" '
#  'itemprop="image"><title>Google</title><script '
#  'nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){var '
#  "_g={kEI:'dVqqabntL5K0hbIPi9rNqAE',kEXPI:'0,203055,10,1101138,2026104,1004656,344796,301150,5219187,12640,36811391,25381059,65168,37669,2106,75317,23254,37805,28334,48903,30411,7714,33385,3050,2,1667,23626,749,22727,25296,21041,20676,2,203,11682,6437,9742,2646,2246,22000,1472,2,2,13029,1383,2,1,1515,3355,2,194,5814,2,4205,3,10939,5159,2,874,2231,5089,19,3008,10,785,4081,4,5386,3326,22576,1250,5337,311,534,2046,2,12,16,1545,3,5941,1010,1747,4,15193,4,2200,2,9,4,28,537,5,1113,389,4,2647,5,5568,298,3414,2846,2993,1275,7,1784,7,1049,2,1912,1947,8510,2,5724,9,602,96,1553,4,794,5135,915,3089,1,2,1378,3,1359,2,2356,2636,10,204,441,158,2,1645,191,4,1928,4,1634,544,4,1567,1034,1399,187,2105,5,259,5,197,1921,445,19,1540,4,385,1979,2363,5,40,6418,4,354,1691,5,264,107,5,4,970,4,966,5,1125,3,2,46,2596,1108,4,32,4,844,510,1349,4,40,4,2110,4,438,323,1,2352,1628,4,233,41,5,1,1184,4,14,3,2,1,447,4,730,5,75,4,1940,4,1431,991,572,1,1091,1,265,1736,5659,14,507,824,1307,1162,8,5,14,57,258,615,80,8,818,1426,4,281,264,563,1652,1324,847,2206,5,1722,4,313,1,2421,2172,4,939,22,4,463,945,21007086,5,2253,739,4,2960,3,3237,5254,2,1558,3,11875,4193,3,746,6,1149,3,5578,2,1968,2,696,2,6501138,1165,1082,107347,2438384,2086746,11695112,4360998,101,10,590,5,1242,3,49,1399,845,149,3,12,1,600,4,65,388,2,932,235,4,769,3,2,2,2,550,4,2628,5,4247,111,1,2,12,44,2,12,16,362,1366,1,2,642,207,7,298,3,12,1,1171,4424,1,2,440,159,122,5,231,1761,206,5,77,215,5,142,4,228,576,1922,2,197,348,471,165,8,109,54,5,1071,582,4,73,2555,556,1260,5,2,8,713,4,222,14,6,1968,4,70,230,304,71,211,125,4,4,3,1,2,2,3,1,3,1,2,3,2,2,2,1,2,2,3,2,2,1,2,3,1,3,1,3,1,3,2,2,1,2,3,1,3,2,1,2,3,1,2,2,2,2,3,9,3,2,1,3,1,11,1,3,2,1,2,11,1,2,2,2,3,9,2,3,2,2,1,2,2,2,3,2,2,2,1,3,2,1,2,2,2,3,1,2,3,2,2,2,2,2,1,3,1,3,1,3,2,2,1,2,3,1,2,3,2,2,1,11,2,1,2,2,3,9,3,2,1,2,2,11,2,1,3,1,2,277,60,548,1278,4,117,345,243,2,131,1820,8,85,1,337,191,609,4,465,737,3,872,4,335,245,2171,665,443,198,1702,9,946,73,65,3,605,3,2,2,2,720,189,3,2,1,8,2134,302,119,450,9,2036,133,335,4,502,178,93,117,450,408,259,3,4,91,370,5,27,495,3,2,2,2,239,4,320,138,96,31,3,605,24,28,456,374,281,73,824,1105,8,12,546,140,3,222,4,290,462,585,4,2268,4,140,3,2,1,8,731,581,1172,2,1077,3552',kBL:'GbFW',kOPI:89978449};(function(){var "
#  "a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='en-IN';google.rdn=true;})();(function(){\n"
#  'var g=this||self;function k(){return '
#  'window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var '
#  'b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return '
#  'b||l}function p(a){for(var '
#  'b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return '
#  'b}function '
#  'q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return '
#  'a}\n'
#  'function r(a,b,d,c,h){var '
#  'e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var '
#  'f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return '
#  'null};google.log=function(a,b,d,c,h,e){e=e===void '
#  '0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var '
#  'f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete '
#  'm[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return '
#  'r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function '
#  'e(a,b,d){if(a)var c=a.id;else{do c=Math.random();while(d[c])}d[c]=[a,b]}var '
#  'f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var '
#  'g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.bx=!1;var '
#  'h;(h=google).lx||(h.lx=function(){});var '
#  'k=[],l;(l=google).fce||(l.fce=function(a,b,d,c){k.push([a,b,d,c])});google.qce=k;google.adl=[];}).call(this);google.f={};(function(){\n'
#  'document.documentElement.addEventListener("submit",function(b){var '
#  'a;if(a=b.target){var '
#  'c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else '
#  'a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var '
#  'a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break '
#  'a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px '
#  '!important;}#gbar{height:22px}#guser{padding-bottom:7px '
#  '!important;text-align:right}.gbh,.gbd{border-top:1px solid '
#  '#c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media '
#  'all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline '
#  '!important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 '
#  '!important}.gbf .gb4{color:#900 !important}\n'
#  '</style><style>body,td,a,p,.h{font-family:sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px '
#  '8px 0}td{line-height:.8em}.gac_m '
#  'td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px '
#  'sans-serif}.gsfs{font:17px '
#  'sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 '
#  '4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#1f1f1f}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl '
#  'a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc '
#  'a{display:block;margin:2px '
#  '0;margin-left:13px;font-size:11px}.lsbb{background:#ecedee;border:solid '
#  '1px;border-color:#d2d2d2 #70757a #70757a '
#  '#d2d2d2;height:30px}.lsbb{display:block}#WqQANb '
#  'a{display:inline-block;margin:0 '
#  '12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px '
#  'repeat-x;color:#1f1f1f;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px '
#  'sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script '
#  'nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){window.google.erd={jsr:1,bv:2392,de:true,dpf:\'-ilRIpYoaDLpVX1jDf-UriuGQ1YI0ko-S2Q1HMSXjKw\',c:\'3e32\'};\n'
#  'var f=this||self;var '
#  'k,l=(k=f.mei)!=null?k:1,m,p=(m=f.diel)!=null?m:0,q,r=(q=f.sdo)!=null?q:!0,t=0,u,v=google.erd,w=v.jsr;google.ml=function(a,b,d,n,e){e=e===void '
#  '0?2:e;b&&(u=a&&a.message);d===void '
#  '0&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return '
#  'google.dl(a,e,d,!0),null;b=d;if(w<0){window.console&&console.error(a,b);if(w===-2)throw '
#  'a;b=!1}else b=!a||!a.message||a.message==="Error loading '
#  'script"||t>=l&&!n?!1:!0;if(!b)return '
#  'null;t++;d=d||{};b=encodeURIComponent;var '
#  'c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(v.jsr)+\n'
#  '"&bver="+b(v.bv);v.dpf&&(c+="&dpf="+b(v.dpf));var g=a.lineNumber;g!==void '
#  '0&&(c+="&line="+g);var '
#  'h=a.fileName;h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),g&&h===window.location.href&&(g=document.documentElement.outerHTML.split("\\n")[g],c+="&cad="+b(g?g.substring(0,300):"No '
#  'script '
#  'found.")));google.ple&&google.ple===1&&(e=2);d&&v.c&&(d.ofc=String(v.c));c=c+("&jsel="+e)+"&ectx="+b(JSON.stringify(d));c+="&emsg=";c+=b(a.name+": '
#  '"+a.message);c+="&jsst=";c+=b(a.stack||"N/A");c.length>=12288&&\n'
#  '(c=c.substring(0,12288));a=c;n||google.log(0,"",a);return '
#  'a};window.onerror=function(a,b,d,n,e){u!==a&&(a=e instanceof '
#  'Error?e:Error(a),d===void 0||"lineNumber"in a||(a.lineNumber=d),b===void '
#  '0||"fileName"in a||(a.fileName=b),google.ml(a,!1,void '
#  '0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="SyntaxError"||a.message.indexOf("Script '
#  'error")!==-1?3:p));u=null;r&&t>=l&&(window.onerror=null)};})();</script></head><body '
#  'bgcolor="#fff"><script nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){var '
#  "src='/images/nav_logo229.png';var iesg=false;document.body.onload = "
#  'function(){window.n && window.n();if (document.images){new '
#  'Image().src=src;}\n'
#  'if '
#  '(!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}\n'
#  '}\n'
#  '})();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>Search</b> <a '
#  'class=gb1 href="https://www.google.com/imghp?hl=en&tab=wi">Images</a> <a '
#  'class=gb1 href="http://maps.google.co.in/maps?hl=en&tab=wl">Maps</a> <a '
#  'class=gb1 href="https://play.google.com/?hl=en&tab=w8">Play</a> <a class=gb1 '
#  'href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 '
#  'href="https://news.google.com/?tab=wn">News</a> <a class=gb1 '
#  'href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 '
#  'href="https://drive.google.com/?tab=wo">Drive</a> <a class=gb1 '
#  'style="text-decoration:none" '
#  'href="https://www.google.co.in/intl/en/about/products?tab=wh"><u>More</u> '
#  '&raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn '
#  'class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a '
#  'href="http://www.google.co.in/history/optout?hl=en" class=gb4>Web '
#  'History</a> | <a  href="/preferences?hl=en" class=gb4>Settings</a> | <a '
#  'target=_top id=gb_70 '
#  'href="https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=http://www.google.com/&ec=GAZAAQ" '
#  'class=gb4>Sign in</a></nobr></div><div class=gbh style=left:0></div><div '
#  'class=gbh style=right:0></div></div><center><br clear="all" '
#  'id="lgpd"><div><img alt="Google" height="92" '
#  'src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" '
#  'style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form '
#  'action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr '
#  'valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input '
#  'name="ie" value="ISO-8859-1" type="hidden"><input value="en-IN" name="hl" '
#  'type="hidden"><input name="source" type="hidden" value="hp"><input '
#  'name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" '
#  'style="height:32px;margin:4px 0"><input class="lst" '
#  'style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#1f1f1f" '
#  'autocomplete="off" value="" title="Google Search" maxlength="2048" name="q" '
#  'size="57"></div><br style="line-height:0"><span class="ds"><span '
#  'class="lsbb"><input class="lsb" value="Google Search" name="btnG" '
#  'type="submit"></span></span><span class="ds"><span class="lsbb"><input '
#  'class="lsb" id="tsuid_dVqqabntL5K0hbIPi9rNqAE_1" value="I\'m Feeling Lucky" '
#  'name="btnI" type="submit"><script '
#  'nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){var '
#  "id='tsuid_dVqqabntL5K0hbIPi9rNqAE_1';document.getElementById(id).onclick = "
#  'function(){if (this.form.q.value){this.checked = 1;if '
#  '(this.form.iflsig)this.form.iflsig.disabled = false;}\n'
#  "else top.location='/doodles/';};})();</script><input "
#  'value="AFdpzrgAAAAAaapohUaR_6ErQb1QciV2QbzYSZWalJhf" name="iflsig" '
#  'type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" '
#  'width="25%"><a href="/advanced_search?hl=en-IN&amp;authuser=0">Advanced '
#  'search</a></td></tr></table><input id="gbv" name="gbv" type="hidden" '
#  'value="1"><script nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){var '
#  'a,b="1";if(document&&document.getElementById)if(typeof '
#  'XMLHttpRequest!="undefined")b="2";else if(typeof '
#  'ActiveXObject!="undefined"){var '
#  'c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new '
#  'ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.search.indexOf("&gbv=2")==-1){var '
#  'f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div '
#  'style="font-size:83%;min-height:3.5em"><br><div '
#  'id="gws-output-pages-elements-homepage_additional_languages__als"><style>#gws-output-pages-elements-homepage_additional_languages__als{font-size:small;margin-bottom:24px}#SIvCob{color:#545454;display:inline-block;line-height:28px;}#SIvCob '
#  'a{}.H6sW5{display:inline-block;margin:0 '
#  '2px;white-space:nowrap}.z4hgWe{display:inline-block;margin:0 '
#  '2px}</style><div id="SIvCob">Google offered in:  <a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=hi&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAY">&#2361;&#2367;&#2344;&#2381;&#2342;&#2368;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=bn&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAc">&#2476;&#2494;&#2434;&#2482;&#2494;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=te&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAg">&#3108;&#3142;&#3122;&#3137;&#3095;&#3137;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=mr&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAk">&#2350;&#2352;&#2366;&#2336;&#2368;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=ta&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAo">&#2980;&#2990;&#3007;&#2996;&#3021;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=gu&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAs">&#2711;&#2753;&#2716;&#2736;&#2750;&#2724;&#2752;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=kn&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCAw">&#3221;&#3240;&#3277;&#3240;&#3233;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=ml&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCA0">&#3374;&#3378;&#3375;&#3390;&#3379;&#3330;</a>    '
#  '<a '
#  'href="http://www.google.com/setprefs?sig=0_C91cpskWWsJqcumlsRoqttK6KQ0%3D&amp;hl=pa&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj5-76WuoqTAxUSWkEAHQttExUQ2ZgBCA4">&#2602;&#2672;&#2588;&#2622;&#2604;&#2624;</a>  '
#  '</div></div></div><span id="footer"><div style="font-size:10pt"><div '
#  'style="margin:19px auto;text-align:center" id="WqQANb"><a '
#  'href="/intl/en/ads/">Advertising</a><a '
#  'href="http://www.google.co.in/services/">Business Solutions</a><a '
#  'href="/intl/en/about.html">About Google</a><a '
#  'href="http://www.google.com/setprefdomain?prefdom=IN&amp;prev=http://www.google.co.in/&amp;sig=K_agkWEe35S3w1cfZj5pDTB3YyBRE%3D">Google.co.in</a></div></div><p '
#  'style="font-size:8pt;color:#636363">&copy; 2026 - <a '
#  'href="/intl/en/policies/privacy/">Privacy</a> - <a '
#  'href="/intl/en/policies/terms/">Terms</a></p></span></center><script '
#  'nonce="hNSjLO4lkC20oQtt7q-L7Q">(function(){window.google.cdo={height:757,width:1440};(function(){var '
#  'a=window.innerWidth,b=window.innerHeight;if(!a||!b){var '
#  'c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var '
#  'e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.google&&window.google.kOPI||null;k&&(h+="&opi="+k);f.call(e,"","",g+h)};}).call(this);})();(function(){google.xjs={basecomb:\'/xjs/_/js/k\\x3dxjs.hp.en.DVckD5E6_mI.es5.O/ck\\x3dxjs.hp.xXhd6_dRK-k.L.X.O/am\\x3dAAIAAAAAAACAAAAAAAAAAAAAAAAAAAAAgAAAAAAgQCAAAAAAAAAAAAAAAEAAAAAAAAAAwQAAAAgAIQAAAAAAgAAAEAAAAAAAAQAAAkAAAACAuCMAAAAAAIAAWAQAAAAAAADwEA/d\\x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oGIPjI9HSpmoVJWPZEtkKlpd9X71w\',basecss:\'/xjs/_/ss/k\\x3dxjs.hp.xXhd6_dRK-k.L.X.O/am\\x3dAAIAAAAAAACAAAAAAAAAAAAAAAAAAAAAgAAAAAAgACAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAIQAAAAAAgAAAEAAAAAAAAQAAAkA/rs\\x3dACT90oH8mezoU_KvtRTiwXpZ6RVAiO2R2g\',basejs:\'/xjs/_/js/k\\x3dxjs.hp.en.DVckD5E6_mI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAAAEAAAAAAAAAAwQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACAuCMAAAAAAIAAWAQAAAAAAADwEA/dg\\x3d0/rs\\x3dACT90oGQ6WxBfHoSpgNse_b-EHv9CI0m2A\',excm:[]};})();(function(){var '
#  "u='/xjs/_/js/k\\x3dxjs.hp.en.DVckD5E6_mI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAAAEAAAAAAAAAAwQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACAuCMAAAAAAIAAWAQAAAAAAADwEA/d\\x3d1/ed\\x3d1/dg\\x3d4/rs\\x3dACT90oGQ6WxBfHoSpgNse_b-EHv9CI0m2A/m\\x3dsb_he,d';var "
#  'st=1;var amd=1000;var mmd=0;var pop=true;var povp=false;var raf=false;var '
#  'lfpp=false;var ecb=false;var cst=false;var pxp=false;\n'
#  'var f=this||self;function g(){var a=google.ia&&google.ia.r.B2Jtyd;return '
#  'a&&[1,5,6].indexOf(a.m)>=0&&a.cbfd&&a.cbvi?a:void 0};function h(a){var '
#  'b=document.createElement("link");b.as="script";b.href=a;b.rel="preload";document.body.appendChild(b)}function '
#  'k(){var '
#  'a=[l];google.dp||(a.forEach(h),google.dp=!0)};google.ps=google.ps||[];function '
#  'm(a){return a?(a=a.match(/[/?&]ccb=([^/&?#]+)/))?a[1]:null:null}function '
#  'p(a){var '
#  'b=l,c=function(){};google.lx=google.stvsc?c:function(){q(b,a&&raf,a&&lfpp);google.lx=c};google.bx||google.lx()}function '
#  'r(a,b){b&&(a.src=b);if(!m(a.src)){var '
#  'c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(e){return '
#  'a.src!==e})}}google.ps.push(a.src);document.body.appendChild(a)}\n'
#  'function '
#  't(a,b,c,d){c&&(a.fetchPriority="low");b?requestAnimationFrame(function(){r(a,d)}):r(a,d)}google.as=r;function '
#  'q(a,b,c){google.tick&&google.tick("load","xjsls");var '
#  'd=document.createElement("script");d.onerror=function(){google.ple=1};d.onload=function(){google.ple=0};google.xjsus=void '
#  '0;t(d,b,c,a);google.aple=-1;google.dp=!0};function w(){for(var '
#  'a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var '
#  'd=a[b],e;if(e=d.hasAttribute("data-lzy_")&&Number(d.getAttribute("data-atf"))&1)e=d.getAttribute("jscontroller"),e=!((e==="UBXHI"||e==="R3fhkb"||e==="TSZEqd")&&d.hasAttribute("data-src"));if(e)return!0}return!1};var '
#  'l,x,y,z,A,B,C,D,E,F,G="";function H(){l=pxp&&google.xjsup||u;var '
#  'a=l.match(/\\/cb=(loaded_h_\\d+)/);a&&a[1]&&(G=a[1]);google.xjsu=l;f._F_jsUrl=l;B=function(c){p(c)};x=!1;y=(st===1||st===3)&&!!google.caft&&!w();z=g();A=!G&&(st===2||st===3)&&!!z&&!w();if(G){var '
#  'b=(st===2||st===3)&&!!z;f[G]=function(c){var '
#  'd=!1,e=function(){d||(d=!0,cst?setTimeout(function(){return void '
#  'c.call(window,window._)},0):c.call(window,window._))};b&&google.ia.adls?(z.cbvi.push(function(){delete '
#  'google.ia.adls}),z.cbvi.push(e),setTimeout(e,mmd)):e()}}C=\n'
#  'pop;D=povp;E=C&&document.prerendering||D&&document.hidden;F=D?"visibilitychange":"prerenderingchange"}function '
#  'I(a){x||y||A||E||(B(a),x=!0)}\n'
#  'setTimeout(function(){google.tick&&google.tick("load","xjspls");H();if(y||A||E){if(y){var '
#  'a=function(){y=!1;I()};google.caft(a);setTimeout(a,amd)}A&&(a=function(){A=!1;I()},z.cbvi.push(a),setTimeout(a,mmd));if(E){var '
#  'b=function(){(D?document.hidden:document.prerendering)||(E=!1,I(!D),document.removeEventListener(F,b))};document.addEventListener(F,b,{passive:!0})}x||k()}else '
#  'B()},0);})();window._ = window._ || {};window._DumpException = '
#  '_._DumpException = function(e){throw e;};window._s = window._s || '
#  '{};_s._DumpException = _._DumpException;window._qs = window._qs || '
#  '{};_qs._DumpException = _._DumpException;window.loaded_h_0 = '
#  'function(cb){cb.call(window,window._);};(function(){var '
#  't=[512,0,2048,0,0,0,524288,134217728,12384,2,32768,34603008,16554528,721682433,8388896,536873024,1082117,4194306,0,64,16386,249692160,2,538968064,1112,0,69376];window._F_toggles '
#  '= window._xjs_toggles = t;})();window._F_installCss = window._F_installCss '
#  '|| function(css){};(function(){var '
#  "pmc='{\\x22d\\x22:{},\\x22sb_he\\x22:{\\x22client\\x22:\\x22heirloom-hp\\x22,\\x22dh\\x22:true,\\x22ds\\x22:\\x22\\x22,\\x22host\\x22:\\x22google.com\\x22,\\x22jsonp\\x22:true,\\x22msgs\\x22:{\\x22cibl\\x22:\\x22Clear "
#  'Search\\x22,\\x22dym\\x22:\\x22Did you '
#  'mean:\\x22,\\x22lcky\\x22:\\x22I\\\\u0026#39;m Feeling '
#  'Lucky\\x22,\\x22lml\\x22:\\x22Learn more\\x22,\\x22psrc\\x22:\\x22This '
#  'search was removed from your \\\\u003Ca '
#  'href\\x3d\\\\\\x22/history\\\\\\x22\\\\u003EWeb '
#  'History\\\\u003C/a\\\\u003E\\x22,\\x22psrl\\x22:\\x22Remove\\x22,\\x22sbit\\x22:\\x22Search '
#  'by image\\x22,\\x22srch\\x22:\\x22Google '
#  "Search\\x22},\\x22ovr\\x22:{},\\x22pq\\x22:\\x22\\x22,\\x22rfs\\x22:[],\\x22stok\\x22:\\x22WxmgVqmPipG0Fddxhxfqtczr0NU\\x22}}';google.pmc=JSON.parse(pmc);})();</script></body></html>")

# %% [markdown]
# #### Making OPTIONS, POST, PUT requests with httplib2

# %%
resp, data = http.request(bin_url, method='OPTIONS')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-methods': 'GET, POST, PUT, DELETE, PATCH, OPTIONS',
#  'access-control-allow-origin': '*',
#  'access-control-max-age': '3600',
#  'allow': 'OPTIONS, HEAD, GET',
#  'connection': 'keep-alive',
#  'content-length': '0',
#  'content-location': 'https://httpbin.org/',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:18 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
resp, data = http.request(bin_url, method='HEAD')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '9593',
#  'content-location': 'https://httpbin.org/',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:19 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
len(data)
# Out:
# 0

# %%
resp, data = http.request('https://httpbin.org/get', method='GET')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '291',
#  'content-location': 'https://httpbin.org/get',
#  'content-type': 'application/json',
#  'date': 'Fri, 06 Mar 2026 04:39:20 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
type(data), len(data)
# Out:
# (bytes, 291)

# %%
# POST operation
post_data = '{"name": "Amit", "city": "Pune"}'

# %%
resp, data = http.request('https://httpbin.org/post', 
                          method='POST',
                          body = post_data,
                          headers={'content-type': 'application/json'})
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '506',
#  'content-type': 'application/json',
#  'date': 'Fri, 06 Mar 2026 04:39:21 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
pprint(data.decode('UTF-8'))
# Out:
# ('{\n'
#  '  "args": {}, \n'
#  '  "data": "{\\"name\\": \\"Amit\\", \\"city\\": \\"Pune\\"}", \n'
#  '  "files": {}, \n'
#  '  "form": {}, \n'
#  '  "headers": {\n'
#  '    "Accept-Encoding": "gzip, deflate", \n'
#  '    "Content-Length": "32", \n'
#  '    "Content-Type": "application/json", \n'
#  '    "Host": "httpbin.org", \n'
#  '    "User-Agent": "Python-httplib2/0.31.2 (gzip)", \n'
#  '    "X-Amzn-Trace-Id": "Root=1-69aa5a79-5ecda84d07ff43da3cce71d1"\n'
#  '  }, \n'
#  '  "json": {\n'
#  '    "city": "Pune", \n'
#  '    "name": "Amit"\n'
#  '  }, \n'
#  '  "origin": "182.70.49.86", \n'
#  '  "url": "https://httpbin.org/post"\n'
#  '}\n')

# %%
# PUT operation
resp, data = http.request('https://httpbin.org/put', 
                          method='PUT',
                          body = post_data,
                          headers={'content-type': 'application/json'})
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '505',
#  'content-type': 'application/json',
#  'date': 'Fri, 06 Mar 2026 04:39:21 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %% [markdown]
# #### Redirects

# %%
http.follow_redirects
# Out:
# True

# %%
http.follow_all_redirects
# Out:
# False

# %%
resp, data = http.request('http://httpbin.org/absolute-redirect/1',
                          method='GET')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '290',
#  'content-location': 'http://httpbin.org/get',
#  'content-type': 'application/json',
#  'date': 'Fri, 06 Mar 2026 04:39:22 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
pprint(resp.previous)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '251',
#  'content-location': 'http://httpbin.org/absolute-redirect/1',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:22 GMT',
#  'location': 'http://httpbin.org/get',
#  'server': 'gunicorn/19.9.0',
#  'status': '302'}

# %%
http.follow_redirects = False
resp, data = http.request('http://httpbin.org/absolute-redirect/1',
                          method='GET')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '251',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:22 GMT',
#  'location': 'http://httpbin.org/get',
#  'server': 'gunicorn/19.9.0',
#  'status': '302'}

# %%
resp, data = http.request('http://httpbin.org/redirect-to?url=https://google.com&status=200',
                          method='GET')
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '0',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Fri, 06 Mar 2026 04:39:23 GMT',
#  'location': 'https://google.com',
#  'server': 'gunicorn/19.9.0',
#  'status': '302'}

# %%
http.follow_redirects = True
resp, data = http.request('http://httpbin.org/redirect-to?url=https://google.com&status=200',
                          method='GET')
pprint(resp)
# Out:
# {'-content-encoding': 'gzip',
#  'accept-ch': 'Sec-CH-Prefers-Color-Scheme',
#  'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000',
#  'cache-control': 'private, max-age=0',
#  'content-length': '20166',
#  'content-location': 'https://www.google.com/',
#  'content-security-policy-report-only': "object-src 'none';base-uri "
#                                         "'self';script-src "
#                                         "'nonce-ZpMGKvcKlx7ubsIdOaxAMA' "
#                                         "'strict-dynamic' 'report-sample' "
#                                         "'unsafe-eval' 'unsafe-inline' https: "
#                                         'http:;report-uri '
#                                         'https://csp.withgoogle.com/csp/gws/other-hp',
#  'content-type': 'text/html; charset=ISO-8859-1',
#  'date': 'Fri, 06 Mar 2026 04:39:26 GMT',
#  'expires': '-1',
#  'p3p': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."',
#  'reporting-endpoints': 'default="//www.google.com/httpservice/retry/jserror?ei=flqqaea5CKechbIPnebcgAY&cad=crash&error=Page%20Crash&jsel=1&bver=2392&dpf=-ilRIpYoaDLpVX1jDf-UriuGQ1YI0ko-S2Q1HMSXjKw"',
#  'server': 'gws',
#  'set-cookie': '__Secure-STRP=AEEP7gIQVtFZc6HOmqTafaZw4nABkWrAhVvILyJ0Zl59M5qXZp8xEEBf_1oQKNA29IznTPmg0UqIv36CkJD5C-UhNPk6H_ow6Q; '
#                'expires=Fri, 06-Mar-2026 04:44:26 GMT; path=/; '
#                'domain=.google.com; Secure; SameSite=strict, '
#                'AEC=AaJma5u9WdINffPqADXiEdUw-XRdiJCeUv5Qks7-uLPDCSkA6RBQuArkD2g; '
#                'expires=Wed, 02-Sep-2026 04:39:26 GMT; path=/; '
#                'domain=.google.com; Secure; HttpOnly; SameSite=lax, '
#                'NID=529=ng3slc7ZLYILdSxJn_jCzDc2RHTjyigimqf9XVPHLSUbJmZLZ8bHW2q12Tagi1V-ha5DsY9Yv6RXiZ-Hr-7LpTznLU02xouBNyPoODOq2wcAm3oNBuBnju5b7KRGmiMprnAZTIydhvYqfkuzMmD3Z9534RZG6Ygnza7V1Neq712QQtLqN45BV-SpDI5FergOYkVF6j7KOLkFHMR-zToI3s268d9hexBdtT8; '
#                'expires=Sat, 05-Sep-2026 04:39:26 GMT; path=/; '
#                'domain=.google.com; HttpOnly, __Secure-BUCKET=CLED; '
#                'expires=Wed, 02-Sep-2026 04:39:26 GMT; path=/; '
#                'domain=.google.com; Secure; HttpOnly',
#  'status': '200',
#  'transfer-encoding': 'chunked',
#  'x-frame-options': 'SAMEORIGIN',
#  'x-xss-protection': '0'}

# %% [markdown]
# #### Using urllib

# %%
import urllib
from pprint import pprint

bin_url = 'https://httpbin.org'

# %%
resp = urllib.request.urlopen(bin_url)
resp

# %%
resp.geturl()
# Out:
# 'https://httpbin.org'

# %%
resp.getcode()
# Out:
# 200

# %%
print(resp.info())
# Out:
# Date: Fri, 06 Mar 2026 04:39:27 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 9593
# Connection: close
# Server: gunicorn/19.9.0
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true

# %%
data =  resp.read()
pprint(data.decode('UTF-8'))
# Out:
# ('<!DOCTYPE html>\n'
#  '<html lang="en">\n'
#  '\n'
#  '<head>\n'
#  '    <meta charset="UTF-8">\n'
#  '    <title>httpbin.org</title>\n'
#  '    <link '
#  'href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700"\n'
#  '        rel="stylesheet">\n'
#  '    <link rel="stylesheet" type="text/css" '
#  'href="/flasgger_static/swagger-ui.css">\n'
#  '    <link rel="icon" type="image/png" href="/static/favicon.ico" '
#  'sizes="64x64 32x32 16x16" />\n'
#  '    <style>\n'
#  '        html {\n'
#  '            box-sizing: border-box;\n'
#  '            overflow: -moz-scrollbars-vertical;\n'
#  '            overflow-y: scroll;\n'
#  '        }\n'
#  '\n'
#  '        *,\n'
#  '        *:before,\n'
#  '        *:after {\n'
#  '            box-sizing: inherit;\n'
#  '        }\n'
#  '\n'
#  '        body {\n'
#  '            margin: 0;\n'
#  '            background: #fafafa;\n'
#  '        }\n'
#  '    </style>\n'
#  '</head>\n'
#  '\n'
#  '<body>\n'
#  '    <a href="https://github.com/requests/httpbin" class="github-corner" '
#  'aria-label="View source on Github">\n'
#  '        <svg width="80" height="80" viewBox="0 0 250 250" '
#  'style="fill:#151513; color:#fff; position: absolute; top: 0; border: 0; '
#  'right: 0;"\n'
#  '            aria-hidden="true">\n'
#  '            <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 '
#  'Z"></path>\n'
#  '            <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 '
#  'C122.0,82.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 '
#  'C127.3,80.9 125.5,87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"\n'
#  '                fill="currentColor" style="transform-origin: 130px 106px;" '
#  'class="octo-arm"></path>\n'
#  '            <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,115.4 '
#  'L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 '
#  '143.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 '
#  '171.4,40.1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 '
#  '190.9,65.4 C194.5,69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 '
#  '216.3,84.9 C212.7,93.1 206.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 '
#  '198.3,112.5 C181.9,128.9 168.3,122.5 157.7,114.1 C157.9,116.9 156.7,120.9 '
#  '152.7,124.9 L141.0,136.5 C139.8,137.7 141.6,141.9 141.8,141.8 Z"\n'
#  '                fill="currentColor" class="octo-body"></path>\n'
#  '        </svg>\n'
#  '    </a>\n'
#  '    <svg xmlns="http://www.w3.org/2000/svg" '
#  'xmlns:xlink="http://www.w3.org/1999/xlink" '
#  'style="position:absolute;width:0;height:0">\n'
#  '        <defs>\n'
#  '            <symbol viewBox="0 0 20 20" id="unlocked">\n'
#  '                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 '
#  '2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8H4c-.553 '
#  '0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 '
#  '19 7.1 19h5.8c.549 0 1.428-.139 '
#  '1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 '
#  '15.8 8z"></path>\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="locked">\n'
#  '                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 '
#  '2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 '
#  '1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 '
#  '1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 '
#  '15.8 8zM12 8H8V5.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="close">\n'
#  '                <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L10 '
#  '11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 '
#  '0-1.697l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 '
#  '1.228-.469 1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 '
#  '.469.469.469 1.229 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 '
#  '1.698z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="large-arrow">\n'
#  '                <path d="M13.25 10L6.109 2.58c-.268-.27-.268-.707 '
#  '0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l-7.83 '
#  '7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 20 20" id="large-arrow-down">\n'
#  '                <path d="M17.418 6.109c.272-.268.709-.268.979 0s.271.701 0 '
#  '.969l-7.908 7.83c-.27.268-.707.268-.979 0l-7.908-7.83c-.27-.268-.27-.701 '
#  '0-.969.271-.268.709-.268.979 0L10 13.25l7.418-7.141z"\n'
#  '                />\n'
#  '            </symbol>\n'
#  '\n'
#  '\n'
#  '            <symbol viewBox="0 0 24 24" id="jump-to">\n'
#  '                <path d="M19 7v4H5.83l3.58-3.59L8 6l-6 6 6 6 1.41-1.41L5.83 '
#  '13H21V7z" />\n'
#  '            </symbol>\n'
#  '\n'
#  '            <symbol viewBox="0 0 24 24" id="expand">\n'
#  '                <path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z" />\n'
#  '            </symbol>\n'
#  '\n'
#  '        </defs>\n'
#  '    </svg>\n'
#  '\n'
#  '\n'
#  '    <div id="swagger-ui">\n'
#  '        <div data-reactroot="" class="swagger-ui">\n'
#  '            <div>\n'
#  '                <div class="information-container wrapper">\n'
#  '                    <section class="block col-12">\n'
#  '                        <div class="info">\n'
#  '                            <hgroup class="main">\n'
#  '                                <h2 class="title">httpbin.org\n'
#  '                                    <small>\n'
#  '                                        <pre class="version">0.9.2</pre>\n'
#  '                                    </small>\n'
#  '                                </h2>\n'
#  '                                <pre class="base-url">[ Base URL: '
#  'httpbin.org/ ]</pre>\n'
#  '                            </hgroup>\n'
#  '                            <div class="description">\n'
#  '                                <div class="markdown">\n'
#  '                                    <p>A simple HTTP Request &amp; Response '
#  'Service.\n'
#  '                                        <br>\n'
#  '                                        <br>\n'
#  '                                        <b>Run locally: </b>\n'
#  '                                        <code>$ docker run -p 80:80 '
#  'kennethreitz/httpbin</code>\n'
#  '                                    </p>\n'
#  '                                </div>\n'
#  '                            </div>\n'
#  '                            <div>\n'
#  '                                <div>\n'
#  '                                    <a href="https://kennethreitz.org" '
#  'target="_blank">the developer - Website</a>\n'
#  '                                </div>\n'
#  '                                <a href="mailto:me@kennethreitz.org">Send '
#  'email to the developer</a>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                        <!-- ADDS THE LOADER SPINNER -->\n'
#  '                        <div class="loading-container">\n'
#  '                            <div class="loading"></div>\n'
#  '                        </div>\n'
#  '\n'
#  '                    </section>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '\n'
#  "    <div class='swagger-ui'>\n"
#  '        <div class="wrapper">\n'
#  '            <section class="clear">\n'
#  '                <span style="float: right;">\n'
#  '                    [Powered by\n'
#  '                    <a target="_blank" '
#  'href="https://github.com/rochacbruno/flasgger">Flasgger</a>]\n'
#  '                    <br>\n'
#  '                </span>\n'
#  '            </section>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '    <script src="/flasgger_static/swagger-ui-bundle.js"> </script>\n'
#  '    <script src="/flasgger_static/swagger-ui-standalone-preset.js"> '
#  '</script>\n'
#  "    <script src='/flasgger_static/lib/jquery.min.js' "
#  "type='text/javascript'></script>\n"
#  '    <script>\n'
#  '\n'
#  '        window.onload = function () {\n'
#  '            \n'
#  '\n'
#  '            fetch("/spec.json")\n'
#  '                .then(function (response) {\n'
#  '                    response.json()\n'
#  '                        .then(function (json) {\n'
#  '                            var current_protocol = '
#  'window.location.protocol.slice(0, -1);\n'
#  '                            if (json.schemes[0] != current_protocol) {\n'
#  '                                // Switches scheme to the current in use\n'
#  '                                var other_protocol = json.schemes[0];\n'
#  '                                json.schemes[0] = current_protocol;\n'
#  '                                json.schemes[1] = other_protocol;\n'
#  '\n'
#  '                            }\n'
#  '                            json.host = window.location.host;  // sets the '
#  'current host\n'
#  '\n'
#  '                            const ui = SwaggerUIBundle({\n'
#  '                                spec: json,\n'
#  '                                validatorUrl: null,\n'
#  "                                dom_id: '#swagger-ui',\n"
#  '                                deepLinking: true,\n'
#  '                                jsonEditor: true,\n'
#  '                                docExpansion: "none",\n'
#  '                                apisSorter: "alpha",\n'
#  '                                //operationsSorter: "alpha",\n'
#  '                                presets: [\n'
#  '                                    SwaggerUIBundle.presets.apis,\n'
#  '                                    // yay ES6 modules ↘\n'
#  '                                    Array.isArray(SwaggerUIStandalonePreset) '
#  '? SwaggerUIStandalonePreset : SwaggerUIStandalonePreset.default\n'
#  '                                ],\n'
#  '                                plugins: [\n'
#  '                                    SwaggerUIBundle.plugins.DownloadUrl\n'
#  '                                ],\n'
#  '            \n'
#  '            // layout: "StandaloneLayout"  // uncomment to enable the green '
#  'top header\n'
#  '        })\n'
#  '\n'
#  '        window.ui = ui\n'
#  '\n'
#  '        // uncomment to rename the top brand if layout is enabled\n'
#  '        // $(".topbar-wrapper .link '
#  'span").replaceWith("<span>httpbin</span>");\n'
#  '        })\n'
#  '    })\n'
#  '}\n'
#  "    </script>  <div class='swagger-ui'>\n"
#  '    <div class="wrapper">\n'
#  '        <section class="block col-12 block-desktop col-12-desktop">\n'
#  '            <div>\n'
#  '\n'
#  '                <h2>Other Utilities</h2>\n'
#  '\n'
#  '                <ul>\n'
#  '                    <li>\n'
#  '                        <a href="/forms/post">HTML form</a> that posts to '
#  '/post /forms/post</li>\n'
#  '                </ul>\n'
#  '\n'
#  '                <br />\n'
#  '                <br />\n'
#  '            </div>\n'
#  '        </section>\n'
#  '    </div>\n'
#  '</div>\n'
#  '</body>\n'
#  '\n'
#  '</html>')

# %%
resp.status, resp.reason
# Out:
# (200, 'OK')

# %%
data2 =  resp.read()
pprint(data2.decode('UTF-8'))
# Out:
# ''

# %%
# OPTIONS operations

# Create the request object
import urllib.request
req = urllib.request.Request(bin_url, method='OPTIONS')

# Send the request
resp = urllib.request.urlopen(req)

print(resp.info())
# Out:
# Date: Fri, 06 Mar 2026 04:39:29 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 0
# Connection: close
# Server: gunicorn/19.9.0
# Allow: OPTIONS, HEAD, GET
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Access-Control-Allow-Methods: GET, POST, PUT, DELETE, PATCH, OPTIONS
# Access-Control-Max-Age: 3600

# %%
# POST operation

# Prepare data to post
import urllib.parse
import urllib.request
post_data = urllib.parse.urlencode({"name": "Amit", "city": "Pune"}).encode('ascii')

# Prepare the request
req = urllib.request.Request('https://httpbin.org/post', 
                             method='POST',
                             data=post_data,
                             headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"})

# Send the request
resp = urllib.request.urlopen(req)

print(resp.info())
print(f"\n\n{resp.status}, {resp.reason}")
# Out:
# Date: Fri, 06 Mar 2026 04:39:30 GMT
# Content-Type: application/json
# Content-Length: 492
# Connection: close
# Server: gunicorn/19.9.0
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
#
#
#
#
# 200, OK

# %%
data = resp.read().decode('UTF-8')
pprint(data)
# Out:
# ('{\n'
#  '  "args": {}, \n'
#  '  "data": "", \n'
#  '  "files": {}, \n'
#  '  "form": {\n'
#  '    "city": "Pune", \n'
#  '    "name": "Amit"\n'
#  '  }, \n'
#  '  "headers": {\n'
#  '    "Accept-Encoding": "identity", \n'
#  '    "Content-Length": "19", \n'
#  '    "Content-Type": "application/x-www-form-urlencoded", \n'
#  '    "Host": "httpbin.org", \n'
#  '    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)", \n'
#  '    "X-Amzn-Trace-Id": "Root=1-69aa5a82-4e181a2c025ba85344de1b36"\n'
#  '  }, \n'
#  '  "json": null, \n'
#  '  "origin": "182.70.49.86", \n'
#  '  "url": "https://httpbin.org/post"\n'
#  '}\n')

# %%
# Exception handling for forbidden (403) response
from urllib.error import HTTPError
try:
    with urllib.request.urlopen('https://httpbin.org/status/403') as resp:
        print("Read response -->", resp.read().decode('UTF-8'), resp.status, resp.reason, sep="\n\n")
except HTTPError as ex:
    print(f"{ex!r}")
    print(f"Code: {ex.code}")
    print(f"Reason: {ex.reason}")
print("\n\nDone")
# Out:
# <HTTPError 403: 'FORBIDDEN'>
# Code: 403
# Reason: FORBIDDEN
#
#
# Done

# %%
# Exception handling for URL error
from urllib.error import URLError
from urllib.error import HTTPError
try:
    with urllib.request.urlopen('https://fake-site.com') as resp:
        print("Read response -->", resp.read().decode('UTF-8'), resp.status, resp.reason, sep="\n\n")
except (HTTPError, URLError) as ex:
    print(f"{ex!r}")
    # print(f"Code: {ex.code}")     # URLError doesn't have an attribute called 'code', as it never reached the server
    print(f"Reason: {ex.reason}")
print("\n\nDone")
# Out:
# URLError(TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Reason: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
#
# Done

# %%
# 'urlparse'
parsed_data = urllib.parse.urlparse('http://www.ramakant.in:80/languages/python.html')
parsed_data
# Out:
# ParseResult(scheme='http', netloc='www.ramakant.in:80', path='/languages/python.html', params='', query='', fragment='')

# %%
# With a query subcomponent
parsed_data = urllib.parse.urlparse('http://www.ramakant.in:80/languages/python.html?greeting=hello&person=John')
parsed_data
# Out:
# ParseResult(scheme='http', netloc='www.ramakant.in:80', path='/languages/python.html', params='', query='greeting=hello&person=John', fragment='')

# %%
# With a fragment subcomponent
parsed_data = urllib.parse.urlparse('http://www.ramakant.in:80/languages/python.html#courses')
parsed_data
# Out:
# ParseResult(scheme='http', netloc='www.ramakant.in:80', path='/languages/python.html', params='', query='', fragment='courses')

# %% [markdown]
# #### Using Requests module

# %%
# %pip install requests --upgrade
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ------------------------ --------------- 3/5 [certifi]
#    ---------------------------------------- 5/5 [requests]
#
# Successfully installed certifi-2026.2.25 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
from pprint import pprint

print(requests.__version__)
# Out:
# 2.32.5

# %%
resp = requests.get('https://jsonplaceholder.typicode.com/todos/1')
type(resp)
# Out:
# requests.models.Response

# %%
resp.status_code
# Out:
# 200

# %%
type(resp.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
pprint(resp.headers)
# Out:
# {'Date': 'Fri, 06 Mar 2026 04:56:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'cache-control': 'max-age=43200', 'etag': 'W/"53-hfEnumeNh6YirfjyjaujcOPPT+s"', 'expires': '-1', 'nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'pragma': 'no-cache', 'report-to': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=xuCEC9Dg4diAbCU41dmUDXrs3lU2%2FwfcLr7leLDllHM%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1765824438"}],"max_age":3600}', 'reporting-endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=xuCEC9Dg4diAbCU41dmUDXrs3lU2%2FwfcLr7leLDllHM%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1765824438"', 'Server': 'cloudflare', 'vary': 'Origin, Accept-Encoding', 'via': '2.0 heroku-router', 'x-content-type-options': 'nosniff', 'x-powered-by': 'Express', 'x-ratelimit-limit': '1000', 'x-ratelimit-remaining': '782', 'x-ratelimit-reset': '1765824457', 'Age': '6', 'cf-cache-status': 'HIT', 'Content-Encoding': 'gzip', 'CF-RAY': '9d7ec587bde8e179-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
data = json.loads(resp.text)
pprint(data)
# Out:
# {'completed': False, 'id': 1, 'title': 'delectus aut autem', 'userId': 1}

# %%
wikipedia_search_url = 'https://en.wikipedia.org/w/index.php'
params = {"search": "requests"}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7"
}

resp = requests.get(wikipedia_search_url,
                    params=params,
                    headers=headers,
                    timeout=15)
print(resp.status_code)
print(resp.url)
# Out:
# 200
# https://en.wikipedia.org/wiki/Requests

# %%
post_data = {
    'title': 'some title',
    'body': 'some body',
    'userId': 22
}

resp = requests.post('https://jsonplaceholder.typicode.com/posts', data=post_data)
resp
# Out:
# <Response [201]>

# %%
json.loads(resp.text)
# Out:
# {'title': 'some title', 'body': 'some body', 'userId': '22', 'id': 101}

# %%
resp = requests.get('https://httpbin.org/absolute-redirect/5')
resp
# Out:
# <Response [200]>

# %%
resp.history
# Out:
# [<Response [302]>,
#  <Response [302]>,
#  <Response [302]>,
#  <Response [302]>,
#  <Response [302]>]

# %%
resp.url
# Out:
# 'http://httpbin.org/get'

# %%
def print_response_history(resp):
    if resp.history:
        print("History")
        for r in resp.history:
            print(r.status_code, r.url)

        print("Finally")
        print(resp.status_code, resp.url)
    else:
        print("Request was not redirected.")

# %%
print_response_history(resp)
# Out:
# History
# 302 https://httpbin.org/absolute-redirect/5
# 302 http://httpbin.org/absolute-redirect/4
# 302 http://httpbin.org/absolute-redirect/3
# 302 http://httpbin.org/absolute-redirect/2
# 302 http://httpbin.org/absolute-redirect/1
# Finally
# 200 http://httpbin.org/get

# %%
resp = requests.get('https://httpbin.org/absolute-redirect/5', allow_redirects=False)
print_response_history(resp)
# Out:
# Request was not redirected.

# %%
resp, resp.url
# Out:
# (<Response [302]>, 'https://httpbin.org/absolute-redirect/5')

# %%
requests.get('https://google.com', timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     758 sock: socket.socket | ssl.SSLSocket
# --> 759 self.sock = sock = self._new_conn()
#     760 server_hostname: str = self.host
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except SocketTimeout as e:
# --> 213     raise ConnectTimeoutError(
#     214         self,
#     215         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     216     ) from e
#     218 except OSError as e:
#
# ConnectTimeoutError: (<HTTPSConnection(host='google.com', port=443) at 0x239ff7e4650>, 'Connection to google.com timed out. (connect timeout=0.001)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\urllib3\util\retry.py:535, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     534     reason = error or ResponseError(cause)
# --> 535     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     537 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<HTTPSConnection(host='google.com', port=443) at 0x239ff7e4650>, 'Connection to google.com timed out. (connect timeout=0.001)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 requests.get('https://google.com', timeout=0.001)
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\RSD\Training\20260302_Synchrn_Python\.venv-scraping\Lib\site-packages\requests\adapters.py:665, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     662 if isinstance(e.reason, ConnectTimeoutError):
#     663     # TODO: Remove this in 3.0.0: see #2811
#     664     if not isinstance(e.reason, NewConnectionError):
# --> 665         raise ConnectTimeout(e, request=request)
#     667 if isinstance(e.reason, ResponseError):
#     668     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<HTTPSConnection(host='google.com', port=443) at 0x239ff7e4650>, 'Connection to google.com timed out. (connect timeout=0.001)'))

# %%
requests.get('https://google.com', timeout=2)
# Out:
# <Response [200]>

# %%
requests.get('https://google.com', timeout=None)
# Out:
# <Response [200]>

# %% [markdown]
# ### Parsing with BeautifulSoup

# %%
'''
<html>

    <head>
        <title>Page Title</title>
    </head>

    <body>
        <h1>Page Header</h1>
        <a href="https://www.google.com">Some Link</a>
    </body>

</html>
'''
# Out:
# '\n<html>\n\n    <head>\n        <title>Page Title</title>\n    </head>\n\n    <body>\n        <h1>Page Header</h1>\n        <a href="https://www.google.com">Some Link</a>\n    </body>\n\n</html>\n'

# %%
# %pip install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from BeautifulSoup4)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv-scraping\Lib\site-packages (from BeautifulSoup4) (4.15.0)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, BeautifulSoup4
#
#    -------------------- ------------------- 1/2 [BeautifulSoup4]
#    -------------------- ------------------- 1/2 [BeautifulSoup4]
#    ---------------------------------------- 2/2 [BeautifulSoup4]
#
# Successfully installed BeautifulSoup4-4.14.3 soupsieve-2.8.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Using cached lxml-6.0.2-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Using cached lxml-6.0.2-cp311-cp311-win_amd64.whl (4.0 MB)
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install html5lib
# Out:
# Collecting html5lib
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in .\.venv-scraping\Lib\site-packages (from html5lib) (1.17.0)
# Collecting webencodings (from html5lib)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, html5lib
#
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    ---------------------------------------- 2/2 [html5lib]
#
# Successfully installed html5lib-1.1 webencodings-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
very_simple_html = """
<html>
    <head>
        <title>The Dormouse's story</title>
    </head>

    <body>
    <p class="title">
        <b>The Dormouse's story</b>
    </p>

    <p class="story">
    Once upon a time there were three little sisters; and their names were:

        <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
        <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
        <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;

    and they lived at the bottom of a well.
    </p>

    <p class="story">The story continues</p>
    </body>
</html>
"""

# %%
soup = BeautifulSoup(very_simple_html)

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were:
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
#
#     and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    The story continues
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.body
# Out:
# <body>
# <p class="title">
# <b>The Dormouse's story</b>
# </p>
# <p class="story">
#     Once upon a time there were three little sisters; and their names were:
#
#         <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#         <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#         <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#
#     and they lived at the bottom of a well.
#     </p>
# <p class="story">The story continues</p>
# </body>

# %%
soup.body.name
# Out:
# 'body'

# %%
soup.body.parent.name
# Out:
# 'html'

# %%
soup.p
# Out:
# <p class="title">
# <b>The Dormouse's story</b>
# </p>

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
html = """
    <h1><a /><b><th <td>
"""
soup = BeautifulSoup(html)
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    <a>
#    </a>
#    <b>
#    </b>
#    <th>
#    </th>
#   </h1>
#  </body>
# </html>

# %%
soup = BeautifulSoup(html, 'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    <a>
#    </a>
#    <b>
#    </b>
#    <th>
#    </th>
#   </h1>
#  </body>
# </html>

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <h1>
#  <a>
#  </a>
#  <b>
#   <th <td="">
#   </th>
#  </b>
# </h1>

# %%
soup = BeautifulSoup(html, 'html5lib')
print(soup.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <h1>
#    <a>
#     <b>
#     </b>
#    </a>
#   </h1>
#  </body>
# </html>

# %%
soup = BeautifulSoup(html, 'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    <a>
#    </a>
#    <b>
#    </b>
#    <th>
#    </th>
#   </h1>
#  </body>
# </html>

# %%
soup = BeautifulSoup(html, 'xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <h1>
#  <a/>
#  <b>
#   <th>
#    <td/>
#   </th>
#  </b>
# </h1>

# %%
soup = BeautifulSoup(html, 'lxml-xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <h1>
#  <a/>
#  <b>
#   <th>
#    <td/>
#   </th>
#  </b>
# </h1>

# %%
resp = requests.get('https://google.com')
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){var _g={kEI:'WW2qaeqLI4G75OUPi6q84As',kEXPI:'0,18167,184898,1101138,2699307,236535,48791,46127,344796,301150,5231828,36811390,25381059,65176,39766,75318,23254,37805,28334,48240,31074,7714,6975,26410,3050,2,23178,2864,22727,10371,35966,20680,11883,6437,9742,2646,24246,1481,2,2,13021,1382,2,1,1515,3355,2,1513,2121,2374,2,4205,3,10939,5159,2,874,2231,5089,19,3008,14,781,4081,4,5068,318,25902,1250,5337,311,534,2046,2,12,16,1545,3,5941,1010,1747,4,537,11579,3077,4,2243,537,5,1113,389,4,2647,5,2698,2870,298,6256,2997,1275,7,1784,7,1049,2,1912,4019,6438,2,5724,9,602,96,1553,4,1613,965,2944,1322,3640,1,2,586,241,3,1359,2,4992,10,204,441,158,2,1645,191,4,1928,4,1634,544,4,1568,1033,1399,187,2105,5,259,5,197,1921,445,19,1333,88,119,4,385,1979,2363,5,40,2569,4,3845,4,354,1696,264,107,5,4,970,4,966,5,1125,3,2,46,3704,4,32,4,847,1475,381,4,40,4,1855,255,4,438,323,1,2352,1865,41,5,1,1184,4,14,3,2,1,340,107,4,598,132,5,75,4,1940,4,1432,991,571,1,1091,1,265,4212,1833,733,617,13,179,329,824,2469,8,5,14,57,258,695,8,818,1426,4,281,264,341,222,2915,7,4,2,556,339,2206,5,1722,4,313,1,1088,1333,1913,259,4,945,16,4,463,945,21007086,5,2253,739,4,2960,3,3237,5254,2,1562,3,11871,4193,3,746,6,1149,3,1452,630,780,2716,2,1968,2,643,50,2,6500670,2,1634,1056,25,420,2158529,386367,13782274,4360998,111,590,5,1242,3,1449,880,113,3,12,1,600,4,65,388,2,978,33,4,152,4,75,475,219,3,2,2,2,550,4,2628,5,4247,111,1,2,12,44,2,12,16,362,1343,1,2,665,207,8,297,3,12,1,1171,47,509,4592,5,1161,783,48,206,5,76,87,129,5,142,4,228,359,2139,2,196,349,450,16,170,8,313,926,368,37,177,4,68,2275,261,24,556,1260,5,2,8,713,4,222,14,6,26,1942,4,70,213,321,71,210,126,4,4,2,3,1,3,1,2,2,3,2,1,2,2,2,3,2,2,2,1,3,2,2,1,3,1,2,2,2,3,1,3,1,3,2,1,3,2,1,2,3,1,3,1,2,3,2,9,2,3,2,2,1,11,2,1,3,1,3,10,2,1,2,3,1,11,2,1,3,1,2,3,2,1,2,3,1,3,2,2,1,2,2,3,1,3,2,2,2,2,1,3,1,2,2,3,1,3,2,1,2,3,1,2,2,2,3,2,1,3,2,9,3,1,3,2,2,9,2,2,2,2,2,11,1,3,2,1,3,276,60,140,176,976,355,179,4,117,269,76,243,2,131,1820,8,423,800,4,242,443,1,2,514,3,872,4,132,211,2408,391,2,272,443,1900,9,946,73,65,3,605,3,2,2,2,721,188,3,2,1,8,322,817,249,798,3,366,450,2046,132,335,4,469,76,228,567,409,356,404,46,126,30,291,3,2,2,2,239,4,235,9,215,95,464,199,28,456,561,55,39,73,205,352,267,1083,8,12,568,235,130,4,290,461,586,4,107,2161,4,113,3,2,1,8,758,235,346,397,1853,1144,489,1749,171',kBL:'rLZi',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='en-IN';google.rdn=true;})();(function(){
# var g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function e(a,b,d){if(a)var c=a.id;else{do c=Math.random();while(d[c])}d[c]=[a,b]}var f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.bx=!1;var h;(h=google).lx||(h.lx=function(){});var k=[],l;(l=google).fce||(l.fce=function(a,b,d,c){k.push([a,b,d,c])});google.qce=k;google.adl=[];}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px sans-serif}.gsfs{font:17px sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#1f1f1f}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#ecedee;border:solid 1px;border-color:#d2d2d2 #70757a #70757a #d2d2d2;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#1f1f1f;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){window.google.erd={jsr:1,bv:2391,de:true,dpf:'s5dCBUskJYMN-mJadlUYRdT0lBdik4ododPE6b9wQM4',c:'393c'};
# var f=this||self;var k,l=(k=f.mei)!=null?k:1,m,p=(m=f.diel)!=null?m:0,q,r=(q=f.sdo)!=null?q:!0,t=0,u,v=google.erd,w=v.jsr;google.ml=function(a,b,d,n,e){e=e===void 0?2:e;b&&(u=a&&a.message);d===void 0&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d,!0),null;b=d;if(w<0){window.console&&console.error(a,b);if(w===-2)throw a;b=!1}else b=!a||!a.message||a.message==="Error loading script"||t>=l&&!n?!1:!0;if(!b)return null;t++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(v.jsr)+
# "&bver="+b(v.bv);v.dpf&&(c+="&dpf="+b(v.dpf));var g=a.lineNumber;g!==void 0&&(c+="&line="+g);var h=a.fileName;h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),g&&h===window.location.href&&(g=document.documentElement.outerHTML.split("\n")[g],c+="&cad="+b(g?g.substring(0,300):"No script found.")));google.ple&&google.ple===1&&(e=2);d&&v.c&&(d.ofc=String(v.c));c=c+("&jsel="+e)+"&ectx="+b(JSON.stringify(d));c+="&emsg=";c+=b(a.name+": "+a.message);c+="&jsst=";c+=b(a.stack||"N/A");c.length>=12288&&
# (c=c.substring(0,12288));a=c;n||google.log(0,"",a);return a};window.onerror=function(a,b,d,n,e){u!==a&&(a=e instanceof Error?e:Error(a),d===void 0||"lineNumber"in a||(a.lineNumber=d),b===void 0||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="SyntaxError"||a.message.indexOf("Script error")!==-1?3:p));u=null;r&&t>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id="gbar"><nobr><b class="gb1">Search</b> <a class="gb1" href="https://www.google.com/imghp?hl=en&amp;tab=wi">Images</a> <a class="gb1" href="https://maps.google.co.in/maps?hl=en&amp;tab=wl">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a> <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/?tab=wn">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a> <a class="gb1" href="https://www.google.co.in/intl/en/about/products?tab=wh" style="text-decoration:none"><u>More</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span class="gbi" id="gbn"></span><span class="gbf" id="gbf"></span><span id="gbe"></span><a class="gb4" href="http://www.google.co.in/history/optout?hl=en">Web History</a> | <a class="gb4" href="/preferences?hl=en">Settings</a> | <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=en&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">Sign in</a></nobr></div><div class="gbh" style="left:0"></div><div class="gbh" style="right:0"></div></div><center><br clear="all" id="lgpd"/><div><img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/><br/><br/></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%"> </td><td align="center" nowrap=""><input name="ie" type="hidden" value="ISO-8859-1"/><input name="hl" type="hidden" value="en-IN"/><input name="source" type="hidden" value="hp"/><input name="biw" type="hidden"/><input name="bih" type="hidden"/><div class="ds" style="height:32px;margin:4px 0"><input autocomplete="off" class="lst" maxlength="2048" name="q" size="57" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#1f1f1f" title="Google Search" value=""/></div><br style="line-height:0"/><span class="ds"><span class="lsbb"><input class="lsb" name="btnG" type="submit" value="Google Search"/></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_WW2qaeqLI4G75OUPi6q84As_1" name="btnI" type="submit" value="I'm Feeling Lucky"/><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){var id='tsuid_WW2qaeqLI4G75OUPi6q84As_1';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input name="iflsig" type="hidden" value="AFdpzrgAAAAAaap7adDNmjf4Xk4hYWLtsxmoprH-K5xM"/></span></span></td><td align="left" class="fl sblc" nowrap="" width="25%"><a href="/advanced_search?hl=en-IN&amp;authuser=0">Advanced search</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"/><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){var a,b="1";if(document&&document.getElementById)if(typeof XMLHttpRequest!="undefined")b="2";else if(typeof ActiveXObject!="undefined"){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.search.indexOf("&gbv=2")==-1){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div style="font-size:83%;min-height:3.5em"><br/><div id="gws-output-pages-elements-homepage_additional_languages__als"><style>#gws-output-pages-elements-homepage_additional_languages__als{font-size:small;margin-bottom:24px}#SIvCob{color:#545454;display:inline-block;line-height:28px;}#SIvCob a{}.H6sW5{display:inline-block;margin:0 2px;white-space:nowrap}.z4hgWe{display:inline-block;margin:0 2px}</style><div id="SIvCob">Google offered in:  <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=hi&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAY">हिन्दी</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=bn&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAc">বাংলা</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=te&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAg">తెలుగు</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=mr&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAk">मराठी</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=ta&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAo">தமிழ்</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=gu&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAs">ગુજરાતી</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=kn&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCAw">ಕನ್ನಡ</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=ml&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCA0">മലയാളം</a> <a href="https://www.google.com/setprefs?sig=0_yMeRsScDkOnwGYKiyVMcxVMZYPM%3D&amp;hl=pa&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwiqnLCYzIqTAxWBHbkGHQsVD7wQ2ZgBCA4">ਪੰਜਾਬੀ</a> </div></div></div><span id="footer"><div style="font-size:10pt"><div id="WqQANb" style="margin:19px auto;text-align:center"><a href="/intl/en/ads/">Advertising</a><a href="http://www.google.co.in/services/">Business Solutions</a><a href="/intl/en/about.html">About Google</a><a href="https://www.google.com/setprefdomain?prefdom=IN&amp;prev=https://www.google.co.in/&amp;sig=K_oEsMEthuaBmBquVe7_5m9kAgVMw%3D">Google.co.in</a></div></div><p style="font-size:8pt;color:#636363">© 2026 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="JK3pEYyAJQ-OXIPgl5gysg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.google&&window.google.kOPI||null;k&&(h+="&opi="+k) ...
# var f=this||self;function g(){var a=google.ia&&google.ia.r.B2Jtyd;return a&&[1,5,6].indexOf(a.m)>=0&&a.cbfd&&a.cbvi?a:void 0};function h(a){var b=document.createElement("link");b.as="script";b.href=a;b.rel="preload";document.body.appendChild(b)}function k(){var a=[l];google.dp||(a.forEach(h),google.dp=!0)};google.ps=google.ps||[];function m(a){return a?(a=a.match(/[/?&]ccb=([^/&?#]+)/))?a[1]:null:null}function p(a){var b=l,c=function(){};google.lx=google.stvsc?c:function(){q(b,a&&raf,a&&lfpp);google.lx=c};google.bx||google.lx()}function r(a,b){b&&(a.src=b);if(!m(a.src)){var c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(e){return a.src!==e})}}google.ps.push(a.src);document.body.appendChild(a)}
# function t(a,b,c,d){c&&(a.fetchPriority="low");b?requestAnimationFrame(function(){r(a,d)}):r(a,d)}google.as=r;function q(a,b,c){google.tick&&google.tick("load","xjsls");var d=document.createElement("script");d.onerror=function(){google.ple=1};d.onload=function(){google.ple=0};google.xjsus=void 0;t(d,b,c,a);google.aple=-1;google.dp=!0};function w(){for(var a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var d=a[b],e;if(e=d.hasAttribute("data-lzy_")&&Number(d.getAttribute("data-atf"))&1)e=d.getAttribute("jscontroller"),e=!((e==="UBXHI"||e==="R3fhkb"||e==="TSZEqd")&&d.hasAttribute("data-src"));if(e)return!0}return!1};var l,x,y,z,A,B,C,D,E,F,G="";function H(){l=pxp&&google.xjsup||u;var a=l.match(/\/cb=(loaded_h_\d+)/);a&&a[1]&&(G=a[1]);google.xjsu=l;f._F_jsUrl=l;B=function(c){p(c)};x=!1;y=(st===1||st===3)&&!!google.caft&&!w();z=g();A=!G&&(st===2||st===3)&&!!z&&!w();if(G){var b=(st===2||st===3)&&!!z;f[G]=function(c){var d=!1,e=function(){d||(d=!0,cst?setTimeout(function(){return void c.call(window,window._)},0):c.call(window,window._))};b&&google.ia.adls?(z.cbvi.push(function(){delete google.ia.adls}),z.cbvi.push(e),setTimeout(e,mmd)):e()}}C=
# pop;D=povp;E=C&&document.prerendering||D&&document.hidden;F=D?"visibilitychange":"prerenderingchange"}function I(a){x||y||A||E||(B(a),x=!0)}
# setTimeout(function(){google.tick&&google.tick("load","xjspls");H();if(y||A||E){if(y){var a=function(){y=!1;I()};google.caft(a);setTimeout(a,amd)}A&&(a=function(){A=!1;I()},z.cbvi.push(a),setTimeout(a,mmd));if(E){var b=function(){(D?document.hidden:document.prerendering)||(E=!1,I(!D),document.removeEventListener(F,b))};document.addEventListener(F,b,{passive:!0})}x||k()}else B()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;window.loaded_h_0 = function(cb){cb.call(window,window._);};(function(){var t=[512,0,2048,0,0,0,524288,268697600,24768,4,65536,69206016,33108032,369623042,16777793,4224,2164235,8388612,0,128,32772,499384320,4,4194304,2225,0,138752];window._F_toggles = window._xjs_toggles = t;})();window._F_installCss = window._F_installCss || function(css){};(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Clear Search\x22,\x22dym\x22:\x22Did you mean:\x22,\x22lcky\x22:\x22I\\u0026#39;m Feeling Lucky\x22,\x22lml\x22:\x22Learn more\x22,\x22psrc\x22:\x22This search was removed from your \\u003Ca href\x3d\\\x22/history\\\x22\\u003EWeb History\\u003C/a\\u003E\x22,\x22psrl\x22:\x22Remove\x22,\x22sbit\x22:\x22Search by image\x22,\x22srch\x22:\x22Google Search\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22stok\x22:\x22Fegz-rGATFkTtf55C3FeGgZOgHA\x22}}';google.pmc=JSON.parse(pmc);})();</script></body></html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Giant Panda Example
with open('files/GiantPanda.html') as html_code:
    soup = BeautifulSoup(html_code)
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    "Giant Panda"
#   </title>
#  </head>
#  <body>
#   <h1>
#    The giant panda also known as panda bear or simply panda
#   </h1>
#   <h2 style="color:blue;">
#    Giant Panda
#   </h2>
#   <h3 style="background-color:yellow;color:red;">
#    The name "giant panda" is sometimes used to distinguish it from the
#    <br/>
#    red panda.
#   </h3>
#   <h6>
#    The giant panda lives in a few mountain ranges in central China
#   </h6>
#   <b class="panda">
#    pandas were thought to be rare and noble creatures
#   </b>
#   <div>
#    <a href="https://en.wikipedia.org/wiki/Giant_panda">
#     Link to Wikipedia page
#    </a>
#   </div>
#   <br/>
#   <br/>
#   <i>
#    <!--Here is a Panda image from Wikipedia -->
#   </i>
#   <div>
#    <img alt="panda not found" src="Panda.jpeg"/>
#   </div>
#   <div>
#    <p class="panda highlight">
#     Giant pandas in the wild will occasionally eat other grasses, wild tubers, or even meat in the form of birds
#    </p>
#   </div>
#  </body>
# </html>

# %%
tag = soup.title
tag
# Out:
# <title>"Giant Panda"</title>

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.h1
tag
# Out:
# <h1>The giant panda also known as panda bear or simply panda</h1>

# %%
tag.name
# Out:
# 'h1'

# %%
tag.name = 'user_defined'
tag.name
# Out:
# 'user_defined'

# %%
tag
# Out:
# <user_defined>The giant panda also known as panda bear or simply panda</user_defined>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    "Giant Panda"
#   </title>
#  </head>
#  <body>
#   <user_defined>
#    The giant panda also known as panda bear or simply panda
#   </user_defined>
#   <h2 style="color:blue;">
#    Giant Panda
#   </h2>
#   <h3 style="background-color:yellow;color:red;">
#    The name "giant panda" is sometimes used to distinguish it from the
#    <br/>
#    red panda.
#   </h3>
#   <h6>
#    The giant panda lives in a few mountain ranges in central China
#   </h6>
#   <b class="panda">
#    pandas were thought to be rare and noble creatures
#   </b>
#   <div>
#    <a href="https://en.wikipedia.org/wiki/Giant_panda">
#     Link to Wikipedia page
#    </a>
#   </div>
#   <br/>
#   <br/>
#   <i>
#    <!--Here is a Panda image from Wikipedia -->
#   </i>
#   <div>
#    <img alt="panda not found" src="Panda.jpeg"/>
#   </div>
#   <div>
#    <p class="panda highlight">
#     Giant pandas in the wild will occasionally eat other grasses, wild tubers, or even meat in the form of birds
#    </p>
#   </div>
#  </body>
# </html>

# %%
tag = soup.a
tag
# Out:
# <a href="https://en.wikipedia.org/wiki/Giant_panda"> Link to Wikipedia page </a>

# %%
tag["href"]
# Out:
# 'https://en.wikipedia.org/wiki/Giant_panda'

# %%
tag.attrs
# Out:
# {'href': 'https://en.wikipedia.org/wiki/Giant_panda'}

# %%
tag = soup.img
tag
# Out:
# <img alt="panda not found" src="Panda.jpeg"/>

# %%
tag.attrs
# Out:
# {'src': 'Panda.jpeg', 'alt': 'panda not found'}

# %%
tag = soup.b
tag
# Out:
# <b class="panda">pandas were thought to be rare and noble creatures</b>

# %%
tag.attrs
# Out:
# {'class': ['panda']}

# %%
tag["class"]
# Out:
# ['panda']

# %%
tag = soup.p
tag
# Out:
# <p class="panda highlight">Giant pandas in the wild will occasionally eat other grasses, wild tubers, or even meat in the form of birds</p>

# %%
tag["class"]
# Out:
# ['panda', 'highlight']

# %%
type(tag.string), tag.string
# Out:
# (bs4.element.NavigableString,
#  'Giant pandas in the wild will occasionally eat other grasses, wild tubers, or even meat in the form of birds')

# %%
comment = soup.i
comment
# Out:
# <i><!--Here is a Panda image from Wikipedia --></i>

# %%
import re

# %%
with open('files/TomJerry_Story.html') as html_code:
    soup = BeautifulSoup(html_code)
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The story of Tom and Jerry
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     Tom and Jerry
#    </b>
#   </p>
#   <img alt="cartoon_image" height="300" src="TomAndJerry.jpg" width="300"/>
#   <p class="comedy animated series">
#    Tom and Jerry is an American animated series of comedy short films created by
#    <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">
#     William_Hanna
#    </a>
#    and
#    <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">
#     Joseph Barbera
#    </a>
#    .
#         It centers on a rivalry between the title characters
#    <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">
#     Tom
#    </a>
#    , a cat, and
#    <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">
#     Jerry
#    </a>
#    , a mouse.
#   </p>
#   <p class="comedy story">
#    The series features comic fights between an iconic pair of adversaries,
#             a house cat (Tom) and a mouse (Jerry). The plots of each short usually center on Tom's
#             numerous attempts to capture Jerry and the mayhem and destruction that follows.
#             Tom rarely succeeds in catching Jerry, mainly because of Jerry's cleverness,
#             cunning abilities, and luck.
#   </p>
#  </body>
# </html>

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>Tom and Jerry</b></p>
# <img alt="cartoon_image" height="300" src="TomAndJerry.jpg" width="300"/>
# <p class="comedy animated series">
#         Tom and Jerry is an American animated series of comedy short films created by
#         <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a> and
#         <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>.
#         It centers on a rivalry between the title characters
#         <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>, a cat, and
#         <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>, a mouse.</p>
# <p class="comedy story">
#             The series features comic fights between an iconic pair of adversaries,
#             a house cat (Tom) and a mouse (Jerry). The plots of each short usually center on Tom's
#             numerous attempts to capture Jerry and the mayhem and destruction that follows.
#             Tom rarely succeeds in catching Jerry, mainly because of Jerry's cleverness,
#             cunning abilities, and luck.
#         </p>
# </body>

# %%
soup.p
# Out:
# <p class="title"><b>Tom and Jerry</b></p>

# %%
soup.find('p')
# Out:
# <p class="title"><b>Tom and Jerry</b></p>

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>Tom and Jerry</b></p>,
#  <p class="comedy animated series">
#          Tom and Jerry is an American animated series of comedy short films created by
#          <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a> and
#          <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>.
#          It centers on a rivalry between the title characters
#          <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>, a cat, and
#          <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>, a mouse.</p>,
#  <p class="comedy story">
#              The series features comic fights between an iconic pair of adversaries,
#              a house cat (Tom) and a mouse (Jerry). The plots of each short usually center on Tom's
#              numerous attempts to capture Jerry and the mayhem and destruction that follows.
#              Tom rarely succeeds in catching Jerry, mainly because of Jerry's cleverness,
#              cunning abilities, and luck.
#          </p>]

# %%
soup.find('title')
# Out:
# <title> The story of Tom and Jerry </title>

# %%
soup.find_all('title')
# Out:
# [<title> The story of Tom and Jerry </title>]

# %%
print(soup.find('span'))
# Out:
# None

# %%
soup.find_all(src='TomAndJerry.jpg')
# Out:
# [<img alt="cartoon_image" height="300" src="TomAndJerry.jpg" width="300"/>]

# %%
soup.find(re.compile("^a"))
# Out:
# <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>

# %%
soup.find_all(re.compile("^a"))
# Out:
# [<a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>,
#  <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>,
#  <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>,
#  <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>]

# %%
for tag in soup.find_all(re.compile("^t")):
    print(tag.name)
# Out:
# title

# %%
# 'a' tags
# Have the class attribute assigned
# attribute value starts with 'cre'
for tag in soup.find_all('a', attrs={'class': re.compile("^cre")}):
    print(tag)
# Out:
# <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>
# <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>

# %%
for tag in soup.find_all('a', attrs={'class': re.compile("^cre")}):
    print(tag.text)
# Out:
# William_Hanna
# Joseph Barbera

# %%
for tag in soup.find_all('a', attrs={'class': re.compile("r")}):
    print(tag)
# Out:
# <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>
# <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>
# <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>
# <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>

# %%
for tag in soup.find_all(id=re.compile('link')):
    print(tag)
# Out:
# <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>
# <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>
# <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>
# <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>

# %%
soup.find_all(['a', 'img'])
# Out:
# [<img alt="cartoon_image" height="300" src="TomAndJerry.jpg" width="300"/>,
#  <a class="creator" href="https://en.wikipedia.org/wiki/William_Hanna" id="link1">William_Hanna</a>,
#  <a class="creator" href="https://en.wikipedia.org/wiki/Joseph_Barbera" id="link2">Joseph Barbera</a>,
#  <a class="character" href="https://en.wikipedia.org/wiki/Tom_Cat" id="link3">Tom</a>,
#  <a class="character" href="https://en.wikipedia.org/wiki/Jerry_Mouse" id="link4">Jerry</a>]

# %%
for tag in soup.find_all(True):
    print(tag.name)
# Out:
# html
# head
# title
# body
# p
# b
# img
# p
# a
# a
# a
# a
# p

# %%
#Define a filter function
def has_src_but_no_href(tag):
    return tag.has_attr('src') and not tag.has_attr('href')

# %%
soup.find_all(has_src_but_no_href)
# Out:
# [<img alt="cartoon_image" height="300" src="TomAndJerry.jpg" width="300"/>]

# %% [markdown]
# ##### Extracting Links

# %%
url = "https://mashable.com/2014/08/28/static-website-generators/"
resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>13 Static Site Generators to Help You Build Your Ultimate Website | Mashable</title>
# <meta charset="utf-8"/>
# <link href="https://mashable.com/archive/static-website-generators" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#00aeef" name="theme-color"/>
# <meta content="Mashable.com" name="application-name"/>
# <meta content="13 Static Site Generators to Help You Build Your Ultimate Website" name="description"/>
# <meta content="noindex" name="robots"/>
# <meta content="122071082108" property="fb:app_id"/>
# <meta content="18807449704" property="fb:pages"/>
# <meta content="Mashable" property="og:site_name"/>
# <meta content="13 Static Site Generators to Help You Build Your Ultimate Website" property="og:title"/>
# <meta content="https://mashable.com/archive/static-website-generators" property="og:url"/>
# <meta content="13 Static Site Generators to Help You Build Your Ultimate Website" property="og:description"/>
# <meta content="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1200x675.v1647024413.jpg" property="og:image"/>
# <meta content="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1200x675.v1647024413.jpg" property="og:image:secure_url"/>
# <meta content="675" property="og:image:height"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="article" property="og:type"/>
# <meta content="Grace Smith" property="article:author"/>
# <meta content="2014-08-28T11:15:22+00:00" property="article:published_time"/>
# <meta content="@mashable" name="twitter:site"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="@mashable" property="twitter:creator"/>
# <meta content="13 Static Site Generators to Help You Build Your Ultimate Website" property="twitter:title"/>
# <meta content="13 Static Site Generators to Help You Build Your Ultimate Website" property="twitter:description"/>
# <meta content="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1200x675.v1647024413.jpg" property="twitter:image"/>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://mashable.com/feeds/rss/all" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://mashable.com/archive/static-website-generators" hreflang="en" rel="alternate"/>
# <link href="https://mashable.com/archive/static-website-generators" hreflang="en-us" rel="alternate"/>
# <link href="https://mashable.com/archive/static-website-generators" hreflang="x-default" rel="alternate"/>
# <link href="/favicons/favicon.svg" rel="shortcut icon mask-icon"/>
# <link href="/favicons/favicon-16x16.jpg" rel="icon" sizes="16x16" type="image/jpg"/>
# <link href="/favicons/favicon-32x32.jpg" rel="icon" sizes="32x32" type="image/jpg"/>
# <link href="/favicons/apple-touch-icon.jpg" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicons/android-chrome-192x192.jpg" rel="icon" sizes="192x192" type="image/jpg"/>
# <link href="/favicons/android-chrome-512x512.jpg" rel="icon" sizes="512x512" type="image/jpg"/>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Organization","url":"https:\/\/mashable.com\/","name":"Mashable","logo":{"@type":"ImageObject","url":"https:\/\/mashable.com\/images\/mashable-logomark.png","width":2400,"height":2400},"sameAs":["https:\/\/www.facebook.com\/mashable\/","https:\/\/twitter.com\/mashable","https:\/\/flipboard.com\/@Mashable","https:\/\/www.pinterest.com\/mashable\/","https:\/\/www.youtube.com\/user\/mashable"],"description":"Mashable is a global, multi-platform media and entertainment company.\n            Powered by its own proprietary technology, Mashable is the go-to source for tech,\n             digital culture and entertainment content for its dedicated and influential audience around the globe.","publishingPrinciples":"https:\/\/mashable.com\/about\/editorial-standards"}</script> <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https:\/\/mashable.com"}]}</script>
# <link href="//cdn.ziffstatic.com" rel="preconnect"/>
# <link href="//www.googletagmanager.com" rel="preconnect"/>
# <link as="style" href="/css/app.css?id=1bff3381604084f07ec829d409d2802c" rel="preload"/>
# <link as="font" crossorigin="" href="/fonts/Outfit.woff2" rel="preload" type="font/woff2"/>
# <link as="image" imagesizes="(max-width: 1280px) 100vw, 1280px" imagesrcset="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_400x225.v1647024413.jpg 400w, https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_800x450.v1647024413.jpg 800w, https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1248x702.v1647024413.jpg 1600w" rel="preload"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# <link href="/css/app.css?id=1bff3381604084f07ec829d409d2802c" rel="stylesheet"/>
# <link as="script" href="https://g.mashable.com/mashable.js?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators" rel="preload"/>
# <script defer="" src="https://g.mashable.com/mashable.js?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators" type="text/javascript"></script>
# <link as="image" href="/images/icons/spritemap.svg" rel="preload"/>
# <link as="script" href="https://cdn.ziffstatic.com/jst/zdconsent.js" rel="preload"/>
# <script type="text/javascript">window.zdconsent = window.zdconsent || {run:[],cmd:[],useractioncomplete:[],analytics:[],functional:[],social:[]};</script>
# <script async="true" fetchpriority="high" id="zdconsent" src="https://cdn.ziffstatic.com/jst/zdconsent.js" type="text/javascript"></script>
# <script>window.zdconsent.run.push("https://cdn.static.zdbb.net/js/z0WVjCBSEeGLoxIxOQVEwQ.min.js")</script>
# <script src="/js/ga-session.js?id=a369edb1387d56de7a50d35b4d472e18"></script>
# <script>
#     // Session UUID logic using sessionStorage
#     function storageAvailable(type) {
#         try {
#             var storage = window[type],
#                 x = '__storage_test__';
#             storage.setItem(x, x);
#             storage.removeItem(x);
#             return true;
#         } catch (e) {
#             return false;
#         }
#     }
#     // Global UUID v4 generator function
#     window.generateUUIDv4 = function() {
#         // RFC4122 version 4 compliant UUID
#         return 'xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx'.replace(/[xy]/g, function(c) {
#             var r = Math.random() * 16 | 0,
#                 v = c === 'x' ? r : (r & 0x3 | 0x8);
#             return v.toString(16);
#         });
#     };
#
#     // Generate view_instance_uuid for every page view
#     window.viewInstanceUuid = window.generateUUIDv4();
#
#     let sessionUuidKey = 'session_uuid';
#     let sessionUuid = null;
#     if (storageAvailable('sessionStorage')) {
#         sessionUuid = sessionStorage.getItem(sessionUuidKey);
#         if (!sessionUuid) {
#             sessionUuid = window.generateUUIDv4();
#             sessionStorage.setItem(sessionUuidKey, sessionUuid);
#         }
#     } else {
#         // fallback: generate a new UUID for this page load
#         sessionUuid = window.generateUUIDv4();
#     }
#     window.sessionUuid = sessionUuid;
# </script>
# <script>window.zdconsent.run.push("https://www.googletagmanager.com/gtag/js?id=G-BPBF083TYP");</script>
# <script>
#     window.globalGAInfo = {"page_view_type":"Standard","is_seamless_page":false,"template":"article","content_type":"article","split_test_identifier":null,"split_test_variant":null,"object_uuid":"00s0gVKdAC9EPTZERS7TvPb","object_type":"archive","title":"13 Static Site Generators to Help You Build Your Ultimate Website","canonical_url":"https:\/\/mashable.com\/archive\/static-website-generators","full_published_date":"08\/28\/2014","original_published_date":"08\/28\/2014","story_flags":"","content_source_name":"Internal","video_show_name":"","content_source_type":"Internal","author_name":"Grace Smith","day_published":28,"month_published":8,"year_published":2014,"days_since_updated":4207,"weeks_since_updated":601,"days_since_originally_published":4207,"weeks_since_originally_published":601,"categories":"","sections":"","tags":"","post_lead_type":null};
#     window.globalGAInfo.page_path = window.location.pathname;
#     window.dataLayer = window.dataLayer || [];
#     window.globalGAInfo.ad_block = window.adBlock ? 'Blocked' : 'NotBlocked';
#
#     if (!window.gtag) { window.gtag = function() { dataLayer.push(arguments); }}
#     window.zdconsent.run.push(function() {
#         window.gtag('js', new Date());
#         window.gtag('config', 'G-BPBF083TYP',{
#             'send_page_view': false,
#             'session': cookies.get('session'),
#             session_uuid: window.sessionUuid,
#             view_instance_uuid: window.viewInstanceUuid,
#             template: window.globalGAInfo.template || null,
#             split_test_identifier: window.globalGAInfo.split_test_identifier || null,
#             split_test_variant: window.globalGAInfo.split_test_variant || null,
#             ad_block: window.adBlock ? 'Blocked' : 'NotBlocked',
#         });
#
#         window.addEventListener("adblock", function() {
#             window.globalGAInfo.ad_block = 'Blocked';
#             window.zdconsent.run.push(function() {
#                 window.gtag('config', 'G-BPBF083TYP', {
#                     ad_block: 'Blocked',
#                     update: true,
#                 });
#             })
#         });
#
#         if (typeof window._ziffIntlGeoRedirect === 'undefined') {
#             if(window.globalGAInfo.template === 'article' || window.globalGAInfo.template === 'deals' || window.globalGAInfo.template === 'comparison' || window.globalGAInfo.template === 'longform' || window.globalGAInfo.template === 'viral_video' || window.globalGAInfo.template === 'review' || window.globalGAInfo.template === 'roundup' || window.globalGAInfo.template === 'video' || window.globalGAInfo.template === 'gift_guide' || window.globalGAInfo.template === 'live_blog') {
#                 let gtagAnalytics = {
#                     ad_block: window.globalGAInfo.ad_block || 'NotBlocked',
#                     author: window.globalGAInfo.author_name || null,
#                     categories: window.globalGAInfo.categories || null,
#                     channel_name: window.globalGAInfo.channel_name || null,
#                     content_lead_type: window.globalGAInfo.post_lead_type || null,
#                     content_source_name: window.globalGAInfo.content_source_name || null,
#                     content_source_type: window.globalGAInfo.content_source_type || null,
#                     day_published: window.globalGAInfo.day_published || null,
#                     days_since_originally_published: window.globalGAInfo.days_since_originally_published || null,
#                     days_since_updated: window.globalGAInfo.days_since_updated || null,
#                     first_published_at: window.globalGAInfo.original_published_date || null,
#                     focus_keyword: window.globalGAInfo.focus_keyword || null,
#                     job_function: window.globalGAInfo.job_function || null,
#                     level_of_effort: window.globalGAInfo.level_of_effort || null,
#                     linked_phrases: window.linked_phrases || null,
#                     month_published: window.globalGAInfo.month_published || null,
#                     object_type: window.globalGAInfo.object_type || null,
#                     object_uuid: window.globalGAInfo.object_uuid || null,
#                     pageview_type: window.globalGAInfo.page_view_type || null,
#                     published_at: window.globalGAInfo.full_published_date || null,
#                     revenue_page_type: window.globalGAInfo.revenue_page_type || null,
#                     story_flags: window.globalGAInfo.story_flags || null,
#                     tags: window.globalGAInfo.tags || null,
#                     video_show_name: window.globalGAInfo.video_show_name || null,
#                     weeks_since_originally_published: window.globalGAInfo.weeks_since_originally_published || null,
#                     weeks_since_updated: window.globalGAInfo.weeks_since_updated || null,
#                     year_published: window.globalGAInfo.year_published || null,
#                 }
#
#                 window.zdconsent.run.push(function() {
#                     window.gtag('event', 'page_view', gtagAnalytics);
#                 })
#             }
#             else {
#                 window.zdconsent.run.push(function() {
#                     window.gtag('event', 'page_view');
#                 })
#             }
#         }
#     });
# </script>
# <script>
#     window.zdconsent.run.push(function() {
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MN78SWW');
#     });
# </script>
# <script type="text/javascript">
#     (function() {
#         window.zdconsent.run.push(function() {
#             let sections = '';
#             if (window.globalGAInfo.sections) {
#                 sections = window.globalGAInfo.sections.split(',').map(item => 'Category - ' + item.trim()).join(',');
#             }
#             //Adding tags into sections with "Tag - " prefix for chartbeat reporting
#             if (window.globalGAInfo.tags) {
#                 sections += (sections !== '' ? ',' : '') + window.globalGAInfo.tags.split(',').map(item => 'Tag - ' + item.trim()).join(',');
#             }
#             if (window.globalGAInfo.content_type) {
#                 sections += (sections !== '' ? ',' : '') + 'Content Type - ' + window.globalGAInfo.content_type;
#             }
#             var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#             /** CONFIGURATION START **/
#             _sf_async_config.uid = 65789;
#             _sf_async_config.domain = 'mashable.com';
#             _sf_async_config.useCanonical = true;
#             _sf_async_config.useCanonicalDomain = true;
#             _sf_async_config.sections = sections;
#             _sf_async_config.authors = window.globalGAInfo.author_name || '';
#             _sf_async_config.type = window.globalGAInfo.content_type || '';
#                         window.zdconsent.run.push("https://static.chartbeat.com/js/chartbeat_video.js");
#         });
#     })();
# </script>
# <script async="" id="pogo" src="https://cdn.ziffstatic.com/pg/mashable.js" type="text/javascript"></script>
# <link as="script" href="https://cdn.ziffstatic.com/pg/mashable.js" rel="preload"/>
# <link as="script" href="https://cdn.ziffstatic.com/pg/mashable.prebid.js" rel="preload"/>
# <link as="style" href="https://cdn.ziffstatic.com/pg/mashable.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="script" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload"/>
# <script>
#     window.PogoConfig =
#     {
#                     "template": "article",
#                             }
# </script>
# <script>
#     window.FIREBASE_CONFIG = {"api_key":"AIzaSyDMOkepbxXuEltyC8v_FIKbBmjEU7HgM_s","auth_domain":"cng-iterable.firebaseapp.com","project_id":"cng-iterable","storage_bucket":"cng-iterable.firebasestorage.app","messaging_sender_id":"845516706668","app_id":"1:845516706668:web:e4298e07ce26aab023d949","measurement_id":"G-8K8EHE9JSK","vapid_key":"BEK-EUUPmJQTBXTmgLDk5wNIj3J5KH37rz1VJ-GA9DHgTK69O4__0oe2KnBtqrK0qlkXd_HFR14xk-EpwXkOhI4"};
#     window.CNG_PUSH = {
#         isLocal: false,
#         promptDelayMs: 30000    };
# </script>
# <script src="/iterable/push-consent.js" type="module"></script>
# <script src="/iterable/push-notify.js" type="module"></script>
# <style>
#             * .pogoPgWrap {
#                 transition: all .01s ease;
#             }
#
#             @font-face{font-display:optional;font-family:outfit;font-weight:100 800;src:url(/fonts/Outfit.woff2) format("woff2")}
#
#         </style>
# </head>
# <body class="">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MN78SWW" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <nav class="top-0 z-30 py-3 w-full bg-white border-b-2 border-primary-400" data-ga-module="global_nav" x-data="{navOpen: false}">
# <div class="flex relative justify-between items-center px-4 pl-3 mx-auto max-w-8xl">
# <button true=""> $refs.firstMenuItem.focus());" class="flex-shrink px-2 nav-button" aria-label="Menu"&gt;
#             <svg class="inline-block w-7 h-7 fill-current"><use href="/images/icons/spritemap.svg#sprite-hamburger"></use></svg>
# </button>
# <a aria-label="Home" class="flex items-center mr-8 w-full xl:w-auto" data-ga-action="navigation_logo" data-ga-click="" data-ga-element="navigation_logo" data-ga-item="logo" href="https://mashable.com">
# <div x-data="{animate: false, reverse: false}" x-init="setTimeout(() =&gt; animate = true, 1000)">
# <svg :class="{ 'animate': animate, 'animate-reverse': reverse }" class="inline-block -mb-3 w-40 h-11 fill-current hover:fill-secondary-100" id="mashable-wordmark-animated" shape-rendering="geometricPrecision" text-rendering="geometricPrecision" viewbox="0 0 2200 650" x-ref="wordmark" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><style><![CDATA[.animate #euSMf1FbiNs11_to{animation:euSMf1FbiNs11_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs11_to{animation:euSMf1FbiNs11_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs11_to__to{0%{transform:translate(2326.395841px,218.229656px)}45%{transform:translate(2326.395841px,218.229656px)}73%{transform:translate(662.384075px,215.434656px)}100%{transform:translate(662.384075px,215.434656px)}}@keyframes euSMf1FbiNs11_to__back{0%{transform:translate(662.384075px,215.434656px)}45%{transform:translate(662.384075px,215.434656px)}73%{transform:translate(2326.395841px,218.229656px)}100%{transform:translate(2326.395841px,218.229656px)}}.animate #euSMf1FbiNs15_to{animation:euSMf1FbiNs15_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs15_to{animation:euSMf1FbiNs15_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs15_to__to{0%{transform:translate(144.277373px,1260.854733px)}41%{transform:translate(144.277373px,331.868153px)}100%{transform:translate(144.277373px,331.868153px)}}@keyframes euSMf1FbiNs15_to__back{0%{transform:translate(144.277373px,331.868153px)}41%{transform:translate(144.277373px,331.868153px)}100%{transform:translate(144.277373px,1260.854733px)}}.animate #euSMf1FbiNs19_to{animation:euSMf1FbiNs19_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs19_to{animation:euSMf1FbiNs19_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs19_to__to{0%{transform:translate(144.277373px,1003.724046px)}60%{transform:translate(144.277373px,1003.724046px)}80%{transform:translate(145.277373px,766.938989px)}100%{transform:translate(145.277373px,766.938989px)}}@keyframes euSMf1FbiNs19_to__back{0%{transform:translate(145.277373px,766.938989px)}60%{transform:translate(145.277373px,766.938989px)}80%{transform:translate(144.277373px,1003.724046px)}100%{transform:translate(144.277373px,1003.724046px)}}.animate #euSMf1FbiNs22_to{animation:euSMf1FbiNs22_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs22_to{animation:euSMf1FbiNs22_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs22_to__to{0%{transform:translate(5474.895347px,1202.280706px)}60%{transform:translate(5474.895347px,1202.280706px)}90%{transform:translate(13.364022px,1202.286993px)}100%{transform:translate(13.364022px,1202.286993px)}}@keyframes euSMf1FbiNs22_to__back{0%{transform:translate(13.364022px,1202.286993px)}60%{transform:translate(13.364022px,1202.286993px)}90%{transform:translate(5474.895347px,1202.280706px)}100%{transform:translate(5474.895347px,1202.280706px)}}]]></style><g id="euSMf1FbiNs2" transform="matrix(1 0 0 1 327.55203400000028 85.59466518500005)"><polygon fill="currentColor" id="euSMf1FbiNs3" points="221.679659,0.620000 221.679659,0.669994 221.589769,0.620000 143.495006,136.034612 65.410231,0.620000 65.320341,0.669994 65.320341,0.620000 0,0.620000 0,264.620000 65.320341,264.620000 65.320341,131.265154 119.594153,225.374460 119.594153,225.374460 129.252375,242.112558 157.747625,242.112558 170.312302,220.325034 221.679659,131.265154 221.679659,264.620000 287,264.620000 287,0.620000 221.679659,0.620000" stroke="none" stroke-width="1"></polygon><path d="M442.390000,897.214899C442.390000,839.553909,481.940898,800.570000,521.811158,800.570000C549.465848,800.570000,567.150479,814.747785,577.439900,829.245519L583.867046,805.729194L642.390000,805.729194L642.390000,987.410806L583.867046,987.410806L577.439900,963.894481C567.150479,978.392215,549.495788,992.570000,521.811158,992.570000C481.920938,992.570000,442.390000,953.586091,442.390000,897.214899ZM574.545689,896.574999C574.545689,876.578124,562.010758,861.780436 ...
# </div>
# </a>
# <div class="flex hidden flex-grow items-center space-x-6 text-sm font-semibold tracking-wide xl:block" data-ga-action="navigation_link" data-ga-element="navigation_link" data-ga-item="title">
# <a class="text-secondary-300 hover:text-primary-400" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-101-top-creators-2025">The Mashable 101</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/creators">Creator Hub</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/tech">Tech</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/science">Science</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/life">Life</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-good">Social Good</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/entertainment">Entertainment</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/deals">Deals</a>
# <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">Shopping</a>
# <a data-ga-click="" data-ga-label="$text" href="https://games.mashable.com/" target="_blank">Games</a>
# </div>
# <div :class="{ 'mx-0':true,  'bg-white':searchOpen  }" class="absolute right-0 py-3 mx-4 lg:py-2 lg:mx-4 lg:max-w-xs xl:max-w-sm lg:min-w-20" false="" true="" x-data="window.navSearch()" x-init="init('site_search_autocomplete')">
# <div class="relative cursor-pointer">
# <input :class="{ 'visible': searchOpen, 'invisible': !searchOpen }" aria-label="Search Mashable Content" class="invisible py-1 pr-2 pl-8 w-full text-sm lg:border focus:outline-none lg:focus:border-gray-400" placeholder="Search" x-model="query" x-on:input="evt=&gt;query=evt.target.value" x-on:keydown="onKeyDown" x-on:keyup="onKeyUp" x-ref="searchInput"/>
# <svg class="inline-block absolute top-0 left-0 mt-2 ml-2 w-4 h-4 fill-current" x-cloak="" x-show="searchOpen"><use href="/images/icons/spritemap.svg#sprite-search-solid"></use></svg>
# <div class="flex absolute top-1 flex-row justify-between py-1 w-full" x-cloak="" x-show="!searchOpen">
# <div class="flex absolute top-0 flex-row justify-between py-0.5 w-full">
# <div class="flex flex-row justify-end items-center w-full">
# <button aria-label="Search" class="flex"><svg class="inline-block ml-2 w-4 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-search-solid"></use></svg></button>
# <span class="hidden ml-2 text-sm text-base font-semibold lg:block" x-cloak="" x-show="!searchOpen">Search</span>
# </div>
# </div>
# <button class="inline-block absolute right-2 text-sm font-semibold lg:hidden" false="" x-cloak="" x-show="searchOpen">Cancel</button>
# </div>
# <div class="absolute z-40 w-full bg-white shadow" x-cloak="" x-show="searchOpen">
# <template :key="key" hidden="" x-for="[key, value] in Object.entries(results)">
# <ul class="my-2" x-show="value &amp;&amp; value.length &gt; 0">
# <li class="py-2 pr-5 pl-8 text-sm text-gray-600" x-text="key + ':'"></li>
# <template :key="index" hidden="" x-for="(item, index) in value">
# <li :class="{'bg-gray-100': index + '-' + key  === selectedIndex}" class="" index="" key="">
# <a :data-ga-item="item.title" :href="item.url" :name="item.title" class="block py-2 pr-5 pl-8 leading-tight no-underline break-words cursor-pointer transition-bg" data-ga-click="" data-ga-element="dropdown-result" data-ga-module="search" x-html="item.title">
#                                         Search Result
#                                     </a>
# </li>
# </template>
# <hr class="my-4 mr-5 ml-8 border border-gray-100 border-1"/>
# </ul>
# </template>
# </div>
# </div>
# </div>
# </div>
# <div class="flex fixed top-0 z-30 flex-col w-screen h-screen bg-white shadow-md nav-open" false="" style="max-width:400px" x-cloak="" x-show="navOpen" x-transition:enter="transition duration-300 ease-out" x-transition:enter-end="opacity-1" x-transition:enter-start="opacity-0" x-transition:leave="transition duration-300 ease-out" x-transition:leave-end="opacity-0" x-trap="navOpen">
# <div class="flex relative px-4 mt-4">
# <button aria-label="Close" class="absolute" false="" x-ref="firstMenuItem">
# <svg class="inline-block w-6 h-6 fill-current"><use href="/images/icons/spritemap.svg#sprite-times-solid"></use></svg>
# </button>
# <div class="relative flex-shrink mx-auto text-center text-primary-400">
# <svg class="inline-block w-6 h-6 opacity-0 fill-current"><use href="/images/icons/spritemap.svg#sprite-mashable-m"></use></svg>
# <svg class="absolute top-0 left-0 -mt-1 -ml-5 w-12 h-12 fill-current"><use href="/images/icons/spritemap.svg#sprite-logomark"></use></svg>
# </div>
# </div>
# <div class="flex overflow-auto overscroll-none flex-col flex-grow py-6 px-8 mt-6" data-ga-action="side_navigation_link" data-ga-element="side_navigation_link" data-ga-item="title">
# <a class="mt-6 uppercase text-secondary-300 header-300 hover:text-primary-400" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-101-top-creators-2025">The Mashable 101</a>
# <div class="mt-6">
# <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/creators" target="_blank"><span class="font-semibold">Creator Hub</span></a>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Tech</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/apps-software">Apps &amp; Software</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/artificial-intelligence">Artificial Intelligence</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/cybersecurity">Cybersecurity</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/cryptocurrency">Cryptocurrency</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mobile">Mobile</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/smart-home">Smart Home</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-media">Social Media</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/tech-industry">Tech Industry</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/transportation">Transportation</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/tech">All Tech</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Science</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/space">Space</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/climate-change">Climate Change</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/environment">Environment</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/science">All Science</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Life</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/family-parenting">Family &amp; Parenting</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/health-wellness">Health &amp; Wellness</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sex-dating-relationships">Sex, Dating &amp; Relationships</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sleep">Sleep</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/careers">Careers</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mental-health">Mental Health</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/life">All Life</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Social Good</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/activism">Activism</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/gender">Gender</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/lgbtq">LGBTQ</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/racism">Racial Justice</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sustainability">Sustainability</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/politics">Politics</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-good">All Social Good</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Entertainment</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/games">Games</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/movies">Movies</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/podcasts">Podcasts</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/tv-shows">TV Shows</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/watch-guides">Watch Guides</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/entertainment">All Entertainment</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">SHOP THE BEST</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-laptops">Laptops</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-cheap-laptops">Budget Laptops</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-dating-apps">Dating Apps</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-sexting-apps">Sexting Apps</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-hookup-apps">Hookup Apps</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-vpns">VPNs</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-robot-vacuums">Robot Vaccuums</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-robot-vacuum-and-mop">Robot Vaccum &amp; Mop</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/article/best-noise-cancelling-headphones">Headphones</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-portable-bluetooth-speakers">Speakers</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-kindles">Kindles</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/gifts">Gift Guides</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-choice">Mashable Choice</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mashable-selects">Mashable Selects</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sex-dating-relationships">All Sex, Dating &amp; Relationships</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/laptops">All Laptops</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/headphones">All Headphones</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/robot-vacuums">All Robot Vacuums</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/vpn">All VPN</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">All Shopping</a>
# </div>
# </div>
# <div class="mt-6">
# <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://games.mashable.com/" target="_blank"><span class="font-semibold">Games</span></a>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Product Reviews</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/adult-friend-finder-review-dating-site">Adult Friend Finder</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/bumble-premium-review">Bumble Premium</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/tinder-platinum-review">Tinder Platinum</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/kindle-paperwhite-signature-edition">Kindle Paperwhite</a>
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/article/ps5-vs-ps5-slim-differences">PS5 vs PS5 Slim</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review">All Reviews</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">All Shopping</a>
# </div>
# </div>
# <div class="mt-6">
# <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/deals"><span class="font-semibold">Deals</span></a>
# </div>
# <div class="mt-6">
# <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/newsletters"><span class="font-semibold">Newsletters</span></a>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">Series</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/best-tech-apple-e-readers-airpods-headphones-earbuds-laptops-robovac">Mashable's Best: E-readers, robovacs, laptops, earbuds, smart home and more</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/trending-now">Trending Now</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/look-up">Look Up</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/mashable-selects">Mashable Selects</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/versus">Versus</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/top-creators-youtube-instagram-tiktok-ranked">Top creators, ranked</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/in-my-bag">In My Bag</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/best-gifts">Gift Ideas For Everyone On Your List</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/moms-dads-grads-gift-guide">Gifts for Moms, Dads, and Grads</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/ai-at-work">AI at Work</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/ai-at-home">AI at Home</a>
# <a class="mt-4 line-clamp-1" data-ga-click="" data-ga-label="$text" href="/series/readers-choice">Mashable Readers' Choice</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/series">All Series</a>
# </div>
# </div>
# <div class="mt-6" x-data="{drawerOpen: false}">
# <button class="uppercase cursor-pointer select-none header-300">
# <span class="font-semibold">VIDEOS</span>
# <div class="inline-block relative">
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="drawerOpen"><use href="/images/icons/spritemap.svg#sprite-minus-solid"></use></svg>
# <svg class="inline-block mb-1 w-5 h-5 text-secondary-300" x-show="!drawerOpen"><use href="/images/icons/spritemap.svg#sprite-plus-solid"></use></svg>
# </div>
# </button>
# <div class="text-base" x-show="drawerOpen">
# <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shows">Mashable Shows</a>
# <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/videos">All Videos</a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <header class="max-w-7xl z-10 px-4 mt-8 text-primary-400 font-sans mx-auto">
# <div class="flex flex-wrap subtitle-2">
# <div class="max-w-3xl">
# </div>
# </div>
# <h1 class="mt-4 header-100 leading-tight max-w-5xl">13 Static Site Generators to Help You Build Your Ultimate Website</h1>
# <div class="mt-2 leading-tight md:leading-normal text-xl max-w-5xl"></div>
# <div class="w-full relative z-10 items-center subtitle-2 mt-8 text-left md:flex md:flex-wrap md:items-center md:space-x-8">
# <div class="flex relative">
#                                          By
#                                                                                                                                                     <div aria-describedby="flyout" class="inline-block md:relative" false="" true="" x-data="{ showAuthor: false }">
# <a class="underline-link" href="/author/grace-smith">Grace Smith</a>
# </div>
#                                                                                                                              on <time datetime="Thu, 28 Aug 2014 11:15:22 +0000">August 28, 2014</time>
# </div>
# <div class="flex flex-initial content-start mt-4 text-base md:mt-0">
# <a aria-label="Facebook Share" class="pr-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="facebook" data-ga-position="1" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators" rel="noopener" target="_blank" title="(opens in a new window)">
# <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-facebook-f-brands"></use></svg>
# <span class="sr-only">Share on Facebook</span>
# </a>
# <a aria-label="Twitter Share" class="px-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="twitter" data-ga-position="2" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&amp;text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website" rel="noopener" target="_blank" title="(opens in a new window)">
# <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-twitter-brands"></use></svg>
# <span class="sr-only">Share on Twitter</span>
# </a>
# <a aria-label="Flipboard Share" class="px-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="flipboard" data-ga-position="3" href="https://share.flipboard.com/bookmarklet/popout?v=2&amp;url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&amp;title=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website" rel="noopener" target="_blank" title="(opens in a new window)">
# <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-flipboard-brands"></use></svg>
# <span class="sr-only">Share on Flipboard</span>
# </a>
# </div>
# </div>
# <div class="">
# </div>
# </header>
# <div class="px-4 mx-auto mt-8 mt-10 max-w-7xl font-sans text-primary-400">
# <img alt="13 Static Site Generators to Help You Build Your Ultimate Website" class="w-full" height="702" sizes="(max-width: 1280px) 100vw, 1280px" src="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1248x702.v1647024413.jpg" srcset="https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_400x225.v1647024413.jpg 400w, https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_800x450.v1647024413.jpg 800w, https://helios-i.mashable.com/imagery/archives/00s0gVKdAC9EPTZERS7TvPb/hero-image.fill.size_1248x702.v1647024413.jpg 1600w" width="1248"/>
# <div class="mt-2 leading-none text-left">
# <span class="font-sans text-gray-600 subtitle-2">Credit: vasabii</span>
# </div>
# </div>
# <main class="relative grid grid-cols-1 px-4 mx-auto max-w-8xl grid-cols-1 2xl:grid-cols-[1fr_300px] gap-0 2xl:gap-4">
# <section class="flex-grow 2xl:pr-4" data-ga-module="content_body" data-seamless="">
# <article class="mt-8 font-serif editor-content" data-autopogo="" id="article">
# <p>Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can make building and maintaining websites incredibly simple, as there is no database to slow requests down, and web servers automatically cache headers, reducing bandwidth usage.</p><p>Static sites also offer greater security, as they do not contain dynamic content, so are immune to the most common attacks. Storing content in flat, text files, makes them ideal to be used with version control systems, such as Git. Utilizing a static site generator means you can build websites with modern frameworks, and workflows, with a high degree of productivity and efficiency.</p><p>We have compiled 13 of the best static site generators, which are easy to scale, offer secure filesystems, increased performance and are quick to setup.</p><p></p>
# </article>
# </section>
# <aside class="hidden 2xl:block" data-ga-module="content_rail">
# <div class="sticky top-0 pt-16 mt-8">
# <div data-pogo="sidebar"></div>
# </div>
# </aside>
# </main>
# <div class="py-9 px-6 mt-20 text-center text-black rounded border md:mt-32 newsletter bg-warmgray-100 border-warmgray-100" data-ga-category="newsletters" data-ga-impression="" data-ga-label="Top Stories" data-ga-module="footer_nl_signup" x-data="window.newsletter()" x-init="init()">
# <div class="flex flex-col mx-auto max-w-4xl font-sans md:flex-row" x-show="!isSuccess">
# <div class="font-bold leading-8 text-left md:w-1/2 header-300">The biggest stories of the day delivered to your inbox.</div>
# <div class="flex flex-col md:mt-2 md:w-1/2">
# <form class="flex flex-row mt-8 h-12 border-b-2 md:mt-0 text-primary-400 border-primary-400 focus-within:text-secondary-300" data-initial-lists="top-stories" x-on:submit.prevent="submit()" x-ref="subscribeForm">
# ...
# </svg></a>
# </div>
# <div class="mb-0 w-1/2 lg:w-auto">
# <a aria-label="Speed Test" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="speedtest" data-ga-module="footer" href="https://www.speedtest.net/" rel="noopener">
# <svg class="inline-block w-32 h-4 text-white fill-current hover:text-accent">
# <path d="M22.199 11.5917C23.5051 12.7793 25.2132 13.4316 26.9771 13.426C29.4052 13.426 31.091 12.1381 31.091 9.99145V9.95799C31.091 8.06227 29.8462 7.1869 27.4069 6.59588C25.1909 6.07734 24.6662 5.68147 24.6662 4.79494V4.76706C24.6662 4.01993 25.3639 3.4066 26.5417 3.4066C27.5967 3.4066 28.6293 3.8192 29.662 4.58864L30.7505 3.06091C29.5783 2.12421 28.2498 1.61682 26.5752 1.61682C24.2978 1.61682 22.6511 2.97728 22.6511 4.94548V4.97894C22.6511 7.09769 24.0354 7.82252 26.4803 8.41354C28.6126 8.90977 29.0759 9.35025 29.0759 10.1754V10.2089C29.0759 11.062 28.2833 11.653 27.0385 11.653C25.6263 11.653 24.5043 11.1066 23.4102 10.1587L22.199 11.5917Z" fill="currentColor"></path>
# <path d="M34.8475 7.74992V3.60722H37.1975C38.7046 3.60722 39.6759 4.31532 39.6759 5.66463V5.69809C39.6759 6.89685 38.727 7.7555 37.1975 7.7555H34.8475V7.74992ZM32.8213 1.77283V13.2698H34.8475V9.57316H37.1361C39.6703 9.57316 41.7356 8.23501 41.7356 5.65348V5.62003C41.7356 3.30056 40.0666 1.77283 37.3705 1.77283H32.8325H32.8213Z" fill="currentColor"></path>
# <path d="M43.4772 13.2698H52.0957V11.4577H45.5034V8.36882H51.2751V6.56789H45.5034V3.57376H52.0119V1.77283H43.4772V13.2698Z" fill="currentColor"></path>
# <path d="M54.161 13.2698H62.7739V11.4577H56.1872V8.36882H61.9478V6.56789H56.1872V3.57376H62.6958V1.77283H54.161V13.2698Z" fill="currentColor"></path>
# <path d="M69.1317 3.61837C71.5486 3.61837 73.1283 5.28549 73.1283 7.5269V7.56035C73.1283 9.81291 71.5486 11.441 69.1317 11.441H66.8654V3.61837H69.1317ZM64.8503 1.77283V13.2587H69.1428C72.7599 13.2587 75.2606 10.7496 75.2606 7.51575V7.48229C75.2606 4.24842 72.7599 1.77283 69.1428 1.77283H64.8503Z" fill="currentColor"></path>
# <path d="M80.0331 13.2698H82.065V3.64625H85.7155V1.77283H76.3826V3.64625H80.0331V13.2698Z" fill="currentColor"></path>
# <path d="M87.859 13.2698H96.4663V11.4577H89.8741V8.36882H95.6458V6.56789H89.8741V3.57376H96.3826V1.77283H87.859V13.2698Z" fill="currentColor"></path>
# <path d="M98.0906 11.5917C99.3967 12.7793 101.105 13.4316 102.869 13.426C105.297 13.426 106.983 12.1381 106.983 9.99145V9.95799C106.983 8.06227 105.738 7.1869 103.299 6.59588C101.082 6.07734 100.558 5.68147 100.558 4.79494V4.76706C100.558 4.01993 101.256 3.4066 102.433 3.4066C103.488 3.4066 104.521 3.8192 105.554 4.58864L106.642 3.06091C105.47 2.12421 104.141 1.61682 102.467 1.61682C100.189 1.61682 98.5427 2.97728 98.5427 4.94548V4.97894C98.5427 7.09769 99.927 7.82252 102.372 8.41354C104.504 8.90977 104.967 9.35025 104.967 10.1754V10.2089C104.967 11.062 104.175 11.653 102.93 11.653C101.518 11.653 100.396 11.1066 99.3019 10.1587L98.0906 11.5917Z" fill="currentColor"></path>
# <path d="M111.973 13.2698H114.021V3.64625H117.672V1.77283H108.333V3.64625H111.973V13.2698Z" fill="currentColor"></path>
# <path clip-rule="evenodd" d="M13.106 12.7512C15.6235 10.2311 15.6235 6.14968 13.106 3.62949C10.583 1.10929 6.49144 1.10929 3.96841 3.62391C1.44539 6.13853 1.4398 10.2311 3.95725 12.7512L2.80737 13.8998L2.80179 13.8943C-0.357571 10.7329 -0.351989 5.61999 2.80737 2.46417C5.96674 -0.691643 11.0909 -0.686067 14.2503 2.46975C17.4097 5.62557 17.4041 10.744 14.2447 13.8998L13.106 12.7512Z" fill="currentColor" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M12.3245 5.21843L11.4705 4.36536L6.87097 8.37982L8.30552 9.81277L12.3245 5.21843Z" fill="currentColor" fill-rule="evenodd"></path>
# <path d="M119.263 2.68712V2.31912H119.548C119.693 2.31912 119.782 2.38045 119.782 2.49754C119.782 2.61463 119.687 2.68712 119.548 2.68712H119.263ZM119.073 3.25026H119.263V2.85996H119.503L119.776 3.25026H120.011L119.715 2.82651C119.871 2.79305 119.983 2.65366 119.977 2.49197C119.977 2.40276 119.944 2.31355 119.882 2.25221C119.793 2.17973 119.682 2.1407 119.564 2.14628H119.068V3.25026H119.073Z" fill="currentColor"></path>
# <path d="M119.486 1.7616C120.011 1.7616 120.435 2.18535 120.435 2.70946C120.435 3.23357 120.011 3.65732 119.486 3.65732C118.961 3.65732 118.537 3.23357 118.537 2.70946C118.537 2.18535 118.961 1.7616 119.486 1.7616ZM119.486 1.88984C119.04 1.88984 118.671 2.25225 118.671 2.70388C118.671 3.14993 119.034 3.51793 119.486 3.51793C119.933 3.51793 120.301 3.15551 120.301 2.70388C120.301 2.25225 119.933 1.88984 119.486 1.88984Z" fill="currentColor"></path>
# </svg></a>
# </div>
# </div>
# </div>
# <hr class="my-12 lg:my-16 border-primary-300"/>
# <div class="font-sans leading-5 subtitle-1">©2005–2026 Mashable, Inc., a Ziff Davis company. All Rights Reserved.</div>
# <div class="mt-2 font-sans leading-5 subtitle-1">Mashable is a registered trademark of Ziff Davis and may not be used by third parties without express written permission.</div>
# <ul class="flex flex-col flex-wrap justify-start mt-8 space-y-4 font-sans underline lg:flex-row lg:space-y-0 lg:space-x-6 subtitle-2">
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/about" rel="noopener" target="_blank" title="(opens in a new window)">About Ziff Davis</a></li>
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/ztg-privacy-policy" rel="noopener" target="_blank" title="(opens in a new window)">Privacy Policy</a></li>
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/terms-of-use" rel="noopener" target="_blank" title="(opens in a new window)">Terms of Use</a></li>
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://ziffmedia.com/" rel="noopener" target="_blank" title="(opens in a new window)">Advertise</a></li>
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/accessibility" rel="noopener" target="_blank" title="(opens in a new window)">Accessibility</a></li>
# <li><a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://dsar.mashable.com">Do Not Sell My Personal Information</a></li>
# <li>
# <button class="block" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="zd_consent" data-ga-module="footer" onclick="window.zdconsent.showConsentTool();">
# <img alt="ZiffDavis AdChoices" class="inline-block mr-2" height="18px" loading="lazy" src="https://c.evidon.com/pub/icong1.png" width="14px"/>AdChoices
#                     </button>
# </li>
# <li class="lg:pt-0"><a aria-label="BBB Accredited Business Logo" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="BBB Accredited Business Logo" data-ga-module="footer" href="https://www.bbb.org/us/ny/new-york/profile/digital-media/ziff-davis-llc-0121-531/#sealclick" rel="noopener" target="_blank" title="(opens in a new window)"><svg height="50" version="1.1" viewbox="0 0 78 45" width="96" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <style>
#       .cls-1 {
#         fill: none;
#       }
#
#       .cls-2 {
#         fill: #fff;
#       }
#
#       .cls-2, .cls-3 {
#         fill-rule: evenodd;
#       }
#
#       .cls-4, .cls-3 {
#         fill: #005f85;
#       }
#
#       .cls-5 {
#         clip-path: url(#clippath);
#       }
#     </style>
# <clippath id="clippath">
# <rect class="cls-1" height="45" width="78"></rect>
# </clippath>
# </defs>
# <!-- Generator: Adobe Illustrator 28.6.0, SVG Export Plug-In . SVG Version: 1.2.0 Build 709)  -->
# <g>
# <g id="Layer_1">
# <g class="cls-5">
# <g>
# <path class="cls-3" d="M4,30.8c-2.1,0-3.8-1.8-3.8-4V4C.1,1.8,1.9,0,4,0h70.2c2.1,0,3.8,1.8,3.8,4v22.7c0,2.2-1.7,4-3.8,4H4Z"></path>
# <path class="cls-2" d="M4.2.6c-1.9,0-3.4,1.5-3.4,3.4v22.7c0,1.9,1.5,3.4,3.4,3.4h23.8V.6H4.2ZM60.1,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.5-.3-1.9-.7h0ZM56.1,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.5-.3-1.9-.7h0ZM41.5,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.4-.3-1.9-.7h0ZM37,20.1v-2.6h1v2.6c0,.6.4,1,1,1s1-.4,1-1v-2.6h1v2.6c0,1.1-.6,1.8-2,1.8-1.3,0-2-.7-2-1.8h0ZM50.7,21.8l-2.1-2.9v2.9h-.9v-4.4h1l2,2.8v-2.8h.9v4.4h-.9ZM45.8,21.8v-4.4h.9v4.4h-.9ZM52.5,21.8v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM32.6,21.8v-4.4h2.3c.8,0,1.3.5,1.3,1.1s-.3.9-.8,1c.5,0,.8.5.8,1.1s-.4,1.2-1.3,1.2h-2.4s0,0,0,0ZM35.3,20.5c0-.3-.2-.5-.6-.5h-1.2v1h1.2c.4,0,.6-.2.6-.5ZM35.2,18.7c0-.3-.2-.5-.5-.5h-1.2v1h1.2c.3,0,.5-.2.5-.5h0s0,0,0,0ZM36.9,12.1c0-1.3,1-2.3,2.3-2.3.8,0,1.5.4,1.8,1.1l-.8.4c-.2-.4-.6-.6-1-.6-.8,0-1.4.6-1.4,1.4s.6,1.4,1.4,1.4c.4,0,.8-.2,1-.6l.8.4c-.3.5-.9,1.1-1.8,1.1-1.3,0-2.3-.9-2.3-2.3ZM41.5,12.1c0-1.3,1-2.3,2.3-2.3.8,0,1.5.4,1.8,1.1l-.8.4c-.2-.4-.6-.6-1-.6-.8,0-1.4.6-1.4,1.4s.6,1.4,1.4,1.4c.4,0,.8-.2,1-.6l.8.4c-.3.5-.9,1.1-1.8,1.1-1.3,0-2.3-.9-2.3-2.3ZM48.7,14.3l-.9-1.6h-.7v1.6h-.9v-4.4h2.1c.9,0,1.5.6,1.5,1.4s-.5,1.2-1,1.3l1,1.7h-1.1s0,0,0,0ZM35.6,14.3l-.3-.7h-1.9l-.3.7h-1.1l1.7-4.4h1.2l1.7,4.4h-1.1ZM68.8,14.3v-4.4h1.7c1.4,0,2.3.9,2.3,2.2s-1,2.2-2.3,2.2h-1.7ZM64.9,14.3v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM59.2,14.3v-4.4h.9v4.4h-.9ZM54.4,14.3v-4.4h1.7c1.4,0,2.3.9,2.3,2.2s-1,2.2-2.3,2.2h-1.7ZM50.5,14.3v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM62,14.3v-3.6h-1.3v-.8h3.5v.8h-1.3v3.6h-.9ZM71.9,12.1c0-.8-.5-1.4-1.4-1.4h-.8v2.7h.8c.9,0,1.4-.6,1.4-1.4h0ZM57.5,12.1c0-.8-.5-1.4-1.4-1.4h-.8v2.7h.8c.9,0,1.4-.6,1.4-1.4h0ZM34.4,10.8l-.7,1.9h1.4l-.7-1.9ZM48.8,11.3c0-.4-.3-.6-.7-.6h-1v1.2h1c.4,0,.7-.2.7-.6h0Z"></path>
# <path class="cls-3" d="M10,25.4c.6.3.9.5,1,1.2.2,1.4-1,1.9-2.2,1.9h-2.8v-5.9h2.8c1,0,1.9.5,1.9,1.6s-.3,1-.8,1.2h0ZM15.5,25.4c.6.3.9.5,1,1.2.2,1.4-1,1.9-2.2,1.9h-2.8v-5.9h2.8c1,0,1.9.5,1.9,1.6s-.3,1-.8,1.2h0ZM22,26.6c-.1-.8-.4-1-1-1.2.5-.3.8-.7.8-1.2,0-1.1-.9-1.6-1.9-1.6h-2.8v5.9h2.8c1.2,0,2.4-.5,2.2-1.9h0ZM22.8,27.1h0c0-.8.6-1.4,1.4-1.4s1.4.6,1.4,1.4h0c0,.8-.6,1.4-1.4,1.4-.7,0-1.4-.6-1.4-1.4ZM25.4,27.1h0c0-.7-.6-1.2-1.2-1.2s-1.2.6-1.2,1.2h0c0,.7.6,1.2,1.2,1.2s1.2-.6,1.2-1.2ZM23.6,26.3h.6c.2,0,.3,0,.4.1,0,0,.1.2.1.3h0c0,.2-.2.4-.4.4l.4.6h-.3l-.4-.5h-.4v.5h-.2v-1.4s0,0,0,0ZM8.9,27.4h-1.6v-1.3h1.6c1.2,0,1.1,1.3,0,1.3ZM14.4,27.4h-1.6v-1.3h1.6c1.2,0,1.1,1.3,0,1.3ZM18.3,26v1.3h1.6c1.1,0,1.2-1.3,0-1.3h-1.6ZM24.2,27c.2,0,.3,0,.3-.2h0c0-.2-.1-.2-.3-.2h-.4v.5h.4ZM7.3,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM18.3,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM12.8,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM8.7,19.9h2.7l.5,1.6h4.4l.5-1.6h2.7l-.4-1.2h-10l-.4,1.2h0ZM12,10.3l-1.3,1.8c-.7.9-.5,2.5.4,3.1l2.4,1.7c.4.3.4.6.2.9l.4.3,1.2-1.7c.8-1,.7-2.5-.4-3.3l-2.4-1.8c-.3-.2-.3-.5-.2-.8l-.3-.2h0ZM14,2.4l-2,2.8c-.9,1.3-.6,3.6.7,4.5l3.3,2.4c.7.5.8,1.8.3,2.4l.3.2,2.3-3.2c1-1.5,1-3.6-.6-4.8l-3.6-2.6c-.5-.4-.7-1-.3-1.6l-.3-.2h0Z"></path>
# </g>
# </g>
# <path class="cls-4" d="M6.2,43.9c-.6,0-1.1,0-1.6-.3-.5-.2-.9-.5-1.2-.8-.4-.4-.6-.8-.8-1.3-.2-.5-.3-1-.3-1.6s0-1.1.3-1.5c.2-.5.5-.9.8-1.3.4-.4.8-.6,1.2-.8.5-.2,1-.3,1.6-.3s1.2.1,1.6.3c.5.2.9.5,1.2.8l-.9.9c-.2-.2-.5-.4-.8-.6-.3-.1-.7-.2-1.1-.2s-.7,0-1,.2c-.3.1-.6.3-.8.6-.2.2-.4.5-.5.9-.1.3-.2.7-.2,1.1s0,.8.2,1.1c.1.3.3.6.5.9.2.2.5.4.8.6.3.1.7.2,1,.2s.9,0,1.2-.2c.3-.1.6-.3.8-.6l.9.9c-.4.4-.8.6-1.2.8-.5.2-1,.3-1.6.3ZM10.1,43.8v-7.9h1.2v7.9h-1.2ZM12.6,43.8v-5.3h1.2v5.3h-1.2ZM13.2,37.5c-.2,0-.4,0-.5-.2-.1-.1-.2-.3-.2-.5s0-.4.2-.5c.1-.1.3-.2.5-.2s.4,0,.5.2c.1.1.2.3.2.5s0,.4-.2.5c-.1.1-.3.2-.5.2ZM17.6,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.7-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s.8,0,1.1.2c.4.2.7.4.9.7l-.8.8c-.2-.2-.3-.3-.6-.4-.2,0-.4-.1-.7-.1s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2s.5,0,.7-.1c.2,0,.4-.2.6-.4l.8.8c-.2.3-.6.5-.9.7-.4.2-.7.2-1.1.2ZM23.9,43.8l-2.2-2.7,2.2-2.6h1.4l-2.6,2.9v-.7c0,0,2.7,3.1,2.7,3.1h-1.5ZM20.6,43.8v-7.9h1.2v7.9h-1.2ZM29.1,43.8v-6c0-.4,0-.8.3-1.1.2-.3.4-.5.7-.7.3-.2.7-.3,1.1-.3s.6,0,.8.2c.2.1.4.3.6.5l-.8.8c0,0-.2-.2-.3-.2-.1,0-.2,0-.4,0-.3,0-.5,0-.7.2-.2.2-.2.4-.2.7v6h-1.2ZM27.8,39.6v-1.1h4.1v1.1h-4.1ZM35,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s1,.1,1.4.4c.4.2.7.6,1,1,.2.4.4.9.4,1.4s-.1,1-.4,1.4c-.2.4-.6.8-1,1-.4.2-.9.4-1.4.4ZM35,42.7c.3,0,.6,0,.8-.2.2-.1.4-.3.5-.6.1-.2.2-.5.2-.8s0-.6-.2-.8c-.1-.2-.3-.4-.5-.5-.2-.1-.5-.2-.8-.2s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2ZM38.8,43.8v-5.3h1.2v5.3h-1.2ZM40,40.9l-.4-.2c0-.7.1-1.2.4-1.6.3-.4.8-.6,1.4-.6s.5,0,.7.1c.2,0,.4.2.6.5l-.8.8c0-.1-.2-.2-.3-.2-.1,0-.3,0-.4,0-.3,0-.6.1-.8.3-.2.2-.3.5-.3,1ZM46.7,40.9v-1.1h1.9c.3,0,.5,0,.7-.2.2-.1.4-.3.5-.5.1-.2.2-.4.2-.7s0-.5-.2-.7c-.1-.2-.3-.3-.5-.5-.2-.1-.4-.2-.7-.2h-1.9v-1.1h2c.5,0,.9,0,1.3.3.4.2.7.5.9.8.2.4.3.8.3,1.3s-.1.9-.3,1.3c-.2.4-.5.6-.9.8-.4.2-.8.3-1.3.3h-2ZM45.8,43.8v-7.7h1.3v7.7h-1.3ZM52.3,43.8v-5.3h1.2v5.3h-1.2ZM53.5,40.9l-.4-.2c0-.7.1-1.2.4-1.6.3-.4.8-.6,1.4-.6s.5,0,.7.1c.2,0,.4.2.6.5l-.8.8c0-.1-.2-.2-.3-.2-.1,0-.3,0-.4,0-.3,0-.6.1-.8.3-.2.2-.3.5-.3,1ZM59,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s1,.1,1.4.4c.4.2.7.6,1,1,.2.4.4.9.4,1.4s-.1,1-.4,1.4c-.2.4-.6.8-1,1-.4.2-.9.4-1.4.4ZM59,42.7c.3,0,.6,0,.8-.2.2-.1.4-.3.5-.6.1-.2.2-.5.2-.8s0-.6-.2-.8c-.1-.2-.3-.4-.5-.5-.2-.1-.5-.2-.8-.2s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2ZM63.4,43.8v-6.2c0-.4,0-.7.2-.9.2-.3.4-.5.7-.7.3-.2.6-.2,1-.2s.5,0,.7.1c.2,0,.4.2.6.4l-.8.8c0,0-.2-.1-.2-.1,0,0-.2,0-.3,0-.2,0-.4,0-.5.2-.1.1-.2.3-.2.5v6.2h-1.2ZM62.1,39.6v-1.1h5.1v1.1h-5.1ZM66.6,43.8v-5.3h1.2v5.3h-1.2ZM67.2,38.1c-.2,0-.4,0-.5-.2-.1-.1-.2-.3-.2-.5s0-.4.2-.5c.1-.1.3-.2.5-.2s.4,0,.5.2c.1.1.2.3.2.5s0,.4-.2.5c-.1.1-.3.2-.5.2ZM69.1,43.8v-7.9h1.2v7.9h-1.2ZM74.1,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s.9.1,1.3.3c.4.2.7.5.9.9.2.4.3.8.3,1.4s0,.2,0,.3c0,0,0,.2,0,.3h-4.3v-1h3.7l-.5.4c0-.3,0-.6-.2-.8s-.3-.4-.5-.5c-.2-.1-.4-.2-.7-.2s-.6,0-.8.2c-.2.1-.4.3-.5.6-.1.2-.2.5-.2.8s0,.6.2.9c.1.2.3.4.6.6.2.1.5.2.8.2s.5,0,.7-.1c.2,0,.4-.2.6-.4l.8.8c-.3.3-.6.5-.9.7-.4.2-.8.2-1.2.2Z"></path>
# </g>
# </g>
# </svg></a></li>
# </ul>
# </div>
# </div>
# </footer>
# <script defer="" src="/js/app.js?id=4d8654aa7a1e124daf2c2d659872e589"></script>
# </body>
# </html>

# %%
soup.find_all("a", attrs={'href': re.compile("^https")})
# Out:
# [<a aria-label="Home" class="flex items-center mr-8 w-full xl:w-auto" data-ga-action="navigation_logo" data-ga-click="" data-ga-element="navigation_logo" data-ga-item="logo" href="https://mashable.com">
#  <div x-data="{animate: false, reverse: false}" x-init="setTimeout(() =&gt; animate = true, 1000)">
#  <svg :class="{ 'animate': animate, 'animate-reverse': reverse }" class="inline-block -mb-3 w-40 h-11 fill-current hover:fill-secondary-100" id="mashable-wordmark-animated" shape-rendering="geometricPrecision" text-rendering="geometricPrecision" viewbox="0 0 2200 650" x-ref="wordmark" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><style><![CDATA[.animate #euSMf1FbiNs11_to{animation:euSMf1FbiNs11_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs11_to{animation:euSMf1FbiNs11_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs11_to__to{0%{transform:translate(2326.395841px,218.229656px)}45%{transform:translate(2326.395841px,218.229656px)}73%{transform:translate(662.384075px,215.434656px)}100%{transform:translate(662.384075px,215.434656px)}}@keyframes euSMf1FbiNs11_to__back{0%{transform:translate(662.384075px,215.434656px)}45%{transform:translate(662.384075px,215.434656px)}73%{transform:translate(2326.395841px,218.229656px)}100%{transform:translate(2326.395841px,218.229656px)}}.animate #euSMf1FbiNs15_to{animation:euSMf1FbiNs15_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs15_to{animation:euSMf1FbiNs15_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs15_to__to{0%{transform:translate(144.277373px,1260.854733px)}41%{transform:translate(144.277373px,331.868153px)}100%{transform:translate(144.277373px,331.868153px)}}@keyframes euSMf1FbiNs15_to__back{0%{transform:translate(144.277373px,331.868153px)}41%{transform:translate(144.277373px,331.868153px)}100%{transform:translate(144.277373px,1260.854733px)}}.animate #euSMf1FbiNs19_to{animation:euSMf1FbiNs19_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs19_to{animation:euSMf1FbiNs19_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs19_to__to{0%{transform:translate(144.277373px,1003.724046px)}60%{transform:translate(144.277373px,1003.724046px)}80%{transform:translate(145.277373px,766.938989px)}100%{transform:translate(145.277373px,766.938989px)}}@keyframes euSMf1FbiNs19_to__back{0%{transform:translate(145.277373px,766.938989px)}60%{transform:translate(145.277373px,766.938989px)}80%{transform:translate(144.277373px,1003.724046px)}100%{transform:translate(144.277373px,1003.724046px)}}.animate #euSMf1FbiNs22_to{animation:euSMf1FbiNs22_to__to 1s linear 1 normal forwards}.animate-reverse #euSMf1FbiNs22_to{animation:euSMf1FbiNs22_to__back 1s linear 1 normal forwards}@keyframes euSMf1FbiNs22_to__to{0%{transform:translate(5474.895347px,1202.280706px)}60%{transform:translate(5474.895347px,1202.280706px)}90%{transform:translate(13.364022px,1202.286993px)}100%{transform:translate(13.364022px,1202.286993px)}}@keyframes euSMf1FbiNs22_to__back{0%{transform:translate(13.364022px,1202.286993px)}60%{transform:translate(13.364022px,1202.286993px)}90%{transform:translate(5474.895347px,1202.280706px)}100%{transform:translate(5474.895347px,1202.280706px)}}]]></style><g id="euSMf1FbiNs2" transform="matrix(1 0 0 1 327.55203400000028 85.59466518500005)"><polygon fill="currentColor" id="euSMf1FbiNs3" points="221.679659,0.620000 221.679659,0.669994 221.589769,0.620000 143.495006,136.034612 65.410231,0.620000 65.320341,0.669994 65.320341,0.620000 0,0.620000 0,264.620000 65.320341,264.620000 65.320341,131.265154 119.594153,225.374460 119.594153,225.374460 129.252375,242.112558 157.747625,242.112558 170.312302,220.325034 221.679659,131.265154 221.679659,264.620000 287,264.620000 287,0.620000 221.679659,0.620000" stroke="none" stroke-width="1"></polygon><path d="M442.390000,897.214899C442.390000,839.553909,481.940898,800.570000,521.811158,800.570000C549.465848,800.570000,567.150479,814.747785,577.439900,829.245519L583.867046,805.729194L642.390000,805.729194L642.390000,987.410806L583.867046,987.410806L577.439900,963.894481C567.150479,978.392215,549.495788,992.570000,521.811158,992.570000C481.920938,992.570000,442.390000,953.586091,442.390000,897.214899ZM574.545689,896.574999C574.545689,876.578124,562.010758,861.78043 ...
#  </div>
#  </a>,
#  <a class="text-secondary-300 hover:text-primary-400" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-101-top-creators-2025">The Mashable 101</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/creators">Creator Hub</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/tech">Tech</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/science">Science</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/life">Life</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-good">Social Good</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/entertainment">Entertainment</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/deals">Deals</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">Shopping</a>,
#  <a data-ga-click="" data-ga-label="$text" href="https://games.mashable.com/" target="_blank">Games</a>,
#  <a class="mt-6 uppercase text-secondary-300 header-300 hover:text-primary-400" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-101-top-creators-2025">The Mashable 101</a>,
#  <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/creators" target="_blank"><span class="font-semibold">Creator Hub</span></a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/apps-software">Apps &amp; Software</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/artificial-intelligence">Artificial Intelligence</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/cybersecurity">Cybersecurity</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/cryptocurrency">Cryptocurrency</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mobile">Mobile</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/smart-home">Smart Home</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-media">Social Media</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/tech-industry">Tech Industry</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/transportation">Transportation</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/tech">All Tech</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/space">Space</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/climate-change">Climate Change</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/environment">Environment</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/science">All Science</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/family-parenting">Family &amp; Parenting</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/health-wellness">Health &amp; Wellness</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sex-dating-relationships">Sex, Dating &amp; Relationships</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sleep">Sleep</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/careers">Careers</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mental-health">Mental Health</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/life">All Life</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/activism">Activism</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/gender">Gender</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/lgbtq">LGBTQ</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/racism">Racial Justice</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sustainability">Sustainability</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/politics">Politics</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/social-good">All Social Good</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/games">Games</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/movies">Movies</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/podcasts">Podcasts</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/tv-shows">TV Shows</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/watch-guides">Watch Guides</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/entertainment">All Entertainment</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-laptops">Laptops</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-cheap-laptops">Budget Laptops</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-dating-apps">Dating Apps</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-sexting-apps">Sexting Apps</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-hookup-apps">Hookup Apps</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-vpns">VPNs</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-robot-vacuums">Robot Vaccuums</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-robot-vacuum-and-mop">Robot Vaccum &amp; Mop</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/article/best-noise-cancelling-headphones">Headphones</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-portable-bluetooth-speakers">Speakers</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/roundup/best-kindles">Kindles</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/gifts">Gift Guides</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/mashable-choice">Mashable Choice</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/mashable-selects">Mashable Selects</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/sex-dating-relationships">All Sex, Dating &amp; Relationships</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/laptops">All Laptops</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/headphones">All Headphones</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/robot-vacuums">All Robot Vacuums</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/category/vpn">All VPN</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">All Shopping</a>,
#  <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://games.mashable.com/" target="_blank"><span class="font-semibold">Games</span></a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/adult-friend-finder-review-dating-site">Adult Friend Finder</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/bumble-premium-review">Bumble Premium</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/tinder-platinum-review">Tinder Platinum</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review/kindle-paperwhite-signature-edition">Kindle Paperwhite</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/article/ps5-vs-ps5-slim-differences">PS5 vs PS5 Slim</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/review">All Reviews</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shopping">All Shopping</a>,
#  <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/deals"><span class="font-semibold">Deals</span></a>,
#  <a class="uppercase cursor-pointer select-none header-300" data-ga-click="" data-ga-label="$text" href="https://mashable.com/newsletters"><span class="font-semibold">Newsletters</span></a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/series">All Series</a>,
#  <a class="block mt-4" data-ga-click="" data-ga-label="$text" href="https://mashable.com/shows">Mashable Shows</a>,
#  <a class="block mt-4 font-bold" data-ga-click="" data-ga-label="$text" href="https://mashable.com/videos">All Videos</a>,
#  <a aria-label="Facebook Share" class="pr-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="facebook" data-ga-position="1" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-facebook-f-brands"></use></svg>
#  <span class="sr-only">Share on Facebook</span>
#  </a>,
#  <a aria-label="Twitter Share" class="px-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="twitter" data-ga-position="2" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&amp;text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-twitter-brands"></use></svg>
#  <span class="sr-only">Share on Twitter</span>
#  </a>,
#  <a aria-label="Flipboard Share" class="px-3 hover:text-primary-400" data-ga-action="social_share_link" data-ga-click="" data-ga-element="social-share-link" data-ga-label="flipboard" data-ga-position="3" href="https://share.flipboard.com/bookmarklet/popout?v=2&amp;url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&amp;title=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block w-5 h-4 fill-current"><use href="/images/icons/spritemap.svg#sprite-flipboard-brands"></use></svg>
#  <span class="sr-only">Share on Flipboard</span>
#  </a>,
#  <a class="underline text-secondary-300 hover:text-primary-400" href="https://www.ziffdavis.com/terms-of-use" rel="noopener" target="_blank" title="(opens in a new window)">Terms of Use</a>,
#  <a class="underline text-secondary-300 hover:text-primary-400" href="https://www.ziffdavis.com/ztg-privacy-policy" rel="noopener" target="_blank" title="(opens in a new window)">Privacy Policy</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/tech">TECH</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/android">Android</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/antivirus">Antivirus</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/apple">Apple</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/artificial-intelligence">Artificial Intelligence</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/cameras">Cameras</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/creative-software">Creative Software</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/cryptocurrency">Cryptocurrency</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/desktops">Desktops</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/gaming-consoles">Gaming Consoles</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/headphones">Headphones</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/laptops">Laptops</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/microsoft">Microsoft</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/mobile">Mobile</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/productivity">Productivity</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/smart-home">Smart Home</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/social-media">Social Media</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/speakers">Speakers</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/tablets">Tablets</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/tech-industry">Tech Industry</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/tiktok">TikTok</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/transportation">Transportation</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/tvs">TVs</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/vpn">VPN</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/wifirouters">Wifi/Routers</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/science">SCIENCE</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/animals">Animals</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/climate-change">Climate Change</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/environment">Environment</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/nasa">NASA</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/rocket-launches">Rocket Launches</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/space">Space</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/">GAMES</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/arcade">Arcade</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/card">Card</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/casino">Casino</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/connections">Connections</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/daily">Daily</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/puzzles">Puzzles</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/strands">Strands</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://games.mashable.com/category/word">Word</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/wordle">Wordle</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/social-good" style="text-wrap: nowrap">SOCIAL GOOD</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/deals">DEALS</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/about/deals-coverage-explained">How we Select Deals</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/entertainment">ENTERTAINMENT</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/dc-comics">DC Comics</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/disney">Disney</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/hbo">HBO</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/hulu">Hulu</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/marvel">Marvel</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/movies">Movies</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/music">Music</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/peacock">Peacock</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/pixar">Pixar</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/podcasts">Podcasts</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/streaming">Streaming</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/tv-shows">TV Shows</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/true-crime">True Crime</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/life">LIFE</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/careers">Careers</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/digital-culture">Digital Culture</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/education">Education</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/family-parenting">Family &amp; Parenting</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/health-wellness">Health &amp; Wellness</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/house-home">House &amp; Home</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/mental-health">Mental Health</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/sex-dating-relationships">Sex, Dating &amp; Relationships</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/sleep">Sleep</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundups" style="text-wrap: nowrap">SHOP THE BEST</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/beauty">All Beauty</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/earbuds">All Earbuds</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/kitchen">All Kitchen</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/robot-vacuums">All Robot Vacuums</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-bluetooth-speakers">Bluetooth Speakers</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-cheap-laptops">Budget Laptops</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-dating-apps">Dating Apps</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-e-readers">E-Readers</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/gifts">Gift Guides</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-noise-cancelling-headphones">Headphones</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-hookup-apps">Hookup Apps</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-ipads">iPads</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-kindles">Kindles</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-laptops">Laptops</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/mashable-choice">Mashable Choice</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/mashable-selects">Mashable Selects</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-portable-bluetooth-speakers">Speakers</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-sexting-apps">Sexting Apps</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/the-best-macbooks">Macbooks</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-robot-vacuums">Robot Vaccuums</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-robot-vacuum-and-mop">Robot Vaccum &amp; Mop</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/best-vpns">VPNs</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/roundup/the-best-windows-laptops">Windows Laptops</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/review">REVIEWS</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/review/adult-friend-finder-review-dating-site">Adult Friend Finder</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/review/bumble-premium-review">Bumble Premium</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/review/kindle-paperwhite-signature-edition">Kindle Paperwhite</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/article/ps5-vs-ps5-slim-differences">PS5 vs PS5 Slim</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/review/tinder-platinum-review">Tinder Platinum</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/black-friday">Black Friday</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/ces">CES</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/cyber-monday">Cyber Monday</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/prime-day">Prime Day</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/samsung-unpacked">Samsung Galaxy Unpacked</a>,
#  <a class="pb-5 text-sm font-normal leading-5 text-white hover:text-secondary-100" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/category/wwdc">WWDC</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/videos" style="text-wrap: nowrap">VIDEOS</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/about/mashable-staff-masthead">About Mashable</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/about/editorial-standards">Editorial Standards</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/about/contact-us">Contact Us</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.j2global.com/careers/jobs/?brand=Mashable" rel="noopener" target="_blank" title="(opens in a new window)">We're Hiring</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/newsletters" rel="noopener">Newsletters</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://mashable.com/sitemap">Sitemap</a>,
#  <a aria-label="Mashable Facebook Page" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="facebook" data-ga-module="footer" href="https://www.facebook.com/mashable/" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block mt-6 mr-8 w-5 h-5 text-white fill-current md:mt-0 md:mr-0 hover:text-accent"><use href="/images/icons/spritemap.svg#sprite-facebook-f-brands"></use></svg></a>,
#  <a aria-label="Mashable Twitter Page" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="twitter" data-ga-module="footer" href="https://twitter.com/mashable" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block mt-6 mr-8 w-5 h-5 text-white fill-current md:mt-0 md:mr-0 hover:text-accent"><use href="/images/icons/spritemap.svg#sprite-twitter-brands"></use></svg></a>,
#  <a aria-label="Mashable Youtube Page" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="youtube" data-ga-module="footer" href="https://www.youtube.com/user/mashable" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block mt-6 mr-8 w-5 h-5 text-white fill-current md:mt-0 md:mr-0 hover:text-accent"><use href="/images/icons/spritemap.svg#sprite-youtube"></use></svg></a>,
#  <a aria-label="Mashable Pinterest Page" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="pinterest" data-ga-module="footer" href="https://www.pinterest.com/mashable/" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block mt-6 mr-8 w-5 h-5 text-white fill-current md:mt-0 md:mr-0 hover:text-accent"><use href="/images/icons/spritemap.svg#sprite-pinterest"></use></svg></a>,
#  <a aria-label="Mashable Flipboard Page" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="flipboard" data-ga-module="footer" href="https://flipboard.com/@Mashable" rel="noopener" target="_blank" title="(opens in a new window)">
#  <svg class="inline-block mt-6 mr-8 w-5 h-5 text-white fill-current md:mt-0 md:mr-0 hover:text-accent"><use href="/images/icons/spritemap.svg#sprite-flipboard-brands"></use></svg></a>,
# ...
#  <path d="M13.677 1.79431C15.9814 2.68239 17.8049 4.49481 18.703 6.79658C17.823 6.58815 16.9249 6.44316 16.0267 6.35254C15.5368 5.60038 14.8927 4.96604 14.1397 4.46762V4.4495C14.0399 3.56142 13.8857 2.67333 13.677 1.79431Z" fill="currentColor"></path>
#  <path d="M7.31733 18.1874C5.02205 17.2812 3.2076 15.4688 2.30945 13.167C3.08059 13.3392 3.96967 13.4932 4.96762 13.611H4.98576C5.47567 14.3632 6.1198 14.9975 6.87279 15.4959C6.97259 16.4022 7.11774 17.2993 7.31733 18.1874Z" fill="currentColor"></path>
#  <path d="M18.7212 13.1488C17.8231 15.4506 15.9995 17.272 13.6952 18.1692C13.8676 17.3808 14.0218 16.4927 14.1397 15.514V15.4959C14.8927 15.0065 15.5278 14.3631 16.0268 13.611H16.0449C16.9431 13.5203 17.8412 13.3663 18.7212 13.1488Z" fill="currentColor"></path>
#  <path d="M7.78002 4.65791C7.76187 4.83009 7.74373 4.98414 7.74373 5.12007L10.5017 7.58496L13.2597 5.1382C13.2597 4.95696 13.2415 4.78478 13.2052 4.60353C13.1326 3.83326 12.8423 1.54055 12.1347 0H8.87776C8.16105 1.54055 7.88888 3.86951 7.78002 4.65791ZM10.5108 12.3969L13.2506 14.8618C13.2506 15.043 13.2324 15.2152 13.1962 15.3965C13.1145 16.1667 12.8151 18.4594 12.1166 20H8.85962C8.14291 18.4413 7.86167 16.1124 7.78002 15.324C7.76187 15.1518 7.74373 14.9977 7.74373 14.8618L10.5108 12.3969ZM8.10662 10.0045L5.63897 12.7413C5.45752 12.7413 5.28515 12.7232 5.1037 12.6869C4.33256 12.6053 2.03728 12.3335 0.494995 11.6085V8.35523C2.05542 7.63933 4.38699 7.35841 5.17628 7.27685C5.34865 7.25872 5.50288 7.2406 5.63897 7.2406L8.10662 10.0045ZM20.5356 8.35523V11.6266C18.9933 12.3244 16.698 12.6235 15.9269 12.705C15.7545 12.7413 15.5731 12.7594 15.3916 12.7594L12.924 10.0045L15.3735 7.24966C15.5277 7.2406 15.682 7.25872 15.8362 7.28591C16.6255 7.36747 18.957 7.64839 20.5175 8.3643H20.5356V8.35523Z" fill="currentColor"></path>
#  </svg></a>,
#  <a aria-label="Speed Test" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="speedtest" data-ga-module="footer" href="https://www.speedtest.net/" rel="noopener">
#  <svg class="inline-block w-32 h-4 text-white fill-current hover:text-accent">
#  <path d="M22.199 11.5917C23.5051 12.7793 25.2132 13.4316 26.9771 13.426C29.4052 13.426 31.091 12.1381 31.091 9.99145V9.95799C31.091 8.06227 29.8462 7.1869 27.4069 6.59588C25.1909 6.07734 24.6662 5.68147 24.6662 4.79494V4.76706C24.6662 4.01993 25.3639 3.4066 26.5417 3.4066C27.5967 3.4066 28.6293 3.8192 29.662 4.58864L30.7505 3.06091C29.5783 2.12421 28.2498 1.61682 26.5752 1.61682C24.2978 1.61682 22.6511 2.97728 22.6511 4.94548V4.97894C22.6511 7.09769 24.0354 7.82252 26.4803 8.41354C28.6126 8.90977 29.0759 9.35025 29.0759 10.1754V10.2089C29.0759 11.062 28.2833 11.653 27.0385 11.653C25.6263 11.653 24.5043 11.1066 23.4102 10.1587L22.199 11.5917Z" fill="currentColor"></path>
#  <path d="M34.8475 7.74992V3.60722H37.1975C38.7046 3.60722 39.6759 4.31532 39.6759 5.66463V5.69809C39.6759 6.89685 38.727 7.7555 37.1975 7.7555H34.8475V7.74992ZM32.8213 1.77283V13.2698H34.8475V9.57316H37.1361C39.6703 9.57316 41.7356 8.23501 41.7356 5.65348V5.62003C41.7356 3.30056 40.0666 1.77283 37.3705 1.77283H32.8325H32.8213Z" fill="currentColor"></path>
#  <path d="M43.4772 13.2698H52.0957V11.4577H45.5034V8.36882H51.2751V6.56789H45.5034V3.57376H52.0119V1.77283H43.4772V13.2698Z" fill="currentColor"></path>
#  <path d="M54.161 13.2698H62.7739V11.4577H56.1872V8.36882H61.9478V6.56789H56.1872V3.57376H62.6958V1.77283H54.161V13.2698Z" fill="currentColor"></path>
#  <path d="M69.1317 3.61837C71.5486 3.61837 73.1283 5.28549 73.1283 7.5269V7.56035C73.1283 9.81291 71.5486 11.441 69.1317 11.441H66.8654V3.61837H69.1317ZM64.8503 1.77283V13.2587H69.1428C72.7599 13.2587 75.2606 10.7496 75.2606 7.51575V7.48229C75.2606 4.24842 72.7599 1.77283 69.1428 1.77283H64.8503Z" fill="currentColor"></path>
#  <path d="M80.0331 13.2698H82.065V3.64625H85.7155V1.77283H76.3826V3.64625H80.0331V13.2698Z" fill="currentColor"></path>
#  <path d="M87.859 13.2698H96.4663V11.4577H89.8741V8.36882H95.6458V6.56789H89.8741V3.57376H96.3826V1.77283H87.859V13.2698Z" fill="currentColor"></path>
#  <path d="M98.0906 11.5917C99.3967 12.7793 101.105 13.4316 102.869 13.426C105.297 13.426 106.983 12.1381 106.983 9.99145V9.95799C106.983 8.06227 105.738 7.1869 103.299 6.59588C101.082 6.07734 100.558 5.68147 100.558 4.79494V4.76706C100.558 4.01993 101.256 3.4066 102.433 3.4066C103.488 3.4066 104.521 3.8192 105.554 4.58864L106.642 3.06091C105.47 2.12421 104.141 1.61682 102.467 1.61682C100.189 1.61682 98.5427 2.97728 98.5427 4.94548V4.97894C98.5427 7.09769 99.927 7.82252 102.372 8.41354C104.504 8.90977 104.967 9.35025 104.967 10.1754V10.2089C104.967 11.062 104.175 11.653 102.93 11.653C101.518 11.653 100.396 11.1066 99.3019 10.1587L98.0906 11.5917Z" fill="currentColor"></path>
#  <path d="M111.973 13.2698H114.021V3.64625H117.672V1.77283H108.333V3.64625H111.973V13.2698Z" fill="currentColor"></path>
#  <path clip-rule="evenodd" d="M13.106 12.7512C15.6235 10.2311 15.6235 6.14968 13.106 3.62949C10.583 1.10929 6.49144 1.10929 3.96841 3.62391C1.44539 6.13853 1.4398 10.2311 3.95725 12.7512L2.80737 13.8998L2.80179 13.8943C-0.357571 10.7329 -0.351989 5.61999 2.80737 2.46417C5.96674 -0.691643 11.0909 -0.686067 14.2503 2.46975C17.4097 5.62557 17.4041 10.744 14.2447 13.8998L13.106 12.7512Z" fill="currentColor" fill-rule="evenodd"></path>
#  <path clip-rule="evenodd" d="M12.3245 5.21843L11.4705 4.36536L6.87097 8.37982L8.30552 9.81277L12.3245 5.21843Z" fill="currentColor" fill-rule="evenodd"></path>
#  <path d="M119.263 2.68712V2.31912H119.548C119.693 2.31912 119.782 2.38045 119.782 2.49754C119.782 2.61463 119.687 2.68712 119.548 2.68712H119.263ZM119.073 3.25026H119.263V2.85996H119.503L119.776 3.25026H120.011L119.715 2.82651C119.871 2.79305 119.983 2.65366 119.977 2.49197C119.977 2.40276 119.944 2.31355 119.882 2.25221C119.793 2.17973 119.682 2.1407 119.564 2.14628H119.068V3.25026H119.073Z" fill="currentColor"></path>
#  <path d="M119.486 1.7616C120.011 1.7616 120.435 2.18535 120.435 2.70946C120.435 3.23357 120.011 3.65732 119.486 3.65732C118.961 3.65732 118.537 3.23357 118.537 2.70946C118.537 2.18535 118.961 1.7616 119.486 1.7616ZM119.486 1.88984C119.04 1.88984 118.671 2.25225 118.671 2.70388C118.671 3.14993 119.034 3.51793 119.486 3.51793C119.933 3.51793 120.301 3.15551 120.301 2.70388C120.301 2.25225 119.933 1.88984 119.486 1.88984Z" fill="currentColor"></path>
#  </svg></a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/about" rel="noopener" target="_blank" title="(opens in a new window)">About Ziff Davis</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/ztg-privacy-policy" rel="noopener" target="_blank" title="(opens in a new window)">Privacy Policy</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/terms-of-use" rel="noopener" target="_blank" title="(opens in a new window)">Terms of Use</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://ziffmedia.com/" rel="noopener" target="_blank" title="(opens in a new window)">Advertise</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://www.ziffdavis.com/accessibility" rel="noopener" target="_blank" title="(opens in a new window)">Accessibility</a>,
#  <a class="text-white hover:text-accent" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="$text" data-ga-module="footer" href="https://dsar.mashable.com">Do Not Sell My Personal Information</a>,
#  <a aria-label="BBB Accredited Business Logo" data-ga-click="" data-ga-element="footer-link" data-ga-item="title" data-ga-label="BBB Accredited Business Logo" data-ga-module="footer" href="https://www.bbb.org/us/ny/new-york/profile/digital-media/ziff-davis-llc-0121-531/#sealclick" rel="noopener" target="_blank" title="(opens in a new window)"><svg height="50" version="1.1" viewbox="0 0 78 45" width="96" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#  <style>
#        .cls-1 {
#          fill: none;
#        }
#
#        .cls-2 {
#          fill: #fff;
#        }
#
#        .cls-2, .cls-3 {
#          fill-rule: evenodd;
#        }
#
#        .cls-4, .cls-3 {
#          fill: #005f85;
#        }
#
#        .cls-5 {
#          clip-path: url(#clippath);
#        }
#      </style>
#  <clippath id="clippath">
#  <rect class="cls-1" height="45" width="78"></rect>
#  </clippath>
#  </defs>
#  <!-- Generator: Adobe Illustrator 28.6.0, SVG Export Plug-In . SVG Version: 1.2.0 Build 709)  -->
#  <g>
#  <g id="Layer_1">
#  <g class="cls-5">
#  <g>
#  <path class="cls-3" d="M4,30.8c-2.1,0-3.8-1.8-3.8-4V4C.1,1.8,1.9,0,4,0h70.2c2.1,0,3.8,1.8,3.8,4v22.7c0,2.2-1.7,4-3.8,4H4Z"></path>
#  <path class="cls-2" d="M4.2.6c-1.9,0-3.4,1.5-3.4,3.4v22.7c0,1.9,1.5,3.4,3.4,3.4h23.8V.6H4.2ZM60.1,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.5-.3-1.9-.7h0ZM56.1,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.5-.3-1.9-.7h0ZM41.5,21.2l.5-.7c.4.4.9.6,1.4.6s.8-.2.8-.5-.4-.4-.9-.5c-.7-.2-1.6-.4-1.6-1.4s.6-1.3,1.7-1.3,1.3.2,1.7.6l-.5.7c-.4-.3-.8-.5-1.3-.5-.4,0-.6.2-.6.4s.4.4.9.5c.7.2,1.6.4,1.6,1.4s-.6,1.4-1.8,1.4c-.8,0-1.4-.3-1.9-.7h0ZM37,20.1v-2.6h1v2.6c0,.6.4,1,1,1s1-.4,1-1v-2.6h1v2.6c0,1.1-.6,1.8-2,1.8-1.3,0-2-.7-2-1.8h0ZM50.7,21.8l-2.1-2.9v2.9h-.9v-4.4h1l2,2.8v-2.8h.9v4.4h-.9ZM45.8,21.8v-4.4h.9v4.4h-.9ZM52.5,21.8v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM32.6,21.8v-4.4h2.3c.8,0,1.3.5,1.3,1.1s-.3.9-.8,1c.5,0,.8.5.8,1.1s-.4,1.2-1.3,1.2h-2.4s0,0,0,0ZM35.3,20.5c0-.3-.2-.5-.6-.5h-1.2v1h1.2c.4,0,.6-.2.6-.5ZM35.2,18.7c0-.3-.2-.5-.5-.5h-1.2v1h1.2c.3,0,.5-.2.5-.5h0s0,0,0,0ZM36.9,12.1c0-1.3,1-2.3,2.3-2.3.8,0,1.5.4,1.8,1.1l-.8.4c-.2-.4-.6-.6-1-.6-.8,0-1.4.6-1.4,1.4s.6,1.4,1.4,1.4c.4,0,.8-.2,1-.6l.8.4c-.3.5-.9,1.1-1.8,1.1-1.3,0-2.3-.9-2.3-2.3ZM41.5,12.1c0-1.3,1-2.3,2.3-2.3.8,0,1.5.4,1.8,1.1l-.8.4c-.2-.4-.6-.6-1-.6-.8,0-1.4.6-1.4,1.4s.6,1.4,1.4,1.4c.4,0,.8-.2,1-.6l.8.4c-.3.5-.9,1.1-1.8,1.1-1.3,0-2.3-.9-2.3-2.3ZM48.7,14.3l-.9-1.6h-.7v1.6h-.9v-4.4h2.1c.9,0,1.5.6,1.5,1.4s-.5,1.2-1,1.3l1,1.7h-1.1s0,0,0,0ZM35.6,14.3l-.3-.7h-1.9l-.3.7h-1.1l1.7-4.4h1.2l1.7,4.4h-1.1ZM68.8,14.3v-4.4h1.7c1.4,0,2.3.9,2.3,2.2s-1,2.2-2.3,2.2h-1.7ZM64.9,14.3v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM59.2,14.3v-4.4h.9v4.4h-.9ZM54.4,14.3v-4.4h1.7c1.4,0,2.3.9,2.3,2.2s-1,2.2-2.3,2.2h-1.7ZM50.5,14.3v-4.4h3.1v.8h-2.2v.9h2.1v.8h-2.1v1h2.2v.8h-3.1ZM62,14.3v-3.6h-1.3v-.8h3.5v.8h-1.3v3.6h-.9ZM71.9,12.1c0-.8-.5-1.4-1.4-1.4h-.8v2.7h.8c.9,0,1.4-.6,1.4-1.4h0ZM57.5,12.1c0-.8-.5-1.4-1.4-1.4h-.8v2.7h.8c.9,0,1.4-.6,1.4-1.4h0ZM34.4,10.8l-.7,1.9h1.4l-.7-1.9ZM48.8,11.3c0-.4-.3-.6-.7-.6h-1v1.2h1c.4,0,.7-.2.7-.6h0Z"></path>
#  <path class="cls-3" d="M10,25.4c.6.3.9.5,1,1.2.2,1.4-1,1.9-2.2,1.9h-2.8v-5.9h2.8c1,0,1.9.5,1.9,1.6s-.3,1-.8,1.2h0ZM15.5,25.4c.6.3.9.5,1,1.2.2,1.4-1,1.9-2.2,1.9h-2.8v-5.9h2.8c1,0,1.9.5,1.9,1.6s-.3,1-.8,1.2h0ZM22,26.6c-.1-.8-.4-1-1-1.2.5-.3.8-.7.8-1.2,0-1.1-.9-1.6-1.9-1.6h-2.8v5.9h2.8c1.2,0,2.4-.5,2.2-1.9h0ZM22.8,27.1h0c0-.8.6-1.4,1.4-1.4s1.4.6,1.4,1.4h0c0,.8-.6,1.4-1.4,1.4-.7,0-1.4-.6-1.4-1.4ZM25.4,27.1h0c0-.7-.6-1.2-1.2-1.2s-1.2.6-1.2,1.2h0c0,.7.6,1.2,1.2,1.2s1.2-.6,1.2-1.2ZM23.6,26.3h.6c.2,0,.3,0,.4.1,0,0,.1.2.1.3h0c0,.2-.2.4-.4.4l.4.6h-.3l-.4-.5h-.4v.5h-.2v-1.4s0,0,0,0ZM8.9,27.4h-1.6v-1.3h1.6c1.2,0,1.1,1.3,0,1.3ZM14.4,27.4h-1.6v-1.3h1.6c1.2,0,1.1,1.3,0,1.3ZM18.3,26v1.3h1.6c1.1,0,1.2-1.3,0-1.3h-1.6ZM24.2,27c.2,0,.3,0,.3-.2h0c0-.2-.1-.2-.3-.2h-.4v.5h.4ZM7.3,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM18.3,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM12.8,23.7h1.4c.9,0,.9,1.3,0,1.3h-1.5v-1.3ZM8.7,19.9h2.7l.5,1.6h4.4l.5-1.6h2.7l-.4-1.2h-10l-.4,1.2h0ZM12,10.3l-1.3,1.8c-.7.9-.5,2.5.4,3.1l2.4,1.7c.4.3.4.6.2.9l.4.3,1.2-1.7c.8-1,.7-2.5-.4-3.3l-2.4-1.8c-.3-.2-.3-.5-.2-.8l-.3-.2h0ZM14,2.4l-2,2.8c-.9,1.3-.6,3.6.7,4.5l3.3,2.4c.7.5.8,1.8.3,2.4l.3.2,2.3-3.2c1-1.5,1-3.6-.6-4.8l-3.6-2.6c-.5-.4-.7-1-.3-1.6l-.3-.2h0Z"></path>
#  </g>
#  </g>
#  <path class="cls-4" d="M6.2,43.9c-.6,0-1.1,0-1.6-.3-.5-.2-.9-.5-1.2-.8-.4-.4-.6-.8-.8-1.3-.2-.5-.3-1-.3-1.6s0-1.1.3-1.5c.2-.5.5-.9.8-1.3.4-.4.8-.6,1.2-.8.5-.2,1-.3,1.6-.3s1.2.1,1.6.3c.5.2.9.5,1.2.8l-.9.9c-.2-.2-.5-.4-.8-.6-.3-.1-.7-.2-1.1-.2s-.7,0-1,.2c-.3.1-.6.3-.8.6-.2.2-.4.5-.5.9-.1.3-.2.7-.2,1.1s0,.8.2,1.1c.1.3.3.6.5.9.2.2.5.4.8.6.3.1.7.2,1,.2s.9,0,1.2-.2c.3-.1.6-.3.8-.6l.9.9c-.4.4-.8.6-1.2.8-.5.2-1,.3-1.6.3ZM10.1,43.8v-7.9h1.2v7.9h-1.2ZM12.6,43.8v-5.3h1.2v5.3h-1.2ZM13.2,37.5c-.2,0-.4,0-.5-.2-.1-.1-.2-.3-.2-.5s0-.4.2-.5c.1-.1.3-.2.5-.2s.4,0,.5.2c.1.1.2.3.2.5s0,.4-.2.5c-.1.1-.3.2-.5.2ZM17.6,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.7-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s.8,0,1.1.2c.4.2.7.4.9.7l-.8.8c-.2-.2-.3-.3-.6-.4-.2,0-.4-.1-.7-.1s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2s.5,0,.7-.1c.2,0,.4-.2.6-.4l.8.8c-.2.3-.6.5-.9.7-.4.2-.7.2-1.1.2ZM23.9,43.8l-2.2-2.7,2.2-2.6h1.4l-2.6,2.9v-.7c0,0,2.7,3.1,2.7,3.1h-1.5ZM20.6,43.8v-7.9h1.2v7.9h-1.2ZM29.1,43.8v-6c0-.4,0-.8.3-1.1.2-.3.4-.5.7-.7.3-.2.7-.3,1.1-.3s.6,0,.8.2c.2.1.4.3.6.5l-.8.8c0,0-.2-.2-.3-.2-.1,0-.2,0-.4,0-.3,0-.5,0-.7.2-.2.2-.2.4-.2.7v6h-1.2ZM27.8,39.6v-1.1h4.1v1.1h-4.1ZM35,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s1,.1,1.4.4c.4.2.7.6,1,1,.2.4.4.9.4,1.4s-.1,1-.4,1.4c-.2.4-.6.8-1,1-.4.2-.9.4-1.4.4ZM35,42.7c.3,0,.6,0,.8-.2.2-.1.4-.3.5-.6.1-.2.2-.5.2-.8s0-.6-.2-.8c-.1-.2-.3-.4-.5-.5-.2-.1-.5-.2-.8-.2s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2ZM38.8,43.8v-5.3h1.2v5.3h-1.2ZM40,40.9l-.4-.2c0-.7.1-1.2.4-1.6.3-.4.8-.6,1.4-.6s.5,0,.7.1c.2,0,.4.2.6.5l-.8.8c0-.1-.2-.2-.3-.2-.1,0-.3,0-.4,0-.3,0-.6.1-.8.3-.2.2-.3.5-.3,1ZM46.7,40.9v-1.1h1.9c.3,0,.5,0,.7-.2.2-.1.4-.3.5-.5.1-.2.2-.4.2-.7s0-.5-.2-.7c-.1-.2-.3-.3-.5-.5-.2-.1-.4-.2-.7-.2h-1.9v-1.1h2c.5,0,.9,0,1.3.3.4.2.7.5.9.8.2.4.3.8.3,1.3s-.1.9-.3,1.3c-.2.4-.5.6-.9.8-.4.2-.8.3-1.3.3h-2ZM45.8,43.8v-7.7h1.3v7.7h-1.3ZM52.3,43.8v-5.3h1.2v5.3h-1.2ZM53.5,40.9l-.4-.2c0-.7.1-1.2.4-1.6.3-.4.8-.6,1.4-.6s.5,0,.7.1c.2,0,.4.2.6.5l-.8.8c0-.1-.2-.2-.3-.2-.1,0-.3,0-.4,0-.3,0-.6.1-.8.3-.2.2-.3.5-.3,1ZM59,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s1,.1,1.4.4c.4.2.7.6,1,1,.2.4.4.9.4,1.4s-.1,1-.4,1.4c-.2.4-.6.8-1,1-.4.2-.9.4-1.4.4ZM59,42.7c.3,0,.6,0,.8-.2.2-.1.4-.3.5-.6.1-.2.2-.5.2-.8s0-.6-.2-.8c-.1-.2-.3-.4-.5-.5-.2-.1-.5-.2-.8-.2s-.6,0-.8.2c-.2.1-.4.3-.5.5-.1.2-.2.5-.2.8s0,.6.2.8c.1.2.3.4.5.6.2.1.5.2.8.2ZM63.4,43.8v-6.2c0-.4,0-.7.2-.9.2-.3.4-.5.7-.7.3-.2.6-.2,1-.2s.5,0,.7.1c.2,0,.4.2.6.4l-.8.8c0,0-.2-.1-.2-.1,0,0-.2,0-.3,0-.2,0-.4,0-.5.2-.1.1-.2.3-.2.5v6.2h-1.2ZM62.1,39.6v-1.1h5.1v1.1h-5.1ZM66.6,43.8v-5.3h1.2v5.3h-1.2ZM67.2,38.1c-.2,0-.4,0-.5-.2-.1-.1-.2-.3-.2-.5s0-.4.2-.5c.1-.1.3-.2.5-.2s.4,0,.5.2c.1.1.2.3.2.5s0,.4-.2.5c-.1.1-.3.2-.5.2ZM69.1,43.8v-7.9h1.2v7.9h-1.2ZM74.1,43.9c-.5,0-1-.1-1.4-.4-.4-.2-.8-.6-1-1-.2-.4-.4-.9-.4-1.4s.1-1,.4-1.4c.2-.4.6-.7,1-1,.4-.2.9-.4,1.4-.4s.9.1,1.3.3c.4.2.7.5.9.9.2.4.3.8.3,1.4s0,.2,0,.3c0,0,0,.2,0,.3h-4.3v-1h3.7l-.5.4c0-.3,0-.6-.2-.8s-.3-.4-.5-.5c-.2-.1-.4-.2-.7-.2s-.6,0-.8.2c-.2.1-.4.3-.5.6-.1.2-.2.5-.2.8s0,.6.2.9c.1.2.3.4.6.6.2.1.5.2.8.2s.5,0,.7-.1c.2,0,.4-.2.6-.4l.8.8c-.3.3-.6.5-.9.7-.4.2-.8.2-1.2.2Z"></path>
#  </g>
#  </g>
#  </svg></a>]

# %%
for tag in soup.find_all("a", attrs={'href': re.compile("^https")}):
    print(tag["href"])
# Out:
# https://mashable.com
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/tech
# https://mashable.com/science
# https://mashable.com/life
# https://mashable.com/category/social-good
# https://mashable.com/entertainment
# https://mashable.com/deals
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/category/apps-software
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cybersecurity
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/mobile
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/tech-industry
# https://mashable.com/category/transportation
# https://mashable.com/tech
# https://mashable.com/category/space
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/science
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/category/careers
# https://mashable.com/category/mental-health
# https://mashable.com/life
# https://mashable.com/category/activism
# https://mashable.com/category/gender
# https://mashable.com/category/lgbtq
# https://mashable.com/category/racism
# https://mashable.com/category/sustainability
# https://mashable.com/category/politics
# https://mashable.com/category/social-good
# https://mashable.com/category/games
# https://mashable.com/category/movies
# https://mashable.com/category/podcasts
# https://mashable.com/category/tv-shows
# https://mashable.com/category/watch-guides
# https://mashable.com/entertainment
# https://mashable.com/roundup/best-laptops
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/article/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-kindles
# https://mashable.com/gifts
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/laptops
# https://mashable.com/category/headphones
# https://mashable.com/category/robot-vacuums
# https://mashable.com/category/vpn
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/tinder-platinum-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review
# https://mashable.com/shopping
# https://mashable.com/deals
# https://mashable.com/newsletters
# https://mashable.com/series
# https://mashable.com/shows
# https://mashable.com/videos
# https://www.facebook.com/sharer.php?u=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators
# https://twitter.com/intent/tweet?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://share.flipboard.com/bookmarklet/popout?v=2&url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&title=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://www.ziffdavis.com/terms-of-use
# https://www.ziffdavis.com/ztg-privacy-policy
# https://mashable.com/tech
# https://mashable.com/category/android
# https://mashable.com/category/antivirus
# https://mashable.com/category/apple
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cameras
# https://mashable.com/category/creative-software
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/desktops
# https://mashable.com/category/gaming-consoles
# https://mashable.com/category/headphones
# https://mashable.com/category/laptops
# https://mashable.com/category/microsoft
# https://mashable.com/category/mobile
# https://mashable.com/category/productivity
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/speakers
# https://mashable.com/category/tablets
# https://mashable.com/category/tech-industry
# https://mashable.com/category/tiktok
# https://mashable.com/category/transportation
# https://mashable.com/category/tvs
# https://mashable.com/category/vpn
# https://mashable.com/category/wifirouters
# https://mashable.com/science
# https://mashable.com/category/animals
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/category/nasa
# https://mashable.com/category/rocket-launches
# https://mashable.com/category/space
# https://games.mashable.com/
# https://games.mashable.com/category/arcade
# https://games.mashable.com/category/card
# https://games.mashable.com/category/casino
# https://mashable.com/category/connections
# https://games.mashable.com/category/daily
# https://games.mashable.com/category/puzzles
# https://mashable.com/category/strands
# https://games.mashable.com/category/word
# https://mashable.com/category/wordle
# https://mashable.com/category/social-good
# https://mashable.com/deals
# https://mashable.com/about/deals-coverage-explained
# https://mashable.com/entertainment
# https://mashable.com/category/dc-comics
# https://mashable.com/category/disney
# https://mashable.com/category/hbo
# https://mashable.com/category/hulu
# https://mashable.com/category/marvel
# https://mashable.com/category/movies
# https://mashable.com/category/music
# https://mashable.com/category/peacock
# https://mashable.com/category/pixar
# https://mashable.com/category/podcasts
# https://mashable.com/category/streaming
# https://mashable.com/category/tv-shows
# https://mashable.com/category/true-crime
# https://mashable.com/life
# https://mashable.com/category/careers
# https://mashable.com/category/digital-culture
# https://mashable.com/category/education
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/house-home
# https://mashable.com/category/mental-health
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/roundups
# https://mashable.com/category/beauty
# https://mashable.com/category/earbuds
# https://mashable.com/category/kitchen
# https://mashable.com/category/robot-vacuums
# https://mashable.com/roundup/best-bluetooth-speakers
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-e-readers
# https://mashable.com/gifts
# https://mashable.com/roundup/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-ipads
# https://mashable.com/roundup/best-kindles
# https://mashable.com/roundup/best-laptops
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/the-best-macbooks
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/the-best-windows-laptops
# https://mashable.com/review
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review/tinder-platinum-review
# https://mashable.com/category/black-friday
# https://mashable.com/category/ces
# https://mashable.com/category/cyber-monday
# https://mashable.com/category/prime-day
# https://mashable.com/category/samsung-unpacked
# https://mashable.com/category/wwdc
# https://mashable.com/videos
# https://mashable.com/about/mashable-staff-masthead
# https://mashable.com/about/editorial-standards
# https://mashable.com/about/contact-us
# https://www.j2global.com/careers/jobs/?brand=Mashable
# https://mashable.com/newsletters
# https://mashable.com/sitemap
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# https://www.youtube.com/user/mashable
# https://www.pinterest.com/mashable/
# https://flipboard.com/@Mashable
# https://www.linkedin.com/company/mashable
# https://mashable.com/feeds/rss/all
# https://www.ziffdavis.com/
# https://www.cnet.com/
# https://www.zdnet.com/
# https://www.pcmag.com/
# https://www.lifehacker.com/
# https://www.askmen.com/
# https://www.extremetech.com/
# https://www.ign.com/
# https://www.speedtest.net/
# https://www.ziffdavis.com/about
# https://www.ziffdavis.com/ztg-privacy-policy
# https://www.ziffdavis.com/terms-of-use
# https://ziffmedia.com/
# https://www.ziffdavis.com/accessibility
# https://dsar.mashable.com
# https://www.bbb.org/us/ny/new-york/profile/digital-media/ziff-davis-llc-0121-531/#sealclick

# %%
for tag in soup.find_all("a", attrs={'href': re.compile("^http://")}):
    print(tag["href"])
# Out:
# http://instagram.com/Mashable

# %%
for tag in soup.find_all("a", href=True):
    print(tag["href"])
# Out:
# https://mashable.com
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/tech
# https://mashable.com/science
# https://mashable.com/life
# https://mashable.com/category/social-good
# https://mashable.com/entertainment
# https://mashable.com/deals
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/category/apps-software
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cybersecurity
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/mobile
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/tech-industry
# https://mashable.com/category/transportation
# https://mashable.com/tech
# https://mashable.com/category/space
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/science
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/category/careers
# https://mashable.com/category/mental-health
# https://mashable.com/life
# https://mashable.com/category/activism
# https://mashable.com/category/gender
# https://mashable.com/category/lgbtq
# https://mashable.com/category/racism
# https://mashable.com/category/sustainability
# https://mashable.com/category/politics
# https://mashable.com/category/social-good
# https://mashable.com/category/games
# https://mashable.com/category/movies
# https://mashable.com/category/podcasts
# https://mashable.com/category/tv-shows
# https://mashable.com/category/watch-guides
# https://mashable.com/entertainment
# https://mashable.com/roundup/best-laptops
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/article/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-kindles
# https://mashable.com/gifts
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/laptops
# https://mashable.com/category/headphones
# https://mashable.com/category/robot-vacuums
# https://mashable.com/category/vpn
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/tinder-platinum-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review
# https://mashable.com/shopping
# https://mashable.com/deals
# https://mashable.com/newsletters
# /series/best-tech-apple-e-readers-airpods-headphones-earbuds-laptops-robovac
# /series/trending-now
# /series/look-up
# /series/mashable-selects
# /series/versus
# /series/top-creators-youtube-instagram-tiktok-ranked
# /series/in-my-bag
# /series/best-gifts
# /series/moms-dads-grads-gift-guide
# /series/ai-at-work
# /series/ai-at-home
# /series/readers-choice
# https://mashable.com/series
# https://mashable.com/shows
# https://mashable.com/videos
# /author/grace-smith
# https://www.facebook.com/sharer.php?u=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators
# https://twitter.com/intent/tweet?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://share.flipboard.com/bookmarklet/popout?v=2&url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&title=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://www.ziffdavis.com/terms-of-use
# https://www.ziffdavis.com/ztg-privacy-policy
# https://mashable.com/tech
# https://mashable.com/category/android
# https://mashable.com/category/antivirus
# https://mashable.com/category/apple
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cameras
# https://mashable.com/category/creative-software
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/desktops
# https://mashable.com/category/gaming-consoles
# https://mashable.com/category/headphones
# https://mashable.com/category/laptops
# https://mashable.com/category/microsoft
# https://mashable.com/category/mobile
# https://mashable.com/category/productivity
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/speakers
# https://mashable.com/category/tablets
# https://mashable.com/category/tech-industry
# https://mashable.com/category/tiktok
# https://mashable.com/category/transportation
# https://mashable.com/category/tvs
# https://mashable.com/category/vpn
# https://mashable.com/category/wifirouters
# https://mashable.com/science
# https://mashable.com/category/animals
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/category/nasa
# https://mashable.com/category/rocket-launches
# https://mashable.com/category/space
# https://games.mashable.com/
# https://games.mashable.com/category/arcade
# https://games.mashable.com/category/card
# https://games.mashable.com/category/casino
# https://mashable.com/category/connections
# https://games.mashable.com/category/daily
# https://games.mashable.com/category/puzzles
# https://mashable.com/category/strands
# https://games.mashable.com/category/word
# https://mashable.com/category/wordle
# https://mashable.com/category/social-good
# https://mashable.com/deals
# https://mashable.com/about/deals-coverage-explained
# https://mashable.com/entertainment
# https://mashable.com/category/dc-comics
# https://mashable.com/category/disney
# https://mashable.com/category/hbo
# https://mashable.com/category/hulu
# https://mashable.com/category/marvel
# https://mashable.com/category/movies
# https://mashable.com/category/music
# https://mashable.com/category/peacock
# https://mashable.com/category/pixar
# https://mashable.com/category/podcasts
# https://mashable.com/category/streaming
# https://mashable.com/category/tv-shows
# https://mashable.com/category/true-crime
# https://mashable.com/life
# https://mashable.com/category/careers
# https://mashable.com/category/digital-culture
# https://mashable.com/category/education
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/house-home
# https://mashable.com/category/mental-health
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/roundups
# https://mashable.com/category/beauty
# https://mashable.com/category/earbuds
# https://mashable.com/category/kitchen
# https://mashable.com/category/robot-vacuums
# https://mashable.com/roundup/best-bluetooth-speakers
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-e-readers
# https://mashable.com/gifts
# https://mashable.com/roundup/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-ipads
# https://mashable.com/roundup/best-kindles
# https://mashable.com/roundup/best-laptops
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/the-best-macbooks
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/the-best-windows-laptops
# https://mashable.com/review
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review/tinder-platinum-review
#
# https://mashable.com/category/black-friday
# https://mashable.com/category/ces
# https://mashable.com/category/cyber-monday
# https://mashable.com/category/prime-day
# https://mashable.com/category/samsung-unpacked
# https://mashable.com/category/wwdc
# https://mashable.com/videos
# https://mashable.com/about/mashable-staff-masthead
# https://mashable.com/about/editorial-standards
# https://mashable.com/about/contact-us
# https://www.j2global.com/careers/jobs/?brand=Mashable
# https://mashable.com/newsletters
# https://mashable.com/sitemap
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://instagram.com/Mashable
# https://www.youtube.com/user/mashable
# https://www.pinterest.com/mashable/
#  https://www.tiktok.com/@mashable
# https://flipboard.com/@Mashable
# https://www.linkedin.com/company/mashable
# https://mashable.com/feeds/rss/all
# https://www.ziffdavis.com/
# https://www.cnet.com/
# https://www.zdnet.com/
# https://www.pcmag.com/
# https://www.lifehacker.com/
# https://www.askmen.com/
# https://www.extremetech.com/
# https://www.ign.com/
# https://www.speedtest.net/
# https://www.ziffdavis.com/about
# https://www.ziffdavis.com/ztg-privacy-policy
# https://www.ziffdavis.com/terms-of-use
# https://ziffmedia.com/
# https://www.ziffdavis.com/accessibility
# https://dsar.mashable.com
# https://www.bbb.org/us/ny/new-york/profile/digital-media/ziff-davis-llc-0121-531/#sealclick

# %%
for link in soup.find_all("a", href=True):
    if not link['href'].startswith('http'):
        link = url + link["href"].strip("/")
    else:
        link = link["href"]
        
    print(link)
# Out:
# https://mashable.com
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/tech
# https://mashable.com/science
# https://mashable.com/life
# https://mashable.com/category/social-good
# https://mashable.com/entertainment
# https://mashable.com/deals
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/mashable-101-top-creators-2025
# https://mashable.com/category/creators
# https://mashable.com/category/apps-software
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cybersecurity
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/mobile
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/tech-industry
# https://mashable.com/category/transportation
# https://mashable.com/tech
# https://mashable.com/category/space
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/science
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/category/careers
# https://mashable.com/category/mental-health
# https://mashable.com/life
# https://mashable.com/category/activism
# https://mashable.com/category/gender
# https://mashable.com/category/lgbtq
# https://mashable.com/category/racism
# https://mashable.com/category/sustainability
# https://mashable.com/category/politics
# https://mashable.com/category/social-good
# https://mashable.com/category/games
# https://mashable.com/category/movies
# https://mashable.com/category/podcasts
# https://mashable.com/category/tv-shows
# https://mashable.com/category/watch-guides
# https://mashable.com/entertainment
# https://mashable.com/roundup/best-laptops
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/article/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-kindles
# https://mashable.com/gifts
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/laptops
# https://mashable.com/category/headphones
# https://mashable.com/category/robot-vacuums
# https://mashable.com/category/vpn
# https://mashable.com/shopping
# https://games.mashable.com/
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/tinder-platinum-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review
# https://mashable.com/shopping
# https://mashable.com/deals
# https://mashable.com/newsletters
# https://mashable.com/2014/08/28/static-website-generators/series/best-tech-apple-e-readers-airpods-headphones-earbuds-laptops-robovac
# https://mashable.com/2014/08/28/static-website-generators/series/trending-now
# https://mashable.com/2014/08/28/static-website-generators/series/look-up
# https://mashable.com/2014/08/28/static-website-generators/series/mashable-selects
# https://mashable.com/2014/08/28/static-website-generators/series/versus
# https://mashable.com/2014/08/28/static-website-generators/series/top-creators-youtube-instagram-tiktok-ranked
# https://mashable.com/2014/08/28/static-website-generators/series/in-my-bag
# https://mashable.com/2014/08/28/static-website-generators/series/best-gifts
# https://mashable.com/2014/08/28/static-website-generators/series/moms-dads-grads-gift-guide
# https://mashable.com/2014/08/28/static-website-generators/series/ai-at-work
# https://mashable.com/2014/08/28/static-website-generators/series/ai-at-home
# https://mashable.com/2014/08/28/static-website-generators/series/readers-choice
# https://mashable.com/series
# https://mashable.com/shows
# https://mashable.com/videos
# https://mashable.com/2014/08/28/static-website-generators/author/grace-smith
# https://www.facebook.com/sharer.php?u=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators
# https://twitter.com/intent/tweet?url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://share.flipboard.com/bookmarklet/popout?v=2&url=https%3A%2F%2Fmashable.com%2Farchive%2Fstatic-website-generators&title=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website
# https://www.ziffdavis.com/terms-of-use
# https://www.ziffdavis.com/ztg-privacy-policy
# https://mashable.com/tech
# https://mashable.com/category/android
# https://mashable.com/category/antivirus
# https://mashable.com/category/apple
# https://mashable.com/category/artificial-intelligence
# https://mashable.com/category/cameras
# https://mashable.com/category/creative-software
# https://mashable.com/category/cryptocurrency
# https://mashable.com/category/desktops
# https://mashable.com/category/gaming-consoles
# https://mashable.com/category/headphones
# https://mashable.com/category/laptops
# https://mashable.com/category/microsoft
# https://mashable.com/category/mobile
# https://mashable.com/category/productivity
# https://mashable.com/category/smart-home
# https://mashable.com/category/social-media
# https://mashable.com/category/speakers
# https://mashable.com/category/tablets
# https://mashable.com/category/tech-industry
# https://mashable.com/category/tiktok
# https://mashable.com/category/transportation
# https://mashable.com/category/tvs
# https://mashable.com/category/vpn
# https://mashable.com/category/wifirouters
# https://mashable.com/science
# https://mashable.com/category/animals
# https://mashable.com/category/climate-change
# https://mashable.com/category/environment
# https://mashable.com/category/nasa
# https://mashable.com/category/rocket-launches
# https://mashable.com/category/space
# https://games.mashable.com/
# https://games.mashable.com/category/arcade
# https://games.mashable.com/category/card
# https://games.mashable.com/category/casino
# https://mashable.com/category/connections
# https://games.mashable.com/category/daily
# https://games.mashable.com/category/puzzles
# https://mashable.com/category/strands
# https://games.mashable.com/category/word
# https://mashable.com/category/wordle
# https://mashable.com/category/social-good
# https://mashable.com/deals
# https://mashable.com/about/deals-coverage-explained
# https://mashable.com/entertainment
# https://mashable.com/category/dc-comics
# https://mashable.com/category/disney
# https://mashable.com/category/hbo
# https://mashable.com/category/hulu
# https://mashable.com/category/marvel
# https://mashable.com/category/movies
# https://mashable.com/category/music
# https://mashable.com/category/peacock
# https://mashable.com/category/pixar
# https://mashable.com/category/podcasts
# https://mashable.com/category/streaming
# https://mashable.com/category/tv-shows
# https://mashable.com/category/true-crime
# https://mashable.com/life
# https://mashable.com/category/careers
# https://mashable.com/category/digital-culture
# https://mashable.com/category/education
# https://mashable.com/category/family-parenting
# https://mashable.com/category/health-wellness
# https://mashable.com/category/house-home
# https://mashable.com/category/mental-health
# https://mashable.com/category/sex-dating-relationships
# https://mashable.com/category/sleep
# https://mashable.com/roundups
# https://mashable.com/category/beauty
# https://mashable.com/category/earbuds
# https://mashable.com/category/kitchen
# https://mashable.com/category/robot-vacuums
# https://mashable.com/roundup/best-bluetooth-speakers
# https://mashable.com/roundup/best-cheap-laptops
# https://mashable.com/roundup/best-dating-apps
# https://mashable.com/roundup/best-e-readers
# https://mashable.com/gifts
# https://mashable.com/roundup/best-noise-cancelling-headphones
# https://mashable.com/roundup/best-hookup-apps
# https://mashable.com/roundup/best-ipads
# https://mashable.com/roundup/best-kindles
# https://mashable.com/roundup/best-laptops
# https://mashable.com/mashable-choice
# https://mashable.com/category/mashable-selects
# https://mashable.com/roundup/best-portable-bluetooth-speakers
# https://mashable.com/roundup/best-sexting-apps
# https://mashable.com/roundup/the-best-macbooks
# https://mashable.com/roundup/best-robot-vacuums
# https://mashable.com/roundup/best-robot-vacuum-and-mop
# https://mashable.com/roundup/best-vpns
# https://mashable.com/roundup/the-best-windows-laptops
# https://mashable.com/review
# https://mashable.com/review/adult-friend-finder-review-dating-site
# https://mashable.com/review/bumble-premium-review
# https://mashable.com/review/kindle-paperwhite-signature-edition
# https://mashable.com/article/ps5-vs-ps5-slim-differences
# https://mashable.com/review/tinder-platinum-review
# https://mashable.com/2014/08/28/static-website-generators/
# https://mashable.com/category/black-friday
# https://mashable.com/category/ces
# https://mashable.com/category/cyber-monday
# https://mashable.com/category/prime-day
# https://mashable.com/category/samsung-unpacked
# https://mashable.com/category/wwdc
# https://mashable.com/videos
# https://mashable.com/about/mashable-staff-masthead
# https://mashable.com/about/editorial-standards
# https://mashable.com/about/contact-us
# https://www.j2global.com/careers/jobs/?brand=Mashable
# https://mashable.com/newsletters
# https://mashable.com/sitemap
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://instagram.com/Mashable
# https://www.youtube.com/user/mashable
# https://www.pinterest.com/mashable/
# https://mashable.com/2014/08/28/static-website-generators/ https://www.tiktok.com/@mashable
# https://flipboard.com/@Mashable
# https://www.linkedin.com/company/mashable
# https://mashable.com/feeds/rss/all
# https://www.ziffdavis.com/
# https://www.cnet.com/
# https://www.zdnet.com/
# https://www.pcmag.com/
# https://www.lifehacker.com/
# https://www.askmen.com/
# https://www.extremetech.com/
# https://www.ign.com/
# https://www.speedtest.net/
# https://www.ziffdavis.com/about
# https://www.ziffdavis.com/ztg-privacy-policy
# https://www.ziffdavis.com/terms-of-use
# https://ziffmedia.com/
# https://www.ziffdavis.com/accessibility
# https://dsar.mashable.com
# https://www.bbb.org/us/ny/new-york/profile/digital-media/ziff-davis-llc-0121-531/#sealclick
